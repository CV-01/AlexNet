# %%
from tensorflow.python.client import device_lib
print(device_lib.list_local_devices())
# Out:
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 9453362075317404472
# xla_global_id: -1
# , name: "/device:GPU:0"
# device_type: "GPU"
# memory_limit: 5748293632
# locality {
#   bus_id: 1
#   links {
#   }
# }
# incarnation: 10336434978980653159
# physical_device_desc: "device: 0, name: NVIDIA GeForce RTX 3060 Ti, pci bus id: 0000:2b:00.0, compute capability: 8.6"
# xla_global_id: 416903419
# ]

# %%
# Import necessary modules
import tensorflow as tf
from tensorflow import keras
from keras.models import Sequential
from keras.layers import Dense, Activation, Dropout, Flatten, Conv2D, MaxPooling2D, BatchNormalization
from keras.datasets import cifar100
from keras.utils import to_categorical

# Load CIFAR100 dataset
(train_images, train_labels), (test_images, test_labels) = cifar100.load_data()

# Normalize pixel values to be between 0 and 1
train_images, test_images = train_images / 255.0, test_images / 255.0

# Convert class vectors to binary class matrices
train_labels = to_categorical(train_labels, 100)
test_labels = to_categorical(test_labels, 100)

print(train_labels.shape, test_labels.shape)
# Out:
# (50000, 100) (10000, 100)

# %%
# AlexNet model architecture
model = Sequential()

# 1st Convolutional Layer
model.add(Conv2D(filters=96, input_shape=(32,32,3), kernel_size=(11,11), strides=(4,4), padding='same'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2,2), strides=(2,2), padding='same'))

# 2nd Convolutional Layer
model.add(Conv2D(filters=256, kernel_size=(5,5), strides=(1,1), padding='same'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2,2), strides=(2,2), padding='same'))

# 3rd Convolutional Layer
model.add(Conv2D(filters=384, kernel_size=(3,3), strides=(1,1), padding='same'))
model.add(BatchNormalization())
model.add(Activation('relu'))

# 4th Convolutional Layer
model.add(Conv2D(filters=384, kernel_size=(3,3), strides=(1,1), padding='same'))
model.add(BatchNormalization())
model.add(Activation('relu'))

# 5th Convolutional Layer
model.add(Conv2D(filters=256, kernel_size=(3,3), strides=(1,1), padding='same'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2,2), strides=(2,2), padding='same'))

# Fully Connected layer
model.add(Flatten())
model.add(Dense(4096, input_shape=(32,32,3,)))
model.add(BatchNormalization())
model.add(Activation('relu'))

# Add Dropout to prevent overfitting
model.add(Dropout(0.3))

# Fully Connected Layer
model.add(Dense(4096))
model.add(BatchNormalization())
model.add(Activation('relu'))
# Add Dropout
model.add(Dropout(0.3))

# Output Layer
model.add(Dense(100))  # Changed to 100 for CIFAR-100
model.add(BatchNormalization())
model.add(Activation('softmax'))

# Model Summary
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 8, 8, 96)          34944
#
#  batch_normalization (BatchN  (None, 8, 8, 96)         384
#  ormalization)
#
#  activation (Activation)     (None, 8, 8, 96)          0
#
#  max_pooling2d (MaxPooling2D  (None, 4, 4, 96)         0
#  )
#
#  conv2d_1 (Conv2D)           (None, 4, 4, 256)         614656
#
#  batch_normalization_1 (Batc  (None, 4, 4, 256)        1024
#  hNormalization)
#
#  activation_1 (Activation)   (None, 4, 4, 256)         0
#
#  max_pooling2d_1 (MaxPooling  (None, 2, 2, 256)        0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 2, 2, 384)         885120
#
#  batch_normalization_2 (Batc  (None, 2, 2, 384)        1536
#  hNormalization)
#
#  activation_2 (Activation)   (None, 2, 2, 384)         0
#
#  conv2d_3 (Conv2D)           (None, 2, 2, 384)         1327488
#
#  batch_normalization_3 (Batc  (None, 2, 2, 384)        1536
#  hNormalization)
#
#  activation_3 (Activation)   (None, 2, 2, 384)         0
#
#  conv2d_4 (Conv2D)           (None, 2, 2, 256)         884992
#
#  batch_normalization_4 (Batc  (None, 2, 2, 256)        1024
#  hNormalization)
#
#  activation_4 (Activation)   (None, 2, 2, 256)         0
#
#  max_pooling2d_2 (MaxPooling  (None, 1, 1, 256)        0
#  2D)
#
#  flatten (Flatten)           (None, 256)               0
#
#  dense (Dense)               (None, 4096)              1052672
#
#  batch_normalization_5 (Batc  (None, 4096)             16384
#  hNormalization)
#
#  activation_5 (Activation)   (None, 4096)              0
#
#  dropout (Dropout)           (None, 4096)              0
#
#  dense_1 (Dense)             (None, 4096)              16781312
#
#  batch_normalization_6 (Batc  (None, 4096)             16384
#  hNormalization)
#
#  activation_6 (Activation)   (None, 4096)              0
#
#  dropout_1 (Dropout)         (None, 4096)              0
#
#  dense_2 (Dense)             (None, 100)               409700
#
#  batch_normalization_7 (Batc  (None, 100)              400
#  hNormalization)
#
#  activation_7 (Activation)   (None, 100)               0
#
# =================================================================
# Total params: 22,029,556
# Trainable params: 22,010,220
# Non-trainable params: 19,336
# _________________________________________________________________

# %%
# Compile the model
model.compile(optimizer=tf.keras.optimizers.SGD(learning_rate=0.001),
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# Train the model
# model.fit(train_images, train_labels, epochs=90, 
#           validation_data=(test_images, test_labels))

history = model.fit(train_images, train_labels, epochs=90, 
                    validation_data=(test_images, test_labels))
# Out:
# Epoch 1/90
# 1563/1563 [==============================] - 16s 8ms/step - loss: 4.2248 - accuracy: 0.0675 - val_loss: 3.7562 - val_accuracy: 0.1463
# Epoch 2/90
# 1563/1563 [==============================] - 13s 8ms/step - loss: 3.8092 - accuracy: 0.1241 - val_loss: 3.5421 - val_accuracy: 0.1875
# Epoch 3/90
# 1563/1563 [==============================] - 13s 8ms/step - loss: 3.6412 - accuracy: 0.1567 - val_loss: 3.4241 - val_accuracy: 0.2124
# Epoch 4/90
# 1563/1563 [==============================] - 13s 8ms/step - loss: 3.5193 - accuracy: 0.1775 - val_loss: 3.3331 - val_accuracy: 0.2216
# Epoch 5/90
# 1563/1563 [==============================] - 13s 8ms/step - loss: 3.4166 - accuracy: 0.1989 - val_loss: 3.2433 - val_accuracy: 0.2471
# Epoch 6/90
# 1563/1563 [==============================] - 13s 8ms/step - loss: 3.3278 - accuracy: 0.2146 - val_loss: 3.1696 - val_accuracy: 0.2602
# Epoch 7/90
# 1563/1563 [==============================] - 13s 8ms/step - loss: 3.2452 - accuracy: 0.2321 - val_loss: 3.1163 - val_accuracy: 0.2669
# Epoch 8/90
# 1563/1563 [==============================] - 13s 8ms/step - loss: 3.1676 - accuracy: 0.2480 - val_loss: 3.0240 - val_accuracy: 0.2855
# Epoch 9/90
# 1563/1563 [==============================] - 13s 8ms/step - loss: 3.0944 - accuracy: 0.2655 - val_loss: 3.0244 - val_accuracy: 0.2857
# Epoch 10/90
# 1563/1563 [==============================] - 13s 8ms/step - loss: 3.0285 - accuracy: 0.2775 - val_loss: 2.9334 - val_accuracy: 0.2989
# Epoch 11/90
# 1563/1563 [==============================] - 12s 8ms/step - loss: 2.9595 - accuracy: 0.2903 - val_loss: 2.9685 - val_accuracy: 0.2848
# Epoch 12/90
# 1563/1563 [==============================] - 12s 8ms/step - loss: 2.9016 - accuracy: 0.3027 - val_loss: 2.8662 - val_accuracy: 0.3116
# Epoch 13/90
# 1563/1563 [==============================] - 12s 8ms/step - loss: 2.8357 - accuracy: 0.3175 - val_loss: 2.8727 - val_accuracy: 0.3035
# Epoch 14/90
# 1563/1563 [==============================] - 12s 8ms/step - loss: 2.7834 - accuracy: 0.3282 - val_loss: 2.8282 - val_accuracy: 0.3140
# Epoch 15/90
# 1563/1563 [==============================] - 12s 8ms/step - loss: 2.7267 - accuracy: 0.3416 - val_loss: 2.8652 - val_accuracy: 0.3158
# Epoch 16/90
# 1563/1563 [==============================] - 13s 8ms/step - loss: 2.6727 - accuracy: 0.3499 - val_loss: 2.7486 - val_accuracy: 0.3350
# Epoch 17/90
# 1563/1563 [==============================] - 13s 8ms/step - loss: 2.6099 - accuracy: 0.3670 - val_loss: 2.9598 - val_accuracy: 0.2959
# Epoch 18/90
# 1563/1563 [==============================] - 12s 8ms/step - loss: 2.5640 - accuracy: 0.3740 - val_loss: 2.8532 - val_accuracy: 0.3085
# Epoch 19/90
# 1563/1563 [==============================] - 12s 8ms/step - loss: 2.5075 - accuracy: 0.3871 - val_loss: 2.7606 - val_accuracy: 0.3356
# Epoch 20/90
# 1563/1563 [==============================] - 12s 8ms/step - loss: 2.4465 - accuracy: 0.4048 - val_loss: 2.8430 - val_accuracy: 0.3227
# Epoch 21/90
# 1563/1563 [==============================] - 13s 8ms/step - loss: 2.3969 - accuracy: 0.4155 - val_loss: 2.8700 - val_accuracy: 0.3141
# Epoch 22/90
# 1563/1563 [==============================] - 13s 8ms/step - loss: 2.3427 - accuracy: 0.4287 - val_loss: 2.6790 - val_accuracy: 0.3548
# Epoch 23/90
# 1563/1563 [==============================] - 13s 8ms/step - loss: 2.2874 - accuracy: 0.4401 - val_loss: 2.7880 - val_accuracy: 0.3318
# Epoch 24/90
# 1563/1563 [==============================] - 13s 8ms/step - loss: 2.2261 - accuracy: 0.4542 - val_loss: 2.6566 - val_accuracy: 0.3604
# Epoch 25/90
# 1563/1563 [==============================] - 13s 8ms/step - loss: 2.1792 - accuracy: 0.4643 - val_loss: 2.8294 - val_accuracy: 0.3297
# Epoch 26/90
# 1563/1563 [==============================] - 13s 8ms/step - loss: 2.1203 - accuracy: 0.4813 - val_loss: 2.8011 - val_accuracy: 0.3373
# Epoch 27/90
# 1563/1563 [==============================] - 13s 8ms/step - loss: 2.0652 - accuracy: 0.4962 - val_loss: 2.8838 - val_accuracy: 0.3226
# Epoch 28/90
# 1563/1563 [==============================] - 13s 8ms/step - loss: 2.0035 - accuracy: 0.5088 - val_loss: 2.7575 - val_accuracy: 0.3485
# Epoch 29/90
# 1563/1563 [==============================] - 13s 8ms/step - loss: 1.9477 - accuracy: 0.5242 - val_loss: 2.7010 - val_accuracy: 0.3570
# Epoch 30/90
# 1563/1563 [==============================] - 13s 8ms/step - loss: 1.8895 - accuracy: 0.5415 - val_loss: 3.2125 - val_accuracy: 0.2781
# Epoch 31/90
# 1563/1563 [==============================] - 13s 8ms/step - loss: 1.8295 - accuracy: 0.5593 - val_loss: 2.7460 - val_accuracy: 0.3504
# Epoch 32/90
# 1563/1563 [==============================] - 13s 8ms/step - loss: 1.7758 - accuracy: 0.5725 - val_loss: 2.6940 - val_accuracy: 0.3631
# Epoch 33/90
# 1563/1563 [==============================] - 13s 8ms/step - loss: 1.7179 - accuracy: 0.5887 - val_loss: 2.7966 - val_accuracy: 0.3474
# Epoch 34/90
# 1563/1563 [==============================] - 13s 8ms/step - loss: 1.6656 - accuracy: 0.6028 - val_loss: 2.7932 - val_accuracy: 0.3554
# Epoch 35/90
# 1563/1563 [==============================] - 13s 8ms/step - loss: 1.6029 - accuracy: 0.6189 - val_loss: 3.0403 - val_accuracy: 0.3122
# Epoch 36/90
# 1563/1563 [==============================] - 13s 8ms/step - loss: 1.5493 - accuracy: 0.6363 - val_loss: 2.7916 - val_accuracy: 0.3588
# Epoch 37/90
# 1563/1563 [==============================] - 13s 8ms/step - loss: 1.4913 - accuracy: 0.6500 - val_loss: 2.7694 - val_accuracy: 0.3647
# Epoch 38/90
# 1563/1563 [==============================] - 13s 8ms/step - loss: 1.4392 - accuracy: 0.6692 - val_loss: 2.7933 - val_accuracy: 0.3588
# Epoch 39/90
# 1563/1563 [==============================] - 13s 8ms/step - loss: 1.3862 - accuracy: 0.6833 - val_loss: 2.8340 - val_accuracy: 0.3569
# Epoch 40/90
# 1563/1563 [==============================] - 13s 8ms/step - loss: 1.3323 - accuracy: 0.6994 - val_loss: 2.9174 - val_accuracy: 0.3473
# Epoch 41/90
# 1563/1563 [==============================] - 13s 8ms/step - loss: 1.2815 - accuracy: 0.7150 - val_loss: 2.8489 - val_accuracy: 0.3572
# Epoch 42/90
# 1563/1563 [==============================] - 13s 8ms/step - loss: 1.2307 - accuracy: 0.7278 - val_loss: 2.9826 - val_accuracy: 0.3385
# Epoch 43/90
# 1563/1563 [==============================] - 13s 8ms/step - loss: 1.1849 - accuracy: 0.7425 - val_loss: 2.9413 - val_accuracy: 0.3518
# Epoch 44/90
# 1563/1563 [==============================] - 13s 8ms/step - loss: 1.1483 - accuracy: 0.7520 - val_loss: 3.0225 - val_accuracy: 0.3353
# Epoch 45/90
# 1563/1563 [==============================] - 13s 8ms/step - loss: 1.0957 - accuracy: 0.7664 - val_loss: 2.9131 - val_accuracy: 0.3597
# Epoch 46/90
# 1563/1563 [==============================] - 13s 8ms/step - loss: 1.0488 - accuracy: 0.7826 - val_loss: 3.0078 - val_accuracy: 0.3409
# Epoch 47/90
# 1563/1563 [==============================] - 13s 8ms/step - loss: 0.9983 - accuracy: 0.8011 - val_loss: 3.0334 - val_accuracy: 0.3456
# Epoch 48/90
# 1563/1563 [==============================] - 13s 8ms/step - loss: 0.9628 - accuracy: 0.8061 - val_loss: 3.0192 - val_accuracy: 0.3470
# Epoch 49/90
# 1563/1563 [==============================] - 13s 8ms/step - loss: 0.9225 - accuracy: 0.8171 - val_loss: 3.0551 - val_accuracy: 0.3488
# Epoch 50/90
# 1563/1563 [==============================] - 13s 8ms/step - loss: 0.8816 - accuracy: 0.8287 - val_loss: 3.1758 - val_accuracy: 0.3343
# Epoch 51/90
# 1563/1563 [==============================] - 13s 8ms/step - loss: 0.8506 - accuracy: 0.8362 - val_loss: 3.0505 - val_accuracy: 0.3531
# Epoch 52/90
# 1563/1563 [==============================] - 13s 8ms/step - loss: 0.8200 - accuracy: 0.8443 - val_loss: 3.0818 - val_accuracy: 0.3488
# Epoch 53/90
# 1563/1563 [==============================] - 13s 8ms/step - loss: 0.7838 - accuracy: 0.8538 - val_loss: 3.1010 - val_accuracy: 0.3525
# Epoch 54/90
# 1563/1563 [==============================] - 13s 8ms/step - loss: 0.7533 - accuracy: 0.8624 - val_loss: 3.1639 - val_accuracy: 0.3452
# Epoch 55/90
# 1563/1563 [==============================] - 13s 8ms/step - loss: 0.7266 - accuracy: 0.8700 - val_loss: 3.1702 - val_accuracy: 0.3420
# Epoch 56/90
# 1563/1563 [==============================] - 13s 8ms/step - loss: 0.6941 - accuracy: 0.8772 - val_loss: 3.1846 - val_accuracy: 0.3422
# Epoch 57/90
# 1563/1563 [==============================] - 13s 8ms/step - loss: 0.6749 - accuracy: 0.8808 - val_loss: 3.1931 - val_accuracy: 0.3470
# Epoch 58/90
# 1563/1563 [==============================] - 13s 8ms/step - loss: 0.6456 - accuracy: 0.8900 - val_loss: 3.1923 - val_accuracy: 0.3495
# Epoch 59/90
# 1563/1563 [==============================] - 13s 8ms/step - loss: 0.6226 - accuracy: 0.8922 - val_loss: 3.2958 - val_accuracy: 0.3414
# Epoch 60/90
# 1563/1563 [==============================] - 13s 8ms/step - loss: 0.5992 - accuracy: 0.9003 - val_loss: 3.2338 - val_accuracy: 0.3486
# Epoch 61/90
# 1563/1563 [==============================] - 13s 8ms/step - loss: 0.5865 - accuracy: 0.9022 - val_loss: 3.2727 - val_accuracy: 0.3493
# Epoch 62/90
# 1563/1563 [==============================] - 13s 8ms/step - loss: 0.5562 - accuracy: 0.9089 - val_loss: 3.2186 - val_accuracy: 0.3533
# Epoch 63/90
# 1563/1563 [==============================] - 13s 8ms/step - loss: 0.5474 - accuracy: 0.9115 - val_loss: 3.2690 - val_accuracy: 0.3483
# Epoch 64/90
# 1563/1563 [==============================] - 13s 8ms/step - loss: 0.5249 - accuracy: 0.9171 - val_loss: 3.2837 - val_accuracy: 0.3498
# Epoch 65/90
# 1563/1563 [==============================] - 13s 8ms/step - loss: 0.5121 - accuracy: 0.9191 - val_loss: 3.3487 - val_accuracy: 0.3396
# Epoch 66/90
# 1563/1563 [==============================] - 13s 8ms/step - loss: 0.4914 - accuracy: 0.9245 - val_loss: 3.3637 - val_accuracy: 0.3414
# Epoch 67/90
# 1563/1563 [==============================] - 13s 8ms/step - loss: 0.4767 - accuracy: 0.9274 - val_loss: 3.3256 - val_accuracy: 0.3474
# Epoch 68/90
# 1563/1563 [==============================] - 13s 8ms/step - loss: 0.4678 - accuracy: 0.9287 - val_loss: 3.3946 - val_accuracy: 0.3399
# Epoch 69/90
# 1563/1563 [==============================] - 13s 8ms/step - loss: 0.4552 - accuracy: 0.9303 - val_loss: 3.4002 - val_accuracy: 0.3424
# Epoch 70/90
# 1563/1563 [==============================] - 13s 8ms/step - loss: 0.4438 - accuracy: 0.9335 - val_loss: 3.3943 - val_accuracy: 0.3435
# Epoch 71/90
# 1563/1563 [==============================] - 13s 8ms/step - loss: 0.4293 - accuracy: 0.9369 - val_loss: 3.5244 - val_accuracy: 0.3307
# Epoch 72/90
# 1563/1563 [==============================] - 13s 8ms/step - loss: 0.4214 - accuracy: 0.9388 - val_loss: 3.4232 - val_accuracy: 0.3369
# Epoch 73/90
# 1563/1563 [==============================] - 13s 8ms/step - loss: 0.4054 - accuracy: 0.9412 - val_loss: 3.4194 - val_accuracy: 0.3467
# Epoch 74/90
# 1563/1563 [==============================] - 13s 8ms/step - loss: 0.4018 - accuracy: 0.9406 - val_loss: 3.4737 - val_accuracy: 0.3459
# Epoch 75/90
# 1563/1563 [==============================] - 12s 8ms/step - loss: 0.3989 - accuracy: 0.9412 - val_loss: 3.4609 - val_accuracy: 0.3384
# Epoch 76/90
# 1563/1563 [==============================] - 13s 8ms/step - loss: 0.3806 - accuracy: 0.9454 - val_loss: 3.5093 - val_accuracy: 0.3387
# Epoch 77/90
# 1563/1563 [==============================] - 13s 8ms/step - loss: 0.3754 - accuracy: 0.9453 - val_loss: 3.5513 - val_accuracy: 0.3402
# Epoch 78/90
# 1563/1563 [==============================] - 13s 8ms/step - loss: 0.3650 - accuracy: 0.9478 - val_loss: 3.4953 - val_accuracy: 0.3421
# Epoch 79/90
# 1563/1563 [==============================] - 13s 8ms/step - loss: 0.3579 - accuracy: 0.9498 - val_loss: 3.4705 - val_accuracy: 0.3449
# Epoch 80/90
# 1563/1563 [==============================] - 13s 8ms/step - loss: 0.3516 - accuracy: 0.9501 - val_loss: 3.5054 - val_accuracy: 0.3416
# Epoch 81/90
# 1563/1563 [==============================] - 13s 8ms/step - loss: 0.3413 - accuracy: 0.9533 - val_loss: 3.4693 - val_accuracy: 0.3490
# Epoch 82/90
# 1563/1563 [==============================] - 13s 8ms/step - loss: 0.3366 - accuracy: 0.9525 - val_loss: 3.4638 - val_accuracy: 0.3502
# Epoch 83/90
# 1563/1563 [==============================] - 13s 8ms/step - loss: 0.3302 - accuracy: 0.9529 - val_loss: 3.5446 - val_accuracy: 0.3433
# Epoch 84/90
# 1563/1563 [==============================] - 12s 8ms/step - loss: 0.3292 - accuracy: 0.9547 - val_loss: 3.5270 - val_accuracy: 0.3434
# Epoch 85/90
# 1563/1563 [==============================] - 13s 8ms/step - loss: 0.3221 - accuracy: 0.9558 - val_loss: 3.5355 - val_accuracy: 0.3440
# Epoch 86/90
# 1563/1563 [==============================] - 13s 8ms/step - loss: 0.3159 - accuracy: 0.9563 - val_loss: 3.5300 - val_accuracy: 0.3406
# Epoch 87/90
# 1563/1563 [==============================] - 13s 8ms/step - loss: 0.3101 - accuracy: 0.9577 - val_loss: 3.5358 - val_accuracy: 0.3432
# Epoch 88/90
# 1563/1563 [==============================] - 13s 8ms/step - loss: 0.3062 - accuracy: 0.9586 - val_loss: 3.5390 - val_accuracy: 0.3452
# Epoch 89/90
# 1563/1563 [==============================] - 13s 8ms/step - loss: 0.2967 - accuracy: 0.9610 - val_loss: 3.5737 - val_accuracy: 0.3430
# Epoch 90/90
# 1563/1563 [==============================] - 13s 8ms/step - loss: 0.2912 - accuracy: 0.9614 - val_loss: 3.4764 - val_accuracy: 0.3525

# %%
#cifar100, dropout 0.3

accuracy = model.evaluate(test_images, test_labels, verbose=1)
print('Test loss:', accuracy[0])
print('Test accuracy:', accuracy[1])
# Out:
# 313/313 [==============================] - 1s 3ms/step - loss: 3.4764 - accuracy: 0.3525
# Test loss: 3.476379632949829
# Test accuracy: 0.35249999165534973

# %%
import matplotlib.pyplot as plt

# Plot training & validation accuracy values
plt.figure(figsize=(12, 12))

plt.subplot(2, 1, 1)
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')

# Plot training & validation loss values
plt.subplot(2, 1, 2)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')

plt.subplots_adjust(hspace=0.3)
plt.show()
