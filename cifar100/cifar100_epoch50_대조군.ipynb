# %%
from tensorflow.python.client import device_lib
print(device_lib.list_local_devices())
# Out:
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 14439905671732976628
# xla_global_id: -1
# , name: "/device:GPU:0"
# device_type: "GPU"
# memory_limit: 5748293632
# locality {
#   bus_id: 1
#   links {
#   }
# }
# incarnation: 7113967608825884174
# physical_device_desc: "device: 0, name: NVIDIA GeForce RTX 3060 Ti, pci bus id: 0000:2b:00.0, compute capability: 8.6"
# xla_global_id: 416903419
# ]

# %%
# Import necessary modules
import tensorflow as tf
from tensorflow import keras
from keras.models import Sequential
from keras.layers import Dense, Activation, Dropout, Flatten, Conv2D, MaxPooling2D, BatchNormalization
from keras.datasets import cifar100
from keras.utils import to_categorical

# Load CIFAR100 dataset
(train_images, train_labels), (test_images, test_labels) = cifar100.load_data()

# Normalize pixel values to be between 0 and 1
train_images, test_images = train_images / 255.0, test_images / 255.0

# Convert class vectors to binary class matrices
train_labels = to_categorical(train_labels, 100)
test_labels = to_categorical(test_labels, 100)

print(train_labels.shape, test_labels.shape)
# Out:
# (50000, 100) (10000, 100)

# %%
# AlexNet model architecture
model = Sequential()

# 1st Convolutional Layer
model.add(Conv2D(filters=96, input_shape=(32,32,3), kernel_size=(11,11), strides=(4,4), padding='same'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2,2), strides=(2,2), padding='same'))

# 2nd Convolutional Layer
model.add(Conv2D(filters=256, kernel_size=(5,5), strides=(1,1), padding='same'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2,2), strides=(2,2), padding='same'))

# 3rd Convolutional Layer
model.add(Conv2D(filters=384, kernel_size=(3,3), strides=(1,1), padding='same'))
model.add(BatchNormalization())
model.add(Activation('relu'))

# 4th Convolutional Layer
model.add(Conv2D(filters=384, kernel_size=(3,3), strides=(1,1), padding='same'))
model.add(BatchNormalization())
model.add(Activation('relu'))

# 5th Convolutional Layer
model.add(Conv2D(filters=256, kernel_size=(3,3), strides=(1,1), padding='same'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2,2), strides=(2,2), padding='same'))

# Fully Connected layer
model.add(Flatten())
model.add(Dense(4096, input_shape=(32,32,3,)))
model.add(BatchNormalization())
model.add(Activation('relu'))

# Add Dropout to prevent overfitting
model.add(Dropout(0.5))

# Fully Connected Layer
model.add(Dense(4096))
model.add(BatchNormalization())
model.add(Activation('relu'))
# Add Dropout
model.add(Dropout(0.5))

# Output Layer
model.add(Dense(100))  # Changed to 100 for CIFAR-100
model.add(BatchNormalization())
model.add(Activation('softmax'))

# Model Summary
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 8, 8, 96)          34944
#
#  batch_normalization (BatchN  (None, 8, 8, 96)         384
#  ormalization)
#
#  activation (Activation)     (None, 8, 8, 96)          0
#
#  max_pooling2d (MaxPooling2D  (None, 4, 4, 96)         0
#  )
#
#  conv2d_1 (Conv2D)           (None, 4, 4, 256)         614656
#
#  batch_normalization_1 (Batc  (None, 4, 4, 256)        1024
#  hNormalization)
#
#  activation_1 (Activation)   (None, 4, 4, 256)         0
#
#  max_pooling2d_1 (MaxPooling  (None, 2, 2, 256)        0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 2, 2, 384)         885120
#
#  batch_normalization_2 (Batc  (None, 2, 2, 384)        1536
#  hNormalization)
#
#  activation_2 (Activation)   (None, 2, 2, 384)         0
#
#  conv2d_3 (Conv2D)           (None, 2, 2, 384)         1327488
#
#  batch_normalization_3 (Batc  (None, 2, 2, 384)        1536
#  hNormalization)
#
#  activation_3 (Activation)   (None, 2, 2, 384)         0
#
#  conv2d_4 (Conv2D)           (None, 2, 2, 256)         884992
#
#  batch_normalization_4 (Batc  (None, 2, 2, 256)        1024
#  hNormalization)
#
#  activation_4 (Activation)   (None, 2, 2, 256)         0
#
#  max_pooling2d_2 (MaxPooling  (None, 1, 1, 256)        0
#  2D)
#
#  flatten (Flatten)           (None, 256)               0
#
#  dense (Dense)               (None, 4096)              1052672
#
#  batch_normalization_5 (Batc  (None, 4096)             16384
#  hNormalization)
#
#  activation_5 (Activation)   (None, 4096)              0
#
#  dropout (Dropout)           (None, 4096)              0
#
#  dense_1 (Dense)             (None, 4096)              16781312
#
#  batch_normalization_6 (Batc  (None, 4096)             16384
#  hNormalization)
#
#  activation_6 (Activation)   (None, 4096)              0
#
#  dropout_1 (Dropout)         (None, 4096)              0
#
#  dense_2 (Dense)             (None, 100)               409700
#
#  batch_normalization_7 (Batc  (None, 100)              400
#  hNormalization)
#
#  activation_7 (Activation)   (None, 100)               0
#
# =================================================================
# Total params: 22,029,556
# Trainable params: 22,010,220
# Non-trainable params: 19,336
# _________________________________________________________________

# %%
# Compile the model
model.compile(optimizer=tf.keras.optimizers.SGD(learning_rate=0.001),
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# Train the model
# model.fit(train_images, train_labels, epochs=90, 
#           validation_data=(test_images, test_labels))

history = model.fit(train_images, train_labels, epochs=50, 
                    validation_data=(test_images, test_labels))
# Out:
# Epoch 1/50
# 1563/1563 [==============================] - 16s 9ms/step - loss: 4.4768 - accuracy: 0.0396 - val_loss: 3.9689 - val_accuracy: 0.1126
# Epoch 2/50
# 1563/1563 [==============================] - 13s 8ms/step - loss: 4.0459 - accuracy: 0.0798 - val_loss: 3.7711 - val_accuracy: 0.1430
# Epoch 3/50
# 1563/1563 [==============================] - 13s 8ms/step - loss: 3.8725 - accuracy: 0.1080 - val_loss: 3.6363 - val_accuracy: 0.1734
# Epoch 4/50
# 1563/1563 [==============================] - 13s 8ms/step - loss: 3.7562 - accuracy: 0.1294 - val_loss: 3.5496 - val_accuracy: 0.1892
# Epoch 5/50
# 1563/1563 [==============================] - 13s 8ms/step - loss: 3.6586 - accuracy: 0.1489 - val_loss: 3.4468 - val_accuracy: 0.2124
# Epoch 6/50
# 1563/1563 [==============================] - 13s 8ms/step - loss: 3.5736 - accuracy: 0.1636 - val_loss: 3.4127 - val_accuracy: 0.2094
# Epoch 7/50
# 1563/1563 [==============================] - 14s 9ms/step - loss: 3.5027 - accuracy: 0.1784 - val_loss: 3.3929 - val_accuracy: 0.2063
# Epoch 8/50
# 1563/1563 [==============================] - 15s 9ms/step - loss: 3.4321 - accuracy: 0.1933 - val_loss: 3.3966 - val_accuracy: 0.2002
# Epoch 9/50
# 1563/1563 [==============================] - 14s 9ms/step - loss: 3.3622 - accuracy: 0.2069 - val_loss: 3.2287 - val_accuracy: 0.2483
# Epoch 10/50
# 1563/1563 [==============================] - 13s 9ms/step - loss: 3.3071 - accuracy: 0.2158 - val_loss: 3.1789 - val_accuracy: 0.2532
# Epoch 11/50
# 1563/1563 [==============================] - 14s 9ms/step - loss: 3.2455 - accuracy: 0.2287 - val_loss: 3.1386 - val_accuracy: 0.2633
# Epoch 12/50
# 1563/1563 [==============================] - 15s 9ms/step - loss: 3.1906 - accuracy: 0.2410 - val_loss: 3.4720 - val_accuracy: 0.1785
# Epoch 13/50
# 1563/1563 [==============================] - 14s 9ms/step - loss: 3.1399 - accuracy: 0.2488 - val_loss: 3.0684 - val_accuracy: 0.2669
# Epoch 14/50
# 1563/1563 [==============================] - 14s 9ms/step - loss: 3.0804 - accuracy: 0.2610 - val_loss: 2.9967 - val_accuracy: 0.2893
# Epoch 15/50
# 1563/1563 [==============================] - 13s 8ms/step - loss: 3.0308 - accuracy: 0.2729 - val_loss: 2.9681 - val_accuracy: 0.2925
# Epoch 16/50
# 1563/1563 [==============================] - 13s 9ms/step - loss: 2.9844 - accuracy: 0.2809 - val_loss: 2.9491 - val_accuracy: 0.2930
# Epoch 17/50
# 1563/1563 [==============================] - 13s 8ms/step - loss: 2.9338 - accuracy: 0.2929 - val_loss: 2.8665 - val_accuracy: 0.3090
# Epoch 18/50
# 1563/1563 [==============================] - 13s 9ms/step - loss: 2.8910 - accuracy: 0.3008 - val_loss: 2.8535 - val_accuracy: 0.3063
# Epoch 19/50
# 1563/1563 [==============================] - 13s 9ms/step - loss: 2.8401 - accuracy: 0.3111 - val_loss: 2.8604 - val_accuracy: 0.3049
# Epoch 20/50
# 1563/1563 [==============================] - 13s 8ms/step - loss: 2.7969 - accuracy: 0.3198 - val_loss: 3.0653 - val_accuracy: 0.2615
# Epoch 21/50
# 1563/1563 [==============================] - 13s 9ms/step - loss: 2.7456 - accuracy: 0.3301 - val_loss: 2.9311 - val_accuracy: 0.2902
# Epoch 22/50
# 1563/1563 [==============================] - 13s 8ms/step - loss: 2.6996 - accuracy: 0.3387 - val_loss: 2.9101 - val_accuracy: 0.2964
# Epoch 23/50
# 1563/1563 [==============================] - 13s 9ms/step - loss: 2.6584 - accuracy: 0.3491 - val_loss: 2.8052 - val_accuracy: 0.3169
# Epoch 24/50
# 1563/1563 [==============================] - 14s 9ms/step - loss: 2.6139 - accuracy: 0.3573 - val_loss: 2.8494 - val_accuracy: 0.3103
# Epoch 25/50
# 1563/1563 [==============================] - 14s 9ms/step - loss: 2.5692 - accuracy: 0.3669 - val_loss: 2.7339 - val_accuracy: 0.3295
# Epoch 26/50
# 1563/1563 [==============================] - 14s 9ms/step - loss: 2.5255 - accuracy: 0.3785 - val_loss: 2.6691 - val_accuracy: 0.3483
# Epoch 27/50
# 1563/1563 [==============================] - 13s 9ms/step - loss: 2.4727 - accuracy: 0.3910 - val_loss: 2.7485 - val_accuracy: 0.3306
# Epoch 28/50
# 1563/1563 [==============================] - 13s 9ms/step - loss: 2.4349 - accuracy: 0.3979 - val_loss: 2.8087 - val_accuracy: 0.3240
# Epoch 29/50
# 1563/1563 [==============================] - 13s 8ms/step - loss: 2.3830 - accuracy: 0.4102 - val_loss: 2.8063 - val_accuracy: 0.3229
# Epoch 30/50
# 1563/1563 [==============================] - 13s 9ms/step - loss: 2.3432 - accuracy: 0.4181 - val_loss: 2.8041 - val_accuracy: 0.3205
# Epoch 31/50
# 1563/1563 [==============================] - 13s 8ms/step - loss: 2.2909 - accuracy: 0.4322 - val_loss: 2.6730 - val_accuracy: 0.3482
# Epoch 32/50
# 1563/1563 [==============================] - 13s 8ms/step - loss: 2.2466 - accuracy: 0.4420 - val_loss: 2.7499 - val_accuracy: 0.3329
# Epoch 33/50
# 1563/1563 [==============================] - 13s 8ms/step - loss: 2.1951 - accuracy: 0.4548 - val_loss: 2.7732 - val_accuracy: 0.3328
# Epoch 34/50
# 1563/1563 [==============================] - 13s 8ms/step - loss: 2.1388 - accuracy: 0.4675 - val_loss: 2.7222 - val_accuracy: 0.3414
# Epoch 35/50
# 1563/1563 [==============================] - 13s 8ms/step - loss: 2.0932 - accuracy: 0.4797 - val_loss: 2.7555 - val_accuracy: 0.3359
# Epoch 36/50
# 1563/1563 [==============================] - 14s 9ms/step - loss: 2.0481 - accuracy: 0.4914 - val_loss: 2.6618 - val_accuracy: 0.3535
# Epoch 37/50
# 1563/1563 [==============================] - 14s 9ms/step - loss: 2.0012 - accuracy: 0.4999 - val_loss: 2.8266 - val_accuracy: 0.3258
# Epoch 38/50
# 1563/1563 [==============================] - 14s 9ms/step - loss: 1.9497 - accuracy: 0.5147 - val_loss: 2.7612 - val_accuracy: 0.3361
# Epoch 39/50
# 1563/1563 [==============================] - 13s 9ms/step - loss: 1.8984 - accuracy: 0.5317 - val_loss: 2.8716 - val_accuracy: 0.3218
# Epoch 40/50
# 1563/1563 [==============================] - 13s 8ms/step - loss: 1.8528 - accuracy: 0.5379 - val_loss: 2.8262 - val_accuracy: 0.3317
# Epoch 41/50
# 1563/1563 [==============================] - 13s 8ms/step - loss: 1.8058 - accuracy: 0.5525 - val_loss: 2.7256 - val_accuracy: 0.3535
# Epoch 42/50
# 1563/1563 [==============================] - 14s 9ms/step - loss: 1.7547 - accuracy: 0.5689 - val_loss: 2.7302 - val_accuracy: 0.3535
# Epoch 43/50
# 1563/1563 [==============================] - 15s 9ms/step - loss: 1.7089 - accuracy: 0.5775 - val_loss: 2.9297 - val_accuracy: 0.3223
# Epoch 44/50
# 1563/1563 [==============================] - 13s 9ms/step - loss: 1.6591 - accuracy: 0.5947 - val_loss: 2.9271 - val_accuracy: 0.3237
# Epoch 45/50
# 1563/1563 [==============================] - 13s 9ms/step - loss: 1.6086 - accuracy: 0.6089 - val_loss: 2.7976 - val_accuracy: 0.3476
# Epoch 46/50
# 1563/1563 [==============================] - 13s 9ms/step - loss: 1.5587 - accuracy: 0.6189 - val_loss: 2.8068 - val_accuracy: 0.3448
# Epoch 47/50
# 1563/1563 [==============================] - 13s 9ms/step - loss: 1.5156 - accuracy: 0.6318 - val_loss: 2.8366 - val_accuracy: 0.3440
# Epoch 48/50
# 1563/1563 [==============================] - 13s 8ms/step - loss: 1.4716 - accuracy: 0.6467 - val_loss: 2.9097 - val_accuracy: 0.3329
# Epoch 49/50
# 1563/1563 [==============================] - 13s 8ms/step - loss: 1.4162 - accuracy: 0.6624 - val_loss: 2.9308 - val_accuracy: 0.3299
# Epoch 50/50
# 1563/1563 [==============================] - 14s 9ms/step - loss: 1.3768 - accuracy: 0.6717 - val_loss: 2.9265 - val_accuracy: 0.3331

# %%
#cifar100, epoch50, 대조군

accuracy = model.evaluate(test_images, test_labels, verbose=1)
print('Test loss:', accuracy[0])
print('Test accuracy:', accuracy[1])
# Out:
# 313/313 [==============================] - 1s 4ms/step - loss: 2.9265 - accuracy: 0.3331
# Test loss: 2.926485538482666
# Test accuracy: 0.33309999108314514

# %%
import matplotlib.pyplot as plt

# Plot training & validation accuracy values
plt.figure(figsize=(12, 12))

plt.subplot(2, 1, 1)
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')

# Plot training & validation loss values
plt.subplot(2, 1, 2)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')

plt.subplots_adjust(hspace=0.3)
plt.show()
