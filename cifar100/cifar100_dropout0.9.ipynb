# %%
from tensorflow.python.client import device_lib
print(device_lib.list_local_devices())
# Out:
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 13694597791173671512
# xla_global_id: -1
# , name: "/device:GPU:0"
# device_type: "GPU"
# memory_limit: 5748293632
# locality {
#   bus_id: 1
#   links {
#   }
# }
# incarnation: 14043581520905063574
# physical_device_desc: "device: 0, name: NVIDIA GeForce RTX 3060 Ti, pci bus id: 0000:2b:00.0, compute capability: 8.6"
# xla_global_id: 416903419
# ]

# %%
# Import necessary modules
import tensorflow as tf
from tensorflow import keras
from keras.models import Sequential
from keras.layers import Dense, Activation, Dropout, Flatten, Conv2D, MaxPooling2D, BatchNormalization
from keras.datasets import cifar100
from keras.utils import to_categorical

# Load CIFAR100 dataset
(train_images, train_labels), (test_images, test_labels) = cifar100.load_data()

# Normalize pixel values to be between 0 and 1
train_images, test_images = train_images / 255.0, test_images / 255.0

# Convert class vectors to binary class matrices
train_labels = to_categorical(train_labels, 100)
test_labels = to_categorical(test_labels, 100)

print(train_labels.shape, test_labels.shape)
# Out:
# (50000, 100) (10000, 100)

# %%
# AlexNet model architecture
model = Sequential()

# 1st Convolutional Layer
model.add(Conv2D(filters=96, input_shape=(32,32,3), kernel_size=(11,11), strides=(4,4), padding='same'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2,2), strides=(2,2), padding='same'))

# 2nd Convolutional Layer
model.add(Conv2D(filters=256, kernel_size=(5,5), strides=(1,1), padding='same'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2,2), strides=(2,2), padding='same'))

# 3rd Convolutional Layer
model.add(Conv2D(filters=384, kernel_size=(3,3), strides=(1,1), padding='same'))
model.add(BatchNormalization())
model.add(Activation('relu'))

# 4th Convolutional Layer
model.add(Conv2D(filters=384, kernel_size=(3,3), strides=(1,1), padding='same'))
model.add(BatchNormalization())
model.add(Activation('relu'))

# 5th Convolutional Layer
model.add(Conv2D(filters=256, kernel_size=(3,3), strides=(1,1), padding='same'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2,2), strides=(2,2), padding='same'))

# Fully Connected layer
model.add(Flatten())
model.add(Dense(4096, input_shape=(32,32,3,)))
model.add(BatchNormalization())
model.add(Activation('relu'))

# Add Dropout to prevent overfitting
model.add(Dropout(0.9))

# Fully Connected Layer
model.add(Dense(4096))
model.add(BatchNormalization())
model.add(Activation('relu'))
# Add Dropout
model.add(Dropout(0.9))

# Output Layer
model.add(Dense(100))  # Changed to 100 for CIFAR-100
model.add(BatchNormalization())
model.add(Activation('softmax'))

# Model Summary
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 8, 8, 96)          34944
#
#  batch_normalization (BatchN  (None, 8, 8, 96)         384
#  ormalization)
#
#  activation (Activation)     (None, 8, 8, 96)          0
#
#  max_pooling2d (MaxPooling2D  (None, 4, 4, 96)         0
#  )
#
#  conv2d_1 (Conv2D)           (None, 4, 4, 256)         614656
#
#  batch_normalization_1 (Batc  (None, 4, 4, 256)        1024
#  hNormalization)
#
#  activation_1 (Activation)   (None, 4, 4, 256)         0
#
#  max_pooling2d_1 (MaxPooling  (None, 2, 2, 256)        0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 2, 2, 384)         885120
#
#  batch_normalization_2 (Batc  (None, 2, 2, 384)        1536
#  hNormalization)
#
#  activation_2 (Activation)   (None, 2, 2, 384)         0
#
#  conv2d_3 (Conv2D)           (None, 2, 2, 384)         1327488
#
#  batch_normalization_3 (Batc  (None, 2, 2, 384)        1536
#  hNormalization)
#
#  activation_3 (Activation)   (None, 2, 2, 384)         0
#
#  conv2d_4 (Conv2D)           (None, 2, 2, 256)         884992
#
#  batch_normalization_4 (Batc  (None, 2, 2, 256)        1024
#  hNormalization)
#
#  activation_4 (Activation)   (None, 2, 2, 256)         0
#
#  max_pooling2d_2 (MaxPooling  (None, 1, 1, 256)        0
#  2D)
#
#  flatten (Flatten)           (None, 256)               0
#
#  dense (Dense)               (None, 4096)              1052672
#
#  batch_normalization_5 (Batc  (None, 4096)             16384
#  hNormalization)
#
#  activation_5 (Activation)   (None, 4096)              0
#
#  dropout (Dropout)           (None, 4096)              0
#
#  dense_1 (Dense)             (None, 4096)              16781312
#
#  batch_normalization_6 (Batc  (None, 4096)             16384
#  hNormalization)
#
#  activation_6 (Activation)   (None, 4096)              0
#
#  dropout_1 (Dropout)         (None, 4096)              0
#
#  dense_2 (Dense)             (None, 100)               409700
#
#  batch_normalization_7 (Batc  (None, 100)              400
#  hNormalization)
#
#  activation_7 (Activation)   (None, 100)               0
#
# =================================================================
# Total params: 22,029,556
# Trainable params: 22,010,220
# Non-trainable params: 19,336
# _________________________________________________________________

# %%
# Compile the model
model.compile(optimizer=tf.keras.optimizers.SGD(learning_rate=0.001),
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# Train the model
# model.fit(train_images, train_labels, epochs=90, 
#           validation_data=(test_images, test_labels))

history = model.fit(train_images, train_labels, epochs=90, 
                    validation_data=(test_images, test_labels))
# Out:
# Epoch 1/90
# 1563/1563 [==============================] - 18s 10ms/step - loss: 5.0365 - accuracy: 0.0116 - val_loss: 4.5416 - val_accuracy: 0.0263
# Epoch 2/90
# 1563/1563 [==============================] - 14s 9ms/step - loss: 4.9313 - accuracy: 0.0132 - val_loss: 4.4984 - val_accuracy: 0.0351
# Epoch 3/90
# 1563/1563 [==============================] - 13s 9ms/step - loss: 4.8479 - accuracy: 0.0149 - val_loss: 4.4666 - val_accuracy: 0.0463
# Epoch 4/90
# 1563/1563 [==============================] - 14s 9ms/step - loss: 4.7640 - accuracy: 0.0166 - val_loss: 4.4248 - val_accuracy: 0.0491
# Epoch 5/90
# 1563/1563 [==============================] - 15s 9ms/step - loss: 4.6986 - accuracy: 0.0180 - val_loss: 4.4047 - val_accuracy: 0.0541
# Epoch 6/90
# 1563/1563 [==============================] - 14s 9ms/step - loss: 4.6356 - accuracy: 0.0210 - val_loss: 4.4119 - val_accuracy: 0.0567
# Epoch 7/90
# 1563/1563 [==============================] - 15s 10ms/step - loss: 4.5951 - accuracy: 0.0220 - val_loss: 4.3548 - val_accuracy: 0.0602
# Epoch 8/90
# 1563/1563 [==============================] - 13s 8ms/step - loss: 4.5432 - accuracy: 0.0254 - val_loss: 4.3527 - val_accuracy: 0.0613
# Epoch 9/90
# 1563/1563 [==============================] - 13s 8ms/step - loss: 4.5070 - accuracy: 0.0275 - val_loss: 4.3357 - val_accuracy: 0.0654
# Epoch 10/90
# 1563/1563 [==============================] - 13s 8ms/step - loss: 4.4707 - accuracy: 0.0296 - val_loss: 4.2945 - val_accuracy: 0.0703
# Epoch 11/90
# 1563/1563 [==============================] - 13s 8ms/step - loss: 4.4327 - accuracy: 0.0324 - val_loss: 4.3064 - val_accuracy: 0.0676
# Epoch 12/90
# 1563/1563 [==============================] - 13s 8ms/step - loss: 4.3997 - accuracy: 0.0334 - val_loss: 4.2164 - val_accuracy: 0.0823
# Epoch 13/90
# 1563/1563 [==============================] - 13s 8ms/step - loss: 4.3675 - accuracy: 0.0367 - val_loss: 4.1928 - val_accuracy: 0.0849
# Epoch 14/90
# 1563/1563 [==============================] - 13s 8ms/step - loss: 4.3394 - accuracy: 0.0390 - val_loss: 4.1855 - val_accuracy: 0.0855
# Epoch 15/90
# 1563/1563 [==============================] - 12s 8ms/step - loss: 4.3127 - accuracy: 0.0393 - val_loss: 4.1550 - val_accuracy: 0.0886
# Epoch 16/90
# 1563/1563 [==============================] - 13s 8ms/step - loss: 4.2912 - accuracy: 0.0409 - val_loss: 4.1674 - val_accuracy: 0.0917
# Epoch 17/90
# 1563/1563 [==============================] - 13s 8ms/step - loss: 4.2645 - accuracy: 0.0436 - val_loss: 4.1309 - val_accuracy: 0.0940
# Epoch 18/90
# 1563/1563 [==============================] - 12s 8ms/step - loss: 4.2489 - accuracy: 0.0464 - val_loss: 4.1394 - val_accuracy: 0.0909
# Epoch 19/90
# 1563/1563 [==============================] - 13s 8ms/step - loss: 4.2265 - accuracy: 0.0474 - val_loss: 4.0962 - val_accuracy: 0.0973
# Epoch 20/90
# 1563/1563 [==============================] - 13s 8ms/step - loss: 4.2023 - accuracy: 0.0497 - val_loss: 4.0738 - val_accuracy: 0.0993
# Epoch 21/90
# 1563/1563 [==============================] - 13s 9ms/step - loss: 4.1816 - accuracy: 0.0530 - val_loss: 4.1165 - val_accuracy: 0.0932
# Epoch 22/90
# 1563/1563 [==============================] - 13s 8ms/step - loss: 4.1588 - accuracy: 0.0559 - val_loss: 4.1012 - val_accuracy: 0.0974
# Epoch 23/90
# 1563/1563 [==============================] - 13s 8ms/step - loss: 4.1442 - accuracy: 0.0554 - val_loss: 4.0516 - val_accuracy: 0.1004
# Epoch 24/90
# 1563/1563 [==============================] - 13s 8ms/step - loss: 4.1217 - accuracy: 0.0578 - val_loss: 4.0000 - val_accuracy: 0.1119
# Epoch 25/90
# 1563/1563 [==============================] - 13s 8ms/step - loss: 4.1063 - accuracy: 0.0613 - val_loss: 3.9771 - val_accuracy: 0.1127
# Epoch 26/90
# 1563/1563 [==============================] - 13s 8ms/step - loss: 4.0871 - accuracy: 0.0617 - val_loss: 4.0034 - val_accuracy: 0.1088
# Epoch 27/90
# 1563/1563 [==============================] - 13s 8ms/step - loss: 4.0688 - accuracy: 0.0620 - val_loss: 4.0532 - val_accuracy: 0.1015
# Epoch 28/90
# 1563/1563 [==============================] - 13s 8ms/step - loss: 4.0500 - accuracy: 0.0656 - val_loss: 4.0452 - val_accuracy: 0.1000
# Epoch 29/90
# 1563/1563 [==============================] - 13s 8ms/step - loss: 4.0353 - accuracy: 0.0663 - val_loss: 3.9489 - val_accuracy: 0.1200
# Epoch 30/90
# 1563/1563 [==============================] - 13s 8ms/step - loss: 4.0163 - accuracy: 0.0698 - val_loss: 3.9925 - val_accuracy: 0.1125
# Epoch 31/90
# 1563/1563 [==============================] - 13s 9ms/step - loss: 3.9978 - accuracy: 0.0708 - val_loss: 3.9721 - val_accuracy: 0.1112
# Epoch 32/90
# 1563/1563 [==============================] - 14s 9ms/step - loss: 3.9883 - accuracy: 0.0716 - val_loss: 3.9433 - val_accuracy: 0.1207
# Epoch 33/90
# 1563/1563 [==============================] - 13s 9ms/step - loss: 3.9697 - accuracy: 0.0728 - val_loss: 3.8759 - val_accuracy: 0.1290
# Epoch 34/90
# 1563/1563 [==============================] - 14s 9ms/step - loss: 3.9505 - accuracy: 0.0752 - val_loss: 3.9065 - val_accuracy: 0.1228
# Epoch 35/90
# 1563/1563 [==============================] - 14s 9ms/step - loss: 3.9350 - accuracy: 0.0776 - val_loss: 3.8967 - val_accuracy: 0.1313
# Epoch 36/90
# 1563/1563 [==============================] - 13s 8ms/step - loss: 3.9136 - accuracy: 0.0806 - val_loss: 3.8796 - val_accuracy: 0.1329
# Epoch 37/90
# 1563/1563 [==============================] - 13s 8ms/step - loss: 3.9006 - accuracy: 0.0823 - val_loss: 3.9165 - val_accuracy: 0.1292
# Epoch 38/90
# 1563/1563 [==============================] - 13s 8ms/step - loss: 3.8849 - accuracy: 0.0859 - val_loss: 3.8343 - val_accuracy: 0.1403
# Epoch 39/90
# 1563/1563 [==============================] - 13s 8ms/step - loss: 3.8718 - accuracy: 0.0849 - val_loss: 3.9982 - val_accuracy: 0.1003
# Epoch 40/90
# 1563/1563 [==============================] - 13s 8ms/step - loss: 3.8538 - accuracy: 0.0861 - val_loss: 3.7892 - val_accuracy: 0.1399
# Epoch 41/90
# 1563/1563 [==============================] - 13s 8ms/step - loss: 3.8441 - accuracy: 0.0867 - val_loss: 3.7948 - val_accuracy: 0.1507
# Epoch 42/90
# 1563/1563 [==============================] - 13s 8ms/step - loss: 3.8204 - accuracy: 0.0925 - val_loss: 3.8356 - val_accuracy: 0.1381
# Epoch 43/90
# 1563/1563 [==============================] - 13s 8ms/step - loss: 3.8098 - accuracy: 0.0929 - val_loss: 3.8440 - val_accuracy: 0.1342
# Epoch 44/90
# 1563/1563 [==============================] - 13s 8ms/step - loss: 3.7925 - accuracy: 0.0946 - val_loss: 3.7254 - val_accuracy: 0.1513
# Epoch 45/90
# 1563/1563 [==============================] - 13s 9ms/step - loss: 3.7767 - accuracy: 0.0963 - val_loss: 3.8476 - val_accuracy: 0.1307
# Epoch 46/90
# 1563/1563 [==============================] - 13s 9ms/step - loss: 3.7588 - accuracy: 0.1017 - val_loss: 3.9723 - val_accuracy: 0.1073
# Epoch 47/90
# 1563/1563 [==============================] - 13s 9ms/step - loss: 3.7402 - accuracy: 0.1029 - val_loss: 3.7601 - val_accuracy: 0.1549
# Epoch 48/90
# 1563/1563 [==============================] - 13s 8ms/step - loss: 3.7270 - accuracy: 0.1011 - val_loss: 3.7657 - val_accuracy: 0.1478
# Epoch 49/90
# 1563/1563 [==============================] - 13s 8ms/step - loss: 3.7067 - accuracy: 0.1060 - val_loss: 3.7127 - val_accuracy: 0.1527
# Epoch 50/90
# 1563/1563 [==============================] - 13s 8ms/step - loss: 3.6915 - accuracy: 0.1081 - val_loss: 3.6953 - val_accuracy: 0.1640
# Epoch 51/90
# 1563/1563 [==============================] - 13s 8ms/step - loss: 3.6750 - accuracy: 0.1100 - val_loss: 3.7073 - val_accuracy: 0.1458
# Epoch 52/90
# 1563/1563 [==============================] - 13s 8ms/step - loss: 3.6584 - accuracy: 0.1128 - val_loss: 3.6838 - val_accuracy: 0.1523
# Epoch 53/90
# 1563/1563 [==============================] - 13s 9ms/step - loss: 3.6443 - accuracy: 0.1144 - val_loss: 3.8211 - val_accuracy: 0.1368
# Epoch 54/90
# 1563/1563 [==============================] - 14s 9ms/step - loss: 3.6282 - accuracy: 0.1157 - val_loss: 3.6739 - val_accuracy: 0.1688
# Epoch 55/90
# 1563/1563 [==============================] - 13s 8ms/step - loss: 3.6091 - accuracy: 0.1183 - val_loss: 3.7328 - val_accuracy: 0.1500
# Epoch 56/90
# 1563/1563 [==============================] - 13s 8ms/step - loss: 3.5956 - accuracy: 0.1195 - val_loss: 3.6863 - val_accuracy: 0.1598
# Epoch 57/90
# 1563/1563 [==============================] - 13s 8ms/step - loss: 3.5814 - accuracy: 0.1222 - val_loss: 3.6009 - val_accuracy: 0.1670
# Epoch 58/90
# 1563/1563 [==============================] - 13s 8ms/step - loss: 3.5653 - accuracy: 0.1218 - val_loss: 3.6968 - val_accuracy: 0.1623
# Epoch 59/90
# 1563/1563 [==============================] - 13s 9ms/step - loss: 3.5450 - accuracy: 0.1263 - val_loss: 3.6525 - val_accuracy: 0.1634
# Epoch 60/90
# 1563/1563 [==============================] - 14s 9ms/step - loss: 3.5283 - accuracy: 0.1301 - val_loss: 3.7223 - val_accuracy: 0.1502
# Epoch 61/90
# 1563/1563 [==============================] - 14s 9ms/step - loss: 3.5091 - accuracy: 0.1327 - val_loss: 3.6028 - val_accuracy: 0.1758
# Epoch 62/90
# 1563/1563 [==============================] - 14s 9ms/step - loss: 3.4895 - accuracy: 0.1370 - val_loss: 3.5831 - val_accuracy: 0.1764
# Epoch 63/90
# 1563/1563 [==============================] - 13s 8ms/step - loss: 3.4739 - accuracy: 0.1361 - val_loss: 3.6455 - val_accuracy: 0.1613
# Epoch 64/90
# 1563/1563 [==============================] - 13s 8ms/step - loss: 3.4598 - accuracy: 0.1379 - val_loss: 3.5717 - val_accuracy: 0.1766
# Epoch 65/90
# 1563/1563 [==============================] - 13s 8ms/step - loss: 3.4432 - accuracy: 0.1404 - val_loss: 3.7015 - val_accuracy: 0.1552
# Epoch 66/90
# 1563/1563 [==============================] - 13s 8ms/step - loss: 3.4245 - accuracy: 0.1449 - val_loss: 3.4917 - val_accuracy: 0.1906
# Epoch 67/90
# 1563/1563 [==============================] - 13s 9ms/step - loss: 3.4069 - accuracy: 0.1442 - val_loss: 3.6156 - val_accuracy: 0.1733
# Epoch 68/90
# 1563/1563 [==============================] - 13s 8ms/step - loss: 3.3865 - accuracy: 0.1506 - val_loss: 3.5335 - val_accuracy: 0.1853
# Epoch 69/90
# 1563/1563 [==============================] - 13s 8ms/step - loss: 3.3753 - accuracy: 0.1501 - val_loss: 3.5456 - val_accuracy: 0.1785
# Epoch 70/90
# 1563/1563 [==============================] - 13s 8ms/step - loss: 3.3543 - accuracy: 0.1545 - val_loss: 3.5906 - val_accuracy: 0.1676
# Epoch 71/90
# 1563/1563 [==============================] - 13s 8ms/step - loss: 3.3384 - accuracy: 0.1548 - val_loss: 3.4741 - val_accuracy: 0.1934
# Epoch 72/90
# 1563/1563 [==============================] - 13s 9ms/step - loss: 3.3181 - accuracy: 0.1597 - val_loss: 3.5484 - val_accuracy: 0.1768
# Epoch 73/90
# 1563/1563 [==============================] - 14s 9ms/step - loss: 3.3029 - accuracy: 0.1628 - val_loss: 3.6176 - val_accuracy: 0.1687
# Epoch 74/90
# 1563/1563 [==============================] - 13s 9ms/step - loss: 3.2807 - accuracy: 0.1662 - val_loss: 3.6624 - val_accuracy: 0.1604
# Epoch 75/90
# 1563/1563 [==============================] - 13s 8ms/step - loss: 3.2643 - accuracy: 0.1686 - val_loss: 3.5311 - val_accuracy: 0.1894
# Epoch 76/90
# 1563/1563 [==============================] - 13s 8ms/step - loss: 3.2482 - accuracy: 0.1679 - val_loss: 3.5896 - val_accuracy: 0.1727
# Epoch 77/90
# 1563/1563 [==============================] - 13s 8ms/step - loss: 3.2278 - accuracy: 0.1744 - val_loss: 3.5342 - val_accuracy: 0.1812
# Epoch 78/90
# 1563/1563 [==============================] - 13s 8ms/step - loss: 3.2111 - accuracy: 0.1762 - val_loss: 3.5673 - val_accuracy: 0.1670
# Epoch 79/90
# 1563/1563 [==============================] - 13s 8ms/step - loss: 3.1933 - accuracy: 0.1796 - val_loss: 3.4910 - val_accuracy: 0.1785
# Epoch 80/90
# 1563/1563 [==============================] - 13s 8ms/step - loss: 3.1762 - accuracy: 0.1818 - val_loss: 3.5787 - val_accuracy: 0.1749
# Epoch 81/90
# 1563/1563 [==============================] - 13s 8ms/step - loss: 3.1641 - accuracy: 0.1832 - val_loss: 3.5981 - val_accuracy: 0.1751
# Epoch 82/90
# 1563/1563 [==============================] - 13s 8ms/step - loss: 3.1441 - accuracy: 0.1858 - val_loss: 3.5483 - val_accuracy: 0.1814
# Epoch 83/90
# 1563/1563 [==============================] - 13s 8ms/step - loss: 3.1240 - accuracy: 0.1892 - val_loss: 3.5823 - val_accuracy: 0.1802
# Epoch 84/90
# 1563/1563 [==============================] - 13s 8ms/step - loss: 3.1058 - accuracy: 0.1943 - val_loss: 3.4933 - val_accuracy: 0.1914
# Epoch 85/90
# 1563/1563 [==============================] - 13s 9ms/step - loss: 3.0845 - accuracy: 0.1979 - val_loss: 3.4356 - val_accuracy: 0.2011
# Epoch 86/90
# 1563/1563 [==============================] - 13s 9ms/step - loss: 3.0733 - accuracy: 0.1988 - val_loss: 3.4653 - val_accuracy: 0.1969
# Epoch 87/90
# 1563/1563 [==============================] - 13s 9ms/step - loss: 3.0543 - accuracy: 0.2018 - val_loss: 3.5854 - val_accuracy: 0.1771
# Epoch 88/90
# 1563/1563 [==============================] - 13s 9ms/step - loss: 3.0353 - accuracy: 0.2081 - val_loss: 3.4446 - val_accuracy: 0.1919
# Epoch 89/90
# 1563/1563 [==============================] - 13s 8ms/step - loss: 3.0136 - accuracy: 0.2098 - val_loss: 3.5421 - val_accuracy: 0.1922
# Epoch 90/90
# 1563/1563 [==============================] - 13s 9ms/step - loss: 3.0005 - accuracy: 0.2106 - val_loss: 3.3496 - val_accuracy: 0.2128

# %%
#cifar100, dropout 0.9

accuracy = model.evaluate(test_images, test_labels, verbose=1)
print('Test loss:', accuracy[0])
print('Test accuracy:', accuracy[1])
# Out:
# 313/313 [==============================] - 1s 3ms/step - loss: 3.3496 - accuracy: 0.2128
# Test loss: 3.3496437072753906
# Test accuracy: 0.21279999613761902

# %%
import matplotlib.pyplot as plt

# Plot training & validation accuracy values
plt.figure(figsize=(12, 12))

plt.subplot(2, 1, 1)
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')

# Plot training & validation loss values
plt.subplot(2, 1, 2)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')

plt.subplots_adjust(hspace=0.3)
plt.show()
