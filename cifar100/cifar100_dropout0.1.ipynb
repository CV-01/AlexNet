# %%
from tensorflow.python.client import device_lib
print(device_lib.list_local_devices())
# Out:
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 952599942955326784
# xla_global_id: -1
# , name: "/device:GPU:0"
# device_type: "GPU"
# memory_limit: 5748293632
# locality {
#   bus_id: 1
#   links {
#   }
# }
# incarnation: 6165425194360343140
# physical_device_desc: "device: 0, name: NVIDIA GeForce RTX 3060 Ti, pci bus id: 0000:2b:00.0, compute capability: 8.6"
# xla_global_id: 416903419
# ]

# %%
# Import necessary modules
import tensorflow as tf
from tensorflow import keras
from keras.models import Sequential
from keras.layers import Dense, Activation, Dropout, Flatten, Conv2D, MaxPooling2D, BatchNormalization
from keras.datasets import cifar100
from keras.utils import to_categorical

# Load CIFAR100 dataset
(train_images, train_labels), (test_images, test_labels) = cifar100.load_data()

# Normalize pixel values to be between 0 and 1
train_images, test_images = train_images / 255.0, test_images / 255.0

# Convert class vectors to binary class matrices
train_labels = to_categorical(train_labels, 100)
test_labels = to_categorical(test_labels, 100)

print(train_labels.shape, test_labels.shape)
# Out:
# (50000, 100) (10000, 100)

# %%
# AlexNet model architecture
model = Sequential()

# 1st Convolutional Layer
model.add(Conv2D(filters=96, input_shape=(32,32,3), kernel_size=(11,11), strides=(4,4), padding='same'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2,2), strides=(2,2), padding='same'))

# 2nd Convolutional Layer
model.add(Conv2D(filters=256, kernel_size=(5,5), strides=(1,1), padding='same'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2,2), strides=(2,2), padding='same'))

# 3rd Convolutional Layer
model.add(Conv2D(filters=384, kernel_size=(3,3), strides=(1,1), padding='same'))
model.add(BatchNormalization())
model.add(Activation('relu'))

# 4th Convolutional Layer
model.add(Conv2D(filters=384, kernel_size=(3,3), strides=(1,1), padding='same'))
model.add(BatchNormalization())
model.add(Activation('relu'))

# 5th Convolutional Layer
model.add(Conv2D(filters=256, kernel_size=(3,3), strides=(1,1), padding='same'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2,2), strides=(2,2), padding='same'))

# Fully Connected layer
model.add(Flatten())
model.add(Dense(4096, input_shape=(32,32,3,)))
model.add(BatchNormalization())
model.add(Activation('relu'))

# Add Dropout to prevent overfitting
model.add(Dropout(0.1))

# Fully Connected Layer
model.add(Dense(4096))
model.add(BatchNormalization())
model.add(Activation('relu'))
# Add Dropout
model.add(Dropout(0.1))

# Output Layer
model.add(Dense(100))  # Changed to 100 for CIFAR-100
model.add(BatchNormalization())
model.add(Activation('softmax'))

# Model Summary
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 8, 8, 96)          34944
#
#  batch_normalization (BatchN  (None, 8, 8, 96)         384
#  ormalization)
#
#  activation (Activation)     (None, 8, 8, 96)          0
#
#  max_pooling2d (MaxPooling2D  (None, 4, 4, 96)         0
#  )
#
#  conv2d_1 (Conv2D)           (None, 4, 4, 256)         614656
#
#  batch_normalization_1 (Batc  (None, 4, 4, 256)        1024
#  hNormalization)
#
#  activation_1 (Activation)   (None, 4, 4, 256)         0
#
#  max_pooling2d_1 (MaxPooling  (None, 2, 2, 256)        0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 2, 2, 384)         885120
#
#  batch_normalization_2 (Batc  (None, 2, 2, 384)        1536
#  hNormalization)
#
#  activation_2 (Activation)   (None, 2, 2, 384)         0
#
#  conv2d_3 (Conv2D)           (None, 2, 2, 384)         1327488
#
#  batch_normalization_3 (Batc  (None, 2, 2, 384)        1536
#  hNormalization)
#
#  activation_3 (Activation)   (None, 2, 2, 384)         0
#
#  conv2d_4 (Conv2D)           (None, 2, 2, 256)         884992
#
#  batch_normalization_4 (Batc  (None, 2, 2, 256)        1024
#  hNormalization)
#
#  activation_4 (Activation)   (None, 2, 2, 256)         0
#
#  max_pooling2d_2 (MaxPooling  (None, 1, 1, 256)        0
#  2D)
#
#  flatten (Flatten)           (None, 256)               0
#
#  dense (Dense)               (None, 4096)              1052672
#
#  batch_normalization_5 (Batc  (None, 4096)             16384
#  hNormalization)
#
#  activation_5 (Activation)   (None, 4096)              0
#
#  dropout (Dropout)           (None, 4096)              0
#
#  dense_1 (Dense)             (None, 4096)              16781312
#
#  batch_normalization_6 (Batc  (None, 4096)             16384
#  hNormalization)
#
#  activation_6 (Activation)   (None, 4096)              0
#
#  dropout_1 (Dropout)         (None, 4096)              0
#
#  dense_2 (Dense)             (None, 100)               409700
#
#  batch_normalization_7 (Batc  (None, 100)              400
#  hNormalization)
#
#  activation_7 (Activation)   (None, 100)               0
#
# =================================================================
# Total params: 22,029,556
# Trainable params: 22,010,220
# Non-trainable params: 19,336
# _________________________________________________________________

# %%
# Compile the model
model.compile(optimizer=tf.keras.optimizers.SGD(learning_rate=0.001),
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# Train the model
# model.fit(train_images, train_labels, epochs=90, 
#           validation_data=(test_images, test_labels))

history = model.fit(train_images, train_labels, epochs=90, 
                    validation_data=(test_images, test_labels))
# Out:
# Epoch 1/90
# 1563/1563 [==============================] - 16s 9ms/step - loss: 4.0316 - accuracy: 0.0943 - val_loss: 3.6509 - val_accuracy: 0.1689
# Epoch 2/90
# 1563/1563 [==============================] - 13s 8ms/step - loss: 3.6198 - accuracy: 0.1587 - val_loss: 3.4611 - val_accuracy: 0.1996
# Epoch 3/90
# 1563/1563 [==============================] - 13s 9ms/step - loss: 3.4295 - accuracy: 0.1990 - val_loss: 3.3196 - val_accuracy: 0.2335
# Epoch 4/90
# 1563/1563 [==============================] - 14s 9ms/step - loss: 3.2981 - accuracy: 0.2234 - val_loss: 3.1690 - val_accuracy: 0.2589
# Epoch 5/90
# 1563/1563 [==============================] - 14s 9ms/step - loss: 3.1751 - accuracy: 0.2487 - val_loss: 3.0978 - val_accuracy: 0.2722
# Epoch 6/90
# 1563/1563 [==============================] - 14s 9ms/step - loss: 3.0723 - accuracy: 0.2696 - val_loss: 3.0758 - val_accuracy: 0.2763
# Epoch 7/90
# 1563/1563 [==============================] - 14s 9ms/step - loss: 2.9698 - accuracy: 0.2908 - val_loss: 2.9685 - val_accuracy: 0.2956
# Epoch 8/90
# 1563/1563 [==============================] - 14s 9ms/step - loss: 2.8893 - accuracy: 0.3084 - val_loss: 2.9647 - val_accuracy: 0.3004
# Epoch 9/90
# 1563/1563 [==============================] - 14s 9ms/step - loss: 2.8035 - accuracy: 0.3267 - val_loss: 3.1035 - val_accuracy: 0.2758
# Epoch 10/90
# 1563/1563 [==============================] - 14s 9ms/step - loss: 2.7300 - accuracy: 0.3408 - val_loss: 3.0103 - val_accuracy: 0.2855
# Epoch 11/90
# 1563/1563 [==============================] - 13s 9ms/step - loss: 2.6561 - accuracy: 0.3597 - val_loss: 2.9975 - val_accuracy: 0.2913
# Epoch 12/90
# 1563/1563 [==============================] - 13s 8ms/step - loss: 2.5861 - accuracy: 0.3734 - val_loss: 2.9493 - val_accuracy: 0.3043
# Epoch 13/90
# 1563/1563 [==============================] - 13s 8ms/step - loss: 2.5147 - accuracy: 0.3925 - val_loss: 2.7972 - val_accuracy: 0.3304
# Epoch 14/90
# 1563/1563 [==============================] - 13s 8ms/step - loss: 2.4384 - accuracy: 0.4077 - val_loss: 2.9032 - val_accuracy: 0.3150
# Epoch 15/90
# 1563/1563 [==============================] - 13s 8ms/step - loss: 2.3720 - accuracy: 0.4266 - val_loss: 2.7280 - val_accuracy: 0.3509
# Epoch 16/90
# 1563/1563 [==============================] - 13s 8ms/step - loss: 2.2981 - accuracy: 0.4449 - val_loss: 2.8156 - val_accuracy: 0.3355
# Epoch 17/90
# 1563/1563 [==============================] - 14s 9ms/step - loss: 2.2319 - accuracy: 0.4606 - val_loss: 2.9094 - val_accuracy: 0.3165
# Epoch 18/90
# 1563/1563 [==============================] - 14s 9ms/step - loss: 2.1696 - accuracy: 0.4772 - val_loss: 2.8094 - val_accuracy: 0.3368
# Epoch 19/90
# 1563/1563 [==============================] - 14s 9ms/step - loss: 2.0980 - accuracy: 0.4956 - val_loss: 2.8297 - val_accuracy: 0.3363
# Epoch 20/90
# 1563/1563 [==============================] - 14s 9ms/step - loss: 2.0252 - accuracy: 0.5169 - val_loss: 2.8439 - val_accuracy: 0.3407
# Epoch 21/90
# 1563/1563 [==============================] - 14s 9ms/step - loss: 1.9624 - accuracy: 0.5316 - val_loss: 2.7824 - val_accuracy: 0.3510
# Epoch 22/90
# 1563/1563 [==============================] - 14s 9ms/step - loss: 1.8895 - accuracy: 0.5512 - val_loss: 2.7671 - val_accuracy: 0.3563
# Epoch 23/90
# 1563/1563 [==============================] - 14s 9ms/step - loss: 1.8288 - accuracy: 0.5699 - val_loss: 2.7614 - val_accuracy: 0.3556
# Epoch 24/90
# 1563/1563 [==============================] - 13s 8ms/step - loss: 1.7678 - accuracy: 0.5885 - val_loss: 2.9435 - val_accuracy: 0.3306
# Epoch 25/90
# 1563/1563 [==============================] - 13s 8ms/step - loss: 1.7007 - accuracy: 0.6085 - val_loss: 3.0977 - val_accuracy: 0.3231
# Epoch 26/90
# 1563/1563 [==============================] - 13s 8ms/step - loss: 1.6300 - accuracy: 0.6251 - val_loss: 2.8374 - val_accuracy: 0.3520
# Epoch 27/90
# 1563/1563 [==============================] - 13s 8ms/step - loss: 1.5667 - accuracy: 0.6451 - val_loss: 2.8043 - val_accuracy: 0.3653
# Epoch 28/90
# 1563/1563 [==============================] - 13s 8ms/step - loss: 1.5076 - accuracy: 0.6608 - val_loss: 2.8571 - val_accuracy: 0.3544
# Epoch 29/90
# 1563/1563 [==============================] - 13s 8ms/step - loss: 1.4510 - accuracy: 0.6829 - val_loss: 2.9036 - val_accuracy: 0.3498
# Epoch 30/90
# 1563/1563 [==============================] - 13s 8ms/step - loss: 1.3915 - accuracy: 0.6968 - val_loss: 2.9752 - val_accuracy: 0.3423
# Epoch 31/90
# 1563/1563 [==============================] - 13s 8ms/step - loss: 1.3226 - accuracy: 0.7201 - val_loss: 2.9533 - val_accuracy: 0.3480
# Epoch 32/90
# 1563/1563 [==============================] - 13s 8ms/step - loss: 1.2748 - accuracy: 0.7313 - val_loss: 2.9485 - val_accuracy: 0.3453
# Epoch 33/90
# 1563/1563 [==============================] - 13s 9ms/step - loss: 1.2205 - accuracy: 0.7483 - val_loss: 2.9537 - val_accuracy: 0.3546
# Epoch 34/90
# 1563/1563 [==============================] - 13s 9ms/step - loss: 1.1652 - accuracy: 0.7645 - val_loss: 2.9713 - val_accuracy: 0.3483
# Epoch 35/90
# 1563/1563 [==============================] - 13s 8ms/step - loss: 1.1218 - accuracy: 0.7771 - val_loss: 2.9737 - val_accuracy: 0.3542
# Epoch 36/90
# 1563/1563 [==============================] - 14s 9ms/step - loss: 1.0657 - accuracy: 0.7927 - val_loss: 3.0863 - val_accuracy: 0.3399
# Epoch 37/90
# 1563/1563 [==============================] - 13s 8ms/step - loss: 1.0229 - accuracy: 0.8062 - val_loss: 3.1020 - val_accuracy: 0.3353
# Epoch 38/90
# 1563/1563 [==============================] - 13s 8ms/step - loss: 0.9764 - accuracy: 0.8184 - val_loss: 3.0567 - val_accuracy: 0.3496
# Epoch 39/90
# 1563/1563 [==============================] - 13s 8ms/step - loss: 0.9377 - accuracy: 0.8264 - val_loss: 3.1159 - val_accuracy: 0.3440
# Epoch 40/90
# 1563/1563 [==============================] - 13s 8ms/step - loss: 0.8948 - accuracy: 0.8391 - val_loss: 3.0895 - val_accuracy: 0.3520
# Epoch 41/90
# 1563/1563 [==============================] - 14s 9ms/step - loss: 0.8620 - accuracy: 0.8473 - val_loss: 3.0921 - val_accuracy: 0.3500
# Epoch 42/90
# 1563/1563 [==============================] - 13s 9ms/step - loss: 0.8192 - accuracy: 0.8562 - val_loss: 3.2576 - val_accuracy: 0.3258
# Epoch 43/90
# 1563/1563 [==============================] - 14s 9ms/step - loss: 0.7844 - accuracy: 0.8679 - val_loss: 3.1289 - val_accuracy: 0.3525
# Epoch 44/90
# 1563/1563 [==============================] - 14s 9ms/step - loss: 0.7553 - accuracy: 0.8737 - val_loss: 3.1214 - val_accuracy: 0.3523
# Epoch 45/90
# 1563/1563 [==============================] - 13s 8ms/step - loss: 0.7256 - accuracy: 0.8806 - val_loss: 3.2884 - val_accuracy: 0.3341
# Epoch 46/90
# 1563/1563 [==============================] - 13s 8ms/step - loss: 0.6914 - accuracy: 0.8907 - val_loss: 3.1935 - val_accuracy: 0.3497
# Epoch 47/90
# 1563/1563 [==============================] - 13s 8ms/step - loss: 0.6690 - accuracy: 0.8947 - val_loss: 3.2069 - val_accuracy: 0.3482
# Epoch 48/90
# 1563/1563 [==============================] - 13s 9ms/step - loss: 0.6439 - accuracy: 0.9010 - val_loss: 3.2086 - val_accuracy: 0.3481
# Epoch 49/90
# 1563/1563 [==============================] - 13s 9ms/step - loss: 0.6145 - accuracy: 0.9093 - val_loss: 3.2586 - val_accuracy: 0.3485
# Epoch 50/90
# 1563/1563 [==============================] - 13s 9ms/step - loss: 0.5931 - accuracy: 0.9122 - val_loss: 3.2874 - val_accuracy: 0.3423
# Epoch 51/90
# 1563/1563 [==============================] - 13s 9ms/step - loss: 0.5790 - accuracy: 0.9129 - val_loss: 3.3669 - val_accuracy: 0.3392
# Epoch 52/90
# 1563/1563 [==============================] - 13s 8ms/step - loss: 0.5516 - accuracy: 0.9218 - val_loss: 3.2906 - val_accuracy: 0.3484
# Epoch 53/90
# 1563/1563 [==============================] - 13s 8ms/step - loss: 0.5309 - accuracy: 0.9248 - val_loss: 3.2938 - val_accuracy: 0.3492
# Epoch 54/90
# 1563/1563 [==============================] - 14s 9ms/step - loss: 0.5197 - accuracy: 0.9252 - val_loss: 3.4647 - val_accuracy: 0.3292
# Epoch 55/90
# 1563/1563 [==============================] - 14s 9ms/step - loss: 0.5097 - accuracy: 0.9276 - val_loss: 3.3976 - val_accuracy: 0.3418
# Epoch 56/90
# 1563/1563 [==============================] - 13s 8ms/step - loss: 0.4888 - accuracy: 0.9333 - val_loss: 3.3697 - val_accuracy: 0.3466
# Epoch 57/90
# 1563/1563 [==============================] - 13s 8ms/step - loss: 0.4698 - accuracy: 0.9371 - val_loss: 3.3469 - val_accuracy: 0.3483
# Epoch 58/90
# 1563/1563 [==============================] - 13s 9ms/step - loss: 0.4546 - accuracy: 0.9396 - val_loss: 3.4047 - val_accuracy: 0.3426
# Epoch 59/90
# 1563/1563 [==============================] - 13s 8ms/step - loss: 0.4498 - accuracy: 0.9395 - val_loss: 3.4231 - val_accuracy: 0.3456
# Epoch 60/90
# 1563/1563 [==============================] - 13s 8ms/step - loss: 0.4390 - accuracy: 0.9425 - val_loss: 3.4031 - val_accuracy: 0.3460
# Epoch 61/90
# 1563/1563 [==============================] - 13s 9ms/step - loss: 0.4231 - accuracy: 0.9441 - val_loss: 3.3718 - val_accuracy: 0.3475
# Epoch 62/90
# 1563/1563 [==============================] - 13s 8ms/step - loss: 0.4124 - accuracy: 0.9461 - val_loss: 3.4381 - val_accuracy: 0.3400
# Epoch 63/90
# 1563/1563 [==============================] - 13s 8ms/step - loss: 0.4021 - accuracy: 0.9479 - val_loss: 3.4426 - val_accuracy: 0.3431
# Epoch 64/90
# 1563/1563 [==============================] - 13s 8ms/step - loss: 0.3934 - accuracy: 0.9498 - val_loss: 3.4833 - val_accuracy: 0.3433
# Epoch 65/90
# 1563/1563 [==============================] - 13s 8ms/step - loss: 0.3788 - accuracy: 0.9521 - val_loss: 3.5141 - val_accuracy: 0.3419
# Epoch 66/90
# 1563/1563 [==============================] - 13s 9ms/step - loss: 0.3778 - accuracy: 0.9519 - val_loss: 3.4850 - val_accuracy: 0.3475
# Epoch 67/90
# 1563/1563 [==============================] - 13s 9ms/step - loss: 0.3712 - accuracy: 0.9516 - val_loss: 3.4989 - val_accuracy: 0.3445
# Epoch 68/90
# 1563/1563 [==============================] - 13s 9ms/step - loss: 0.3580 - accuracy: 0.9558 - val_loss: 3.5160 - val_accuracy: 0.3437
# Epoch 69/90
# 1563/1563 [==============================] - 13s 9ms/step - loss: 0.3532 - accuracy: 0.9558 - val_loss: 3.5495 - val_accuracy: 0.3459
# Epoch 70/90
# 1563/1563 [==============================] - 13s 9ms/step - loss: 0.3416 - accuracy: 0.9581 - val_loss: 3.6362 - val_accuracy: 0.3283
# Epoch 71/90
# 1563/1563 [==============================] - 13s 9ms/step - loss: 0.3370 - accuracy: 0.9585 - val_loss: 3.5637 - val_accuracy: 0.3359
# Epoch 72/90
# 1563/1563 [==============================] - 14s 9ms/step - loss: 0.3333 - accuracy: 0.9586 - val_loss: 3.4919 - val_accuracy: 0.3509
# Epoch 73/90
# 1563/1563 [==============================] - 14s 9ms/step - loss: 0.3250 - accuracy: 0.9605 - val_loss: 3.5487 - val_accuracy: 0.3381
# Epoch 74/90
# 1563/1563 [==============================] - 14s 9ms/step - loss: 0.3168 - accuracy: 0.9629 - val_loss: 3.5434 - val_accuracy: 0.3476
# Epoch 75/90
# 1563/1563 [==============================] - 13s 9ms/step - loss: 0.3073 - accuracy: 0.9632 - val_loss: 3.5471 - val_accuracy: 0.3399
# Epoch 76/90
# 1563/1563 [==============================] - 13s 8ms/step - loss: 0.3055 - accuracy: 0.9643 - val_loss: 3.5980 - val_accuracy: 0.3415
# Epoch 77/90
# 1563/1563 [==============================] - 13s 8ms/step - loss: 0.2987 - accuracy: 0.9649 - val_loss: 3.5532 - val_accuracy: 0.3464
# Epoch 78/90
# 1563/1563 [==============================] - 13s 8ms/step - loss: 0.2958 - accuracy: 0.9645 - val_loss: 3.5738 - val_accuracy: 0.3426
# Epoch 79/90
# 1563/1563 [==============================] - 13s 9ms/step - loss: 0.2951 - accuracy: 0.9651 - val_loss: 3.5289 - val_accuracy: 0.3472
# Epoch 80/90
# 1563/1563 [==============================] - 13s 8ms/step - loss: 0.2861 - accuracy: 0.9656 - val_loss: 3.5600 - val_accuracy: 0.3409
# Epoch 81/90
# 1563/1563 [==============================] - 13s 8ms/step - loss: 0.2797 - accuracy: 0.9681 - val_loss: 3.6092 - val_accuracy: 0.3396
# Epoch 82/90
# 1563/1563 [==============================] - 13s 9ms/step - loss: 0.2701 - accuracy: 0.9703 - val_loss: 3.6357 - val_accuracy: 0.3377
# Epoch 83/90
# 1563/1563 [==============================] - 13s 8ms/step - loss: 0.2702 - accuracy: 0.9709 - val_loss: 3.5297 - val_accuracy: 0.3476
# Epoch 84/90
# 1563/1563 [==============================] - 13s 9ms/step - loss: 0.2626 - accuracy: 0.9713 - val_loss: 3.5741 - val_accuracy: 0.3469
# Epoch 85/90
# 1563/1563 [==============================] - 13s 9ms/step - loss: 0.2594 - accuracy: 0.9724 - val_loss: 3.6161 - val_accuracy: 0.3395
# Epoch 86/90
# 1563/1563 [==============================] - 13s 9ms/step - loss: 0.2592 - accuracy: 0.9702 - val_loss: 3.5521 - val_accuracy: 0.3494
# Epoch 87/90
# 1563/1563 [==============================] - 13s 8ms/step - loss: 0.2590 - accuracy: 0.9712 - val_loss: 3.6012 - val_accuracy: 0.3427
# Epoch 88/90
# 1563/1563 [==============================] - 14s 9ms/step - loss: 0.2544 - accuracy: 0.9712 - val_loss: 3.6110 - val_accuracy: 0.3438
# Epoch 89/90
# 1563/1563 [==============================] - 14s 9ms/step - loss: 0.2428 - accuracy: 0.9747 - val_loss: 3.6569 - val_accuracy: 0.3430
# Epoch 90/90
# 1563/1563 [==============================] - 13s 9ms/step - loss: 0.2437 - accuracy: 0.9739 - val_loss: 3.6066 - val_accuracy: 0.3453

# %%
#cifar100, dropout 0.1

accuracy = model.evaluate(test_images, test_labels, verbose=1)
print('Test loss:', accuracy[0])
print('Test accuracy:', accuracy[1])
# Out:
# 313/313 [==============================] - 1s 3ms/step - loss: 3.6066 - accuracy: 0.3453
# Test loss: 3.6065831184387207
# Test accuracy: 0.34529998898506165

# %%
import matplotlib.pyplot as plt

# Plot training & validation accuracy values
plt.figure(figsize=(12, 12))

plt.subplot(2, 1, 1)
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')

# Plot training & validation loss values
plt.subplot(2, 1, 2)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')

plt.subplots_adjust(hspace=0.3)
plt.show()
