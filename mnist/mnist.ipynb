# %%
from tensorflow.python.client import device_lib 
print(device_lib.list_local_devices())
# Out:
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 4977358434715452957
# xla_global_id: -1
# , name: "/device:GPU:0"
# device_type: "GPU"
# memory_limit: 5748293632
# locality {
#   bus_id: 1
#   links {
#   }
# }
# incarnation: 2833040074676319498
# physical_device_desc: "device: 0, name: NVIDIA GeForce RTX 3060 Ti, pci bus id: 0000:2b:00.0, compute capability: 8.6"
# xla_global_id: 416903419
# ]

# %%
import tensorflow as tf
from tensorflow import keras
from keras.models import Sequential
from keras.layers import Dense, Activation, Dropout, Flatten, Conv2D, MaxPooling2D, BatchNormalization
from keras.utils import to_categorical

# %%
#MNIST 데이터셋 로드
mnist = keras.datasets.mnist
(train_images, train_labels), (test_images, test_labels) = mnist.load_data()

# 데이터 전처리
train_images = train_images.reshape(-1, 28, 28, 1)
test_images = test_images.reshape(-1, 28, 28, 1)
train_images = train_images / 255.0
test_images = test_images / 255.0
train_labels = to_categorical(train_labels)
test_labels = to_categorical(test_labels)

print(train_labels.shape, test_labels.shape)

# 데이터 로더 생성
#batch_size = 64
#train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
#test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)
# Out:
# (60000, 10) (10000, 10)

# %%
# AlexNet model architecture
model = Sequential()

# 1st Convolutional Layer
model.add(Conv2D(filters=96, input_shape=(28,28,1), kernel_size=(11,11), strides=(4,4), padding='same')) 
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2,2), strides=(2,2), padding='same'))

# 2nd Convolutional Layer
model.add(Conv2D(filters=256, kernel_size=(5,5), strides=(1,1), padding='same')) 
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2,2), strides=(2,2), padding='same'))

# 3rd Convolutional Layer
model.add(Conv2D(filters=384, kernel_size=(3,3), strides=(1,1), padding='same')) 
model.add(BatchNormalization())
model.add(Activation('relu'))

# 4th Convolutional Layer
model.add(Conv2D(filters=384, kernel_size=(3,3), strides=(1,1), padding='same')) 
model.add(BatchNormalization())
model.add(Activation('relu'))

# 5th Convolutional Layer
model.add(Conv2D(filters=256, kernel_size=(3,3), strides=(1,1), padding='same')) 
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2,2), strides=(2,2), padding='same'))

# Fully Connected layer
model.add(Flatten())
model.add(Dense(4096, input_shape=(32,32,3))) 
model.add(BatchNormalization()) 
model.add(Activation('relu'))

# Add Dropout to prevent overfitting
model.add(Dropout(0.5))

# Fully Connected Layer
model.add(Dense(4096)) 
model.add(BatchNormalization()) 
model.add(Activation('relu')) # Add Dropout 
model.add(Dropout(0.5))

# Output Layer
model.add(Dense(10)) 
model.add(BatchNormalization()) 
model.add(Activation('softmax'))

# Model Summary
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 7, 7, 96)          11712
#
#  batch_normalization (BatchN  (None, 7, 7, 96)         384
#  ormalization)
#
#  activation (Activation)     (None, 7, 7, 96)          0
#
#  max_pooling2d (MaxPooling2D  (None, 4, 4, 96)         0
#  )
#
#  conv2d_1 (Conv2D)           (None, 4, 4, 256)         614656
#
#  batch_normalization_1 (Batc  (None, 4, 4, 256)        1024
#  hNormalization)
#
#  activation_1 (Activation)   (None, 4, 4, 256)         0
#
#  max_pooling2d_1 (MaxPooling  (None, 2, 2, 256)        0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 2, 2, 384)         885120
#
#  batch_normalization_2 (Batc  (None, 2, 2, 384)        1536
#  hNormalization)
#
#  activation_2 (Activation)   (None, 2, 2, 384)         0
#
#  conv2d_3 (Conv2D)           (None, 2, 2, 384)         1327488
#
#  batch_normalization_3 (Batc  (None, 2, 2, 384)        1536
#  hNormalization)
#
#  activation_3 (Activation)   (None, 2, 2, 384)         0
#
#  conv2d_4 (Conv2D)           (None, 2, 2, 256)         884992
#
#  batch_normalization_4 (Batc  (None, 2, 2, 256)        1024
#  hNormalization)
#
#  activation_4 (Activation)   (None, 2, 2, 256)         0
#
#  max_pooling2d_2 (MaxPooling  (None, 1, 1, 256)        0
#  2D)
#
#  flatten (Flatten)           (None, 256)               0
#
#  dense (Dense)               (None, 4096)              1052672
#
#  batch_normalization_5 (Batc  (None, 4096)             16384
#  hNormalization)
#
#  activation_5 (Activation)   (None, 4096)              0
#
#  dropout (Dropout)           (None, 4096)              0
#
#  dense_1 (Dense)             (None, 4096)              16781312
#
#  batch_normalization_6 (Batc  (None, 4096)             16384
#  hNormalization)
#
#  activation_6 (Activation)   (None, 4096)              0
#
#  dropout_1 (Dropout)         (None, 4096)              0
#
#  dense_2 (Dense)             (None, 10)                40970
#
#  batch_normalization_7 (Batc  (None, 10)               40
#  hNormalization)
#
#  activation_7 (Activation)   (None, 10)                0
#
# =================================================================
# Total params: 21,637,234
# Trainable params: 21,618,078
# Non-trainable params: 19,156
# _________________________________________________________________

# %%
# Compile the model
model.compile(optimizer=tf.keras.optimizers.SGD(learning_rate=0.001), 
              loss='categorical_crossentropy',
              metrics=['accuracy'])
# Train the model
# model.fit(train_images, train_labels, epochs=90, validation_data=(test_images, test_labels))

history = model.fit(train_images, train_labels, epochs=90, 
                    validation_data=(test_images, test_labels))
# Out:
# Epoch 1/90
# 1875/1875 [==============================] - 17s 8ms/step - loss: 0.7887 - accuracy: 0.8494 - val_loss: 0.3326 - val_accuracy: 0.9656
# Epoch 2/90
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.4658 - accuracy: 0.9428 - val_loss: 0.2283 - val_accuracy: 0.9757
# Epoch 3/90
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.3696 - accuracy: 0.9557 - val_loss: 0.1832 - val_accuracy: 0.9795
# Epoch 4/90
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.3091 - accuracy: 0.9630 - val_loss: 0.1449 - val_accuracy: 0.9817
# Epoch 5/90
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.2679 - accuracy: 0.9683 - val_loss: 0.1174 - val_accuracy: 0.9828
# Epoch 6/90
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.2349 - accuracy: 0.9720 - val_loss: 0.1038 - val_accuracy: 0.9845
# Epoch 7/90
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.2044 - accuracy: 0.9760 - val_loss: 0.0981 - val_accuracy: 0.9856
# Epoch 8/90
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.1854 - accuracy: 0.9786 - val_loss: 0.0854 - val_accuracy: 0.9869
# Epoch 9/90
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.1688 - accuracy: 0.9804 - val_loss: 0.0751 - val_accuracy: 0.9881
# Epoch 10/90
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.1536 - accuracy: 0.9822 - val_loss: 0.0725 - val_accuracy: 0.9874
# Epoch 11/90
# 1875/1875 [==============================] - 14s 8ms/step - loss: 0.1402 - accuracy: 0.9844 - val_loss: 0.0707 - val_accuracy: 0.9873
# Epoch 12/90
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.1317 - accuracy: 0.9847 - val_loss: 0.0738 - val_accuracy: 0.9851
# Epoch 13/90
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.1224 - accuracy: 0.9863 - val_loss: 0.0685 - val_accuracy: 0.9869
# Epoch 14/90
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.1114 - accuracy: 0.9885 - val_loss: 0.0618 - val_accuracy: 0.9871
# Epoch 15/90
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.1058 - accuracy: 0.9886 - val_loss: 0.0616 - val_accuracy: 0.9879
# Epoch 16/90
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.0975 - accuracy: 0.9901 - val_loss: 0.0577 - val_accuracy: 0.9869
# Epoch 17/90
# 1875/1875 [==============================] - 14s 8ms/step - loss: 0.0921 - accuracy: 0.9907 - val_loss: 0.0498 - val_accuracy: 0.9905
# Epoch 18/90
# 1875/1875 [==============================] - 14s 8ms/step - loss: 0.0875 - accuracy: 0.9912 - val_loss: 0.0525 - val_accuracy: 0.9882
# Epoch 19/90
# 1875/1875 [==============================] - 14s 8ms/step - loss: 0.0804 - accuracy: 0.9926 - val_loss: 0.0522 - val_accuracy: 0.9870
# Epoch 20/90
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.0764 - accuracy: 0.9928 - val_loss: 0.0508 - val_accuracy: 0.9885
# Epoch 21/90
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.0713 - accuracy: 0.9940 - val_loss: 0.0472 - val_accuracy: 0.9882
# Epoch 22/90
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.0683 - accuracy: 0.9942 - val_loss: 0.0423 - val_accuracy: 0.9898
# Epoch 23/90
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.0665 - accuracy: 0.9943 - val_loss: 0.0424 - val_accuracy: 0.9904
# Epoch 24/90
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.0616 - accuracy: 0.9948 - val_loss: 0.0491 - val_accuracy: 0.9891
# Epoch 25/90
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.0567 - accuracy: 0.9959 - val_loss: 0.0399 - val_accuracy: 0.9903
# Epoch 26/90
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.0545 - accuracy: 0.9960 - val_loss: 0.0446 - val_accuracy: 0.9893
# Epoch 27/90
# 1875/1875 [==============================] - 14s 8ms/step - loss: 0.0533 - accuracy: 0.9960 - val_loss: 0.0472 - val_accuracy: 0.9885
# Epoch 28/90
# 1875/1875 [==============================] - 15s 8ms/step - loss: 0.0490 - accuracy: 0.9968 - val_loss: 0.0390 - val_accuracy: 0.9904
# Epoch 29/90
# 1875/1875 [==============================] - 14s 8ms/step - loss: 0.0480 - accuracy: 0.9964 - val_loss: 0.0413 - val_accuracy: 0.9902
# Epoch 30/90
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.0470 - accuracy: 0.9966 - val_loss: 0.0662 - val_accuracy: 0.9831
# Epoch 31/90
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.0457 - accuracy: 0.9966 - val_loss: 0.0439 - val_accuracy: 0.9878
# Epoch 32/90
# 1875/1875 [==============================] - 14s 8ms/step - loss: 0.0440 - accuracy: 0.9969 - val_loss: 0.0402 - val_accuracy: 0.9894
# Epoch 33/90
# 1875/1875 [==============================] - 14s 8ms/step - loss: 0.0419 - accuracy: 0.9971 - val_loss: 0.0407 - val_accuracy: 0.9893
# Epoch 34/90
# 1875/1875 [==============================] - 14s 8ms/step - loss: 0.0410 - accuracy: 0.9973 - val_loss: 0.0393 - val_accuracy: 0.9898
# Epoch 35/90
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.0396 - accuracy: 0.9973 - val_loss: 0.0381 - val_accuracy: 0.9897
# Epoch 36/90
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.0365 - accuracy: 0.9978 - val_loss: 0.0388 - val_accuracy: 0.9894
# Epoch 37/90
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.0356 - accuracy: 0.9981 - val_loss: 0.0341 - val_accuracy: 0.9908
# Epoch 38/90
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.0359 - accuracy: 0.9977 - val_loss: 0.0354 - val_accuracy: 0.9907
# Epoch 39/90
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.0340 - accuracy: 0.9978 - val_loss: 0.0498 - val_accuracy: 0.9865
# Epoch 40/90
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.0334 - accuracy: 0.9978 - val_loss: 0.0375 - val_accuracy: 0.9906
# Epoch 41/90
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.0322 - accuracy: 0.9980 - val_loss: 0.0393 - val_accuracy: 0.9897
# Epoch 42/90
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.0304 - accuracy: 0.9984 - val_loss: 0.0356 - val_accuracy: 0.9903
# Epoch 43/90
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.0303 - accuracy: 0.9981 - val_loss: 0.0342 - val_accuracy: 0.9909
# Epoch 44/90
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.0286 - accuracy: 0.9984 - val_loss: 0.0486 - val_accuracy: 0.9870
# Epoch 45/90
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.0286 - accuracy: 0.9983 - val_loss: 0.0378 - val_accuracy: 0.9900
# Epoch 46/90
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.0280 - accuracy: 0.9984 - val_loss: 0.0366 - val_accuracy: 0.9889
# Epoch 47/90
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.0257 - accuracy: 0.9986 - val_loss: 0.0351 - val_accuracy: 0.9905
# Epoch 48/90
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.0250 - accuracy: 0.9990 - val_loss: 0.0340 - val_accuracy: 0.9902
# Epoch 49/90
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.0259 - accuracy: 0.9986 - val_loss: 0.0349 - val_accuracy: 0.9905
# Epoch 50/90
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.0245 - accuracy: 0.9988 - val_loss: 0.0343 - val_accuracy: 0.9900
# Epoch 51/90
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.0247 - accuracy: 0.9988 - val_loss: 0.0350 - val_accuracy: 0.9903
# Epoch 52/90
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.0239 - accuracy: 0.9988 - val_loss: 0.0375 - val_accuracy: 0.9898
# Epoch 53/90
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.0233 - accuracy: 0.9990 - val_loss: 0.0344 - val_accuracy: 0.9915
# Epoch 54/90
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.0220 - accuracy: 0.9989 - val_loss: 0.0425 - val_accuracy: 0.9884
# Epoch 55/90
# 1875/1875 [==============================] - 14s 8ms/step - loss: 0.0215 - accuracy: 0.9991 - val_loss: 0.0343 - val_accuracy: 0.9903
# Epoch 56/90
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.0215 - accuracy: 0.9989 - val_loss: 0.0352 - val_accuracy: 0.9901
# Epoch 57/90
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.0214 - accuracy: 0.9988 - val_loss: 0.0362 - val_accuracy: 0.9888
# Epoch 58/90
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.0200 - accuracy: 0.9993 - val_loss: 0.0320 - val_accuracy: 0.9906
# Epoch 59/90
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.0209 - accuracy: 0.9989 - val_loss: 0.0366 - val_accuracy: 0.9900
# Epoch 60/90
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.0206 - accuracy: 0.9991 - val_loss: 0.0375 - val_accuracy: 0.9894
# Epoch 61/90
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.0197 - accuracy: 0.9991 - val_loss: 0.0388 - val_accuracy: 0.9893
# Epoch 62/90
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.0199 - accuracy: 0.9990 - val_loss: 0.0355 - val_accuracy: 0.9902
# Epoch 63/90
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.0175 - accuracy: 0.9995 - val_loss: 0.0351 - val_accuracy: 0.9900
# Epoch 64/90
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.0183 - accuracy: 0.9991 - val_loss: 0.0388 - val_accuracy: 0.9893
# Epoch 65/90
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.0174 - accuracy: 0.9994 - val_loss: 0.0334 - val_accuracy: 0.9907
# Epoch 66/90
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.0175 - accuracy: 0.9993 - val_loss: 0.0346 - val_accuracy: 0.9899
# Epoch 67/90
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.0171 - accuracy: 0.9994 - val_loss: 0.0337 - val_accuracy: 0.9899
# Epoch 68/90
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.0171 - accuracy: 0.9995 - val_loss: 0.0370 - val_accuracy: 0.9892
# Epoch 69/90
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.0164 - accuracy: 0.9993 - val_loss: 0.0322 - val_accuracy: 0.9909
# Epoch 70/90
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.0166 - accuracy: 0.9994 - val_loss: 0.0333 - val_accuracy: 0.9902
# Epoch 71/90
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.0161 - accuracy: 0.9994 - val_loss: 0.0368 - val_accuracy: 0.9894
# Epoch 72/90
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.0157 - accuracy: 0.9994 - val_loss: 0.0345 - val_accuracy: 0.9891
# Epoch 73/90
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.0156 - accuracy: 0.9994 - val_loss: 0.0336 - val_accuracy: 0.9902
# Epoch 74/90
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.0152 - accuracy: 0.9995 - val_loss: 0.0344 - val_accuracy: 0.9908
# Epoch 75/90
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.0152 - accuracy: 0.9995 - val_loss: 0.0323 - val_accuracy: 0.9908
# Epoch 76/90
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.0147 - accuracy: 0.9995 - val_loss: 0.0324 - val_accuracy: 0.9903
# Epoch 77/90
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.0145 - accuracy: 0.9994 - val_loss: 0.0336 - val_accuracy: 0.9906
# Epoch 78/90
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.0154 - accuracy: 0.9993 - val_loss: 0.0360 - val_accuracy: 0.9898
# Epoch 79/90
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.0142 - accuracy: 0.9995 - val_loss: 0.0376 - val_accuracy: 0.9896
# Epoch 80/90
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.0141 - accuracy: 0.9995 - val_loss: 0.0335 - val_accuracy: 0.9906
# Epoch 81/90
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.0142 - accuracy: 0.9995 - val_loss: 0.0352 - val_accuracy: 0.9905
# Epoch 82/90
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.0130 - accuracy: 0.9997 - val_loss: 0.0326 - val_accuracy: 0.9906
# Epoch 83/90
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.0134 - accuracy: 0.9995 - val_loss: 0.0342 - val_accuracy: 0.9897
# Epoch 84/90
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.0125 - accuracy: 0.9997 - val_loss: 0.0336 - val_accuracy: 0.9904
# Epoch 85/90
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.0131 - accuracy: 0.9995 - val_loss: 0.0332 - val_accuracy: 0.9908
# Epoch 86/90
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.0128 - accuracy: 0.9996 - val_loss: 0.0323 - val_accuracy: 0.9906
# Epoch 87/90
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.0133 - accuracy: 0.9994 - val_loss: 0.0351 - val_accuracy: 0.9899
# Epoch 88/90
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.0128 - accuracy: 0.9996 - val_loss: 0.0346 - val_accuracy: 0.9899
# Epoch 89/90
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.0123 - accuracy: 0.9996 - val_loss: 0.0321 - val_accuracy: 0.9910
# Epoch 90/90
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.0123 - accuracy: 0.9996 - val_loss: 0.0328 - val_accuracy: 0.9903

# %%
#mnist

accuracy = model.evaluate(test_images, test_labels, verbose=1)
print('Test loss:', accuracy[0])
print('Test accuracy:', accuracy[1])
# Out:
# 313/313 [==============================] - 1s 3ms/step - loss: 0.0328 - accuracy: 0.9903
# Test loss: 0.03276030719280243
# Test accuracy: 0.9902999997138977

# %%
import matplotlib.pyplot as plt

# Plot training & validation accuracy values
plt.figure(figsize=(12, 12))

plt.subplot(2, 1, 1)
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')

# Plot training & validation loss values
plt.subplot(2, 1, 2)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')

plt.subplots_adjust(hspace=0.3)
plt.show()
