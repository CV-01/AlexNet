# %%
from tensorflow.python.client import device_lib 
print(device_lib.list_local_devices())
# Out:
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 12740868820969054839
# xla_global_id: -1
# , name: "/device:GPU:0"
# device_type: "GPU"
# memory_limit: 5748293632
# locality {
#   bus_id: 1
#   links {
#   }
# }
# incarnation: 13913355355516588057
# physical_device_desc: "device: 0, name: NVIDIA GeForce RTX 3060 Ti, pci bus id: 0000:2b:00.0, compute capability: 8.6"
# xla_global_id: 416903419
# ]

# %%
import tensorflow as tf
from tensorflow import keras
from keras.models import Sequential
from keras.layers import Dense, Activation, Dropout, Flatten, Conv2D, MaxPooling2D, BatchNormalization
from keras.utils import to_categorical

# %%
# Fashion MNIST 데이터셋 로드
fashion_mnist = keras.datasets.fashion_mnist
(train_images, train_labels), (test_images, test_labels) = fashion_mnist.load_data()

# 데이터 전처리
train_images = train_images.reshape(-1, 28, 28, 1)
test_images = test_images.reshape(-1, 28, 28, 1)
train_images = train_images / 255.0
test_images = test_images / 255.0
train_labels = to_categorical(train_labels)
test_labels = to_categorical(test_labels)

print(train_labels.shape, test_labels.shape)

# 데이터 로더 생성
#batch_size = 64
#train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
#test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)
# Out:
# (60000, 10) (10000, 10)

# %%
# AlexNet model architecture
model = Sequential()

# 1st Convolutional Layer
model.add(Conv2D(filters=96, input_shape=(28,28,1), kernel_size=(11,11), strides=(4,4), padding='same')) 
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2,2), strides=(2,2), padding='same'))

# 2nd Convolutional Layer
model.add(Conv2D(filters=256, kernel_size=(5,5), strides=(1,1), padding='same')) 
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2,2), strides=(2,2), padding='same'))

# 3rd Convolutional Layer
model.add(Conv2D(filters=384, kernel_size=(3,3), strides=(1,1), padding='same')) 
model.add(BatchNormalization())
model.add(Activation('relu'))


#########################################################################
model.add(Conv2D(filters=384, kernel_size=(3,3), strides=(1,1), padding='same')) 
model.add(BatchNormalization())
model.add(Activation('relu'))

model.add(Conv2D(filters=384, kernel_size=(3,3), strides=(1,1), padding='same')) 
model.add(BatchNormalization())
model.add(Activation('relu'))
#########################################################################


# 4th Convolutional Layer
model.add(Conv2D(filters=384, kernel_size=(3,3), strides=(1,1), padding='same')) 
model.add(BatchNormalization())
model.add(Activation('relu'))

# 5th Convolutional Layer
model.add(Conv2D(filters=256, kernel_size=(3,3), strides=(1,1), padding='same')) 
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2,2), strides=(2,2), padding='same'))

# Fully Connected layer
model.add(Flatten())
model.add(Dense(4096, input_shape=(32,32,3))) 
model.add(BatchNormalization()) 
model.add(Activation('relu'))

# Add Dropout to prevent overfitting
model.add(Dropout(0.5))

# Fully Connected Layer
model.add(Dense(4096)) 
model.add(BatchNormalization()) 
model.add(Activation('relu')) # Add Dropout 
model.add(Dropout(0.5))

# Output Layer
model.add(Dense(10)) 
model.add(BatchNormalization()) 
model.add(Activation('softmax'))

# Model Summary
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 7, 7, 96)          11712
#
#  batch_normalization (BatchN  (None, 7, 7, 96)         384
#  ormalization)
#
#  activation (Activation)     (None, 7, 7, 96)          0
#
#  max_pooling2d (MaxPooling2D  (None, 4, 4, 96)         0
#  )
#
#  conv2d_1 (Conv2D)           (None, 4, 4, 256)         614656
#
#  batch_normalization_1 (Batc  (None, 4, 4, 256)        1024
#  hNormalization)
#
#  activation_1 (Activation)   (None, 4, 4, 256)         0
#
#  max_pooling2d_1 (MaxPooling  (None, 2, 2, 256)        0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 2, 2, 384)         885120
#
#  batch_normalization_2 (Batc  (None, 2, 2, 384)        1536
#  hNormalization)
#
#  activation_2 (Activation)   (None, 2, 2, 384)         0
#
#  conv2d_3 (Conv2D)           (None, 2, 2, 384)         1327488
#
#  batch_normalization_3 (Batc  (None, 2, 2, 384)        1536
#  hNormalization)
#
#  activation_3 (Activation)   (None, 2, 2, 384)         0
#
#  conv2d_4 (Conv2D)           (None, 2, 2, 384)         1327488
#
#  batch_normalization_4 (Batc  (None, 2, 2, 384)        1536
#  hNormalization)
#
#  activation_4 (Activation)   (None, 2, 2, 384)         0
#
#  conv2d_5 (Conv2D)           (None, 2, 2, 384)         1327488
#
#  batch_normalization_5 (Batc  (None, 2, 2, 384)        1536
#  hNormalization)
#
#  activation_5 (Activation)   (None, 2, 2, 384)         0
#
#  conv2d_6 (Conv2D)           (None, 2, 2, 256)         884992
#
#  batch_normalization_6 (Batc  (None, 2, 2, 256)        1024
#  hNormalization)
#
#  activation_6 (Activation)   (None, 2, 2, 256)         0
#
#  max_pooling2d_2 (MaxPooling  (None, 1, 1, 256)        0
#  2D)
#
#  flatten (Flatten)           (None, 256)               0
#
#  dense (Dense)               (None, 4096)              1052672
#
#  batch_normalization_7 (Batc  (None, 4096)             16384
#  hNormalization)
#
#  activation_7 (Activation)   (None, 4096)              0
#
#  dropout (Dropout)           (None, 4096)              0
#
#  dense_1 (Dense)             (None, 4096)              16781312
#
#  batch_normalization_8 (Batc  (None, 4096)             16384
#  hNormalization)
#
#  activation_8 (Activation)   (None, 4096)              0
#
#  dropout_1 (Dropout)         (None, 4096)              0
#
#  dense_2 (Dense)             (None, 10)                40970
#
#  batch_normalization_9 (Batc  (None, 10)               40
#  hNormalization)
#
#  activation_9 (Activation)   (None, 10)                0
#
# =================================================================
# Total params: 24,295,282
# Trainable params: 24,274,590
# Non-trainable params: 20,692
# _________________________________________________________________

# %%
# Compile the model
model.compile(optimizer=tf.keras.optimizers.SGD(learning_rate=0.001), 
              loss='categorical_crossentropy',
              metrics=['accuracy'])
# Train the model
# model.fit(train_images, train_labels, epochs=90, validation_data=(test_images, test_labels))

history = model.fit(train_images, train_labels, epochs=90, 
                    validation_data=(test_images, test_labels))
# Out:
# Epoch 1/90
# 1875/1875 [==============================] - 21s 10ms/step - loss: 0.9538 - accuracy: 0.7499 - val_loss: 0.6123 - val_accuracy: 0.8411
# Epoch 2/90
# 1875/1875 [==============================] - 18s 9ms/step - loss: 0.6803 - accuracy: 0.8388 - val_loss: 0.5156 - val_accuracy: 0.8591
# Epoch 3/90
# 1875/1875 [==============================] - 18s 9ms/step - loss: 0.5896 - accuracy: 0.8579 - val_loss: 0.4658 - val_accuracy: 0.8728
# Epoch 4/90
# 1875/1875 [==============================] - 18s 9ms/step - loss: 0.5294 - accuracy: 0.8700 - val_loss: 0.4455 - val_accuracy: 0.8713
# Epoch 5/90
# 1875/1875 [==============================] - 18s 9ms/step - loss: 0.4876 - accuracy: 0.8770 - val_loss: 0.4191 - val_accuracy: 0.8731
# Epoch 6/90
# 1875/1875 [==============================] - 18s 9ms/step - loss: 0.4518 - accuracy: 0.8855 - val_loss: 0.4555 - val_accuracy: 0.8591
# Epoch 7/90
# 1875/1875 [==============================] - 18s 9ms/step - loss: 0.4259 - accuracy: 0.8888 - val_loss: 0.3772 - val_accuracy: 0.8855
# Epoch 8/90
# 1875/1875 [==============================] - 18s 9ms/step - loss: 0.3998 - accuracy: 0.8948 - val_loss: 0.3667 - val_accuracy: 0.8884
# Epoch 9/90
# 1875/1875 [==============================] - 18s 9ms/step - loss: 0.3774 - accuracy: 0.9014 - val_loss: 0.3636 - val_accuracy: 0.8831
# Epoch 10/90
# 1875/1875 [==============================] - 18s 9ms/step - loss: 0.3572 - accuracy: 0.9054 - val_loss: 0.3441 - val_accuracy: 0.8903
# Epoch 11/90
# 1875/1875 [==============================] - 18s 9ms/step - loss: 0.3445 - accuracy: 0.9071 - val_loss: 0.3512 - val_accuracy: 0.8890
# Epoch 12/90
# 1875/1875 [==============================] - 18s 9ms/step - loss: 0.3235 - accuracy: 0.9137 - val_loss: 0.3269 - val_accuracy: 0.8981
# Epoch 13/90
# 1875/1875 [==============================] - 18s 9ms/step - loss: 0.3093 - accuracy: 0.9184 - val_loss: 0.3353 - val_accuracy: 0.8935
# Epoch 14/90
# 1875/1875 [==============================] - 18s 9ms/step - loss: 0.2991 - accuracy: 0.9208 - val_loss: 0.3634 - val_accuracy: 0.8847
# Epoch 15/90
# 1875/1875 [==============================] - 18s 9ms/step - loss: 0.2833 - accuracy: 0.9253 - val_loss: 0.3876 - val_accuracy: 0.8824
# Epoch 16/90
# 1875/1875 [==============================] - 18s 9ms/step - loss: 0.2701 - accuracy: 0.9282 - val_loss: 0.3668 - val_accuracy: 0.8846
# Epoch 17/90
# 1875/1875 [==============================] - 18s 9ms/step - loss: 0.2616 - accuracy: 0.9305 - val_loss: 0.4226 - val_accuracy: 0.8706
# Epoch 18/90
# 1875/1875 [==============================] - 18s 10ms/step - loss: 0.2492 - accuracy: 0.9344 - val_loss: 0.3326 - val_accuracy: 0.8960
# Epoch 19/90
# 1875/1875 [==============================] - 18s 9ms/step - loss: 0.2387 - accuracy: 0.9369 - val_loss: 0.3499 - val_accuracy: 0.8934
# Epoch 20/90
# 1875/1875 [==============================] - 18s 9ms/step - loss: 0.2294 - accuracy: 0.9394 - val_loss: 0.4099 - val_accuracy: 0.8808
# Epoch 21/90
# 1875/1875 [==============================] - 18s 9ms/step - loss: 0.2190 - accuracy: 0.9421 - val_loss: 0.3809 - val_accuracy: 0.8811
# Epoch 22/90
# 1875/1875 [==============================] - 18s 9ms/step - loss: 0.2109 - accuracy: 0.9444 - val_loss: 0.3578 - val_accuracy: 0.8899
# Epoch 23/90
# 1875/1875 [==============================] - 18s 9ms/step - loss: 0.2013 - accuracy: 0.9478 - val_loss: 0.3376 - val_accuracy: 0.8958
# Epoch 24/90
# 1875/1875 [==============================] - 18s 9ms/step - loss: 0.1938 - accuracy: 0.9505 - val_loss: 0.3453 - val_accuracy: 0.8958
# Epoch 25/90
# 1875/1875 [==============================] - 18s 9ms/step - loss: 0.1824 - accuracy: 0.9538 - val_loss: 0.3867 - val_accuracy: 0.8881
# Epoch 26/90
# 1875/1875 [==============================] - 18s 9ms/step - loss: 0.1750 - accuracy: 0.9558 - val_loss: 0.3817 - val_accuracy: 0.8906
# Epoch 27/90
# 1875/1875 [==============================] - 18s 9ms/step - loss: 0.1694 - accuracy: 0.9571 - val_loss: 0.4310 - val_accuracy: 0.8821
# Epoch 28/90
# 1875/1875 [==============================] - 18s 9ms/step - loss: 0.1614 - accuracy: 0.9599 - val_loss: 0.3763 - val_accuracy: 0.8905
# Epoch 29/90
# 1875/1875 [==============================] - 18s 9ms/step - loss: 0.1609 - accuracy: 0.9592 - val_loss: 0.4317 - val_accuracy: 0.8805
# Epoch 30/90
# 1875/1875 [==============================] - 18s 9ms/step - loss: 0.1522 - accuracy: 0.9619 - val_loss: 0.3586 - val_accuracy: 0.8987
# Epoch 31/90
# 1875/1875 [==============================] - 18s 10ms/step - loss: 0.1414 - accuracy: 0.9650 - val_loss: 0.3748 - val_accuracy: 0.8913
# Epoch 32/90
# 1875/1875 [==============================] - 18s 9ms/step - loss: 0.1375 - accuracy: 0.9662 - val_loss: 0.3692 - val_accuracy: 0.8954
# Epoch 33/90
# 1875/1875 [==============================] - 18s 9ms/step - loss: 0.1331 - accuracy: 0.9672 - val_loss: 0.4206 - val_accuracy: 0.8912
# Epoch 34/90
# 1875/1875 [==============================] - 18s 9ms/step - loss: 0.1290 - accuracy: 0.9693 - val_loss: 0.3890 - val_accuracy: 0.8960
# Epoch 35/90
# 1875/1875 [==============================] - 17s 9ms/step - loss: 0.1235 - accuracy: 0.9707 - val_loss: 0.3683 - val_accuracy: 0.8986
# Epoch 36/90
# 1875/1875 [==============================] - 17s 9ms/step - loss: 0.1172 - accuracy: 0.9720 - val_loss: 0.4485 - val_accuracy: 0.8866
# Epoch 37/90
# 1875/1875 [==============================] - 17s 9ms/step - loss: 0.1148 - accuracy: 0.9719 - val_loss: 0.4100 - val_accuracy: 0.8896
# Epoch 38/90
# 1875/1875 [==============================] - 17s 9ms/step - loss: 0.1103 - accuracy: 0.9738 - val_loss: 0.4048 - val_accuracy: 0.8901
# Epoch 39/90
# 1875/1875 [==============================] - 17s 9ms/step - loss: 0.1062 - accuracy: 0.9747 - val_loss: 0.3791 - val_accuracy: 0.9011
# Epoch 40/90
# 1875/1875 [==============================] - 17s 9ms/step - loss: 0.1034 - accuracy: 0.9760 - val_loss: 0.4975 - val_accuracy: 0.8700
# Epoch 41/90
# 1875/1875 [==============================] - 17s 9ms/step - loss: 0.1031 - accuracy: 0.9760 - val_loss: 0.3849 - val_accuracy: 0.8952
# Epoch 42/90
# 1875/1875 [==============================] - 17s 9ms/step - loss: 0.0934 - accuracy: 0.9786 - val_loss: 0.4445 - val_accuracy: 0.8850
# Epoch 43/90
# 1875/1875 [==============================] - 17s 9ms/step - loss: 0.0925 - accuracy: 0.9787 - val_loss: 0.4092 - val_accuracy: 0.8952
# Epoch 44/90
# 1875/1875 [==============================] - 17s 9ms/step - loss: 0.0917 - accuracy: 0.9786 - val_loss: 0.3787 - val_accuracy: 0.8995
# Epoch 45/90
# 1875/1875 [==============================] - 17s 9ms/step - loss: 0.0869 - accuracy: 0.9804 - val_loss: 0.4029 - val_accuracy: 0.8956
# Epoch 46/90
# 1875/1875 [==============================] - 17s 9ms/step - loss: 0.0803 - accuracy: 0.9819 - val_loss: 0.4031 - val_accuracy: 0.8979
# Epoch 47/90
# 1875/1875 [==============================] - 17s 9ms/step - loss: 0.0755 - accuracy: 0.9840 - val_loss: 0.4279 - val_accuracy: 0.8952
# Epoch 48/90
# 1875/1875 [==============================] - 17s 9ms/step - loss: 0.0783 - accuracy: 0.9831 - val_loss: 0.4172 - val_accuracy: 0.8920
# Epoch 49/90
# 1875/1875 [==============================] - 17s 9ms/step - loss: 0.0750 - accuracy: 0.9833 - val_loss: 0.4370 - val_accuracy: 0.8888
# Epoch 50/90
# 1875/1875 [==============================] - 17s 9ms/step - loss: 0.0715 - accuracy: 0.9846 - val_loss: 0.4058 - val_accuracy: 0.8987
# Epoch 51/90
# 1875/1875 [==============================] - 17s 9ms/step - loss: 0.0730 - accuracy: 0.9844 - val_loss: 0.4661 - val_accuracy: 0.8895
# Epoch 52/90
# 1875/1875 [==============================] - 17s 9ms/step - loss: 0.0671 - accuracy: 0.9861 - val_loss: 0.5803 - val_accuracy: 0.8611
# Epoch 53/90
# 1875/1875 [==============================] - 17s 9ms/step - loss: 0.0644 - accuracy: 0.9864 - val_loss: 0.4155 - val_accuracy: 0.8982
# Epoch 54/90
# 1875/1875 [==============================] - 17s 9ms/step - loss: 0.0682 - accuracy: 0.9847 - val_loss: 0.4601 - val_accuracy: 0.8930
# Epoch 55/90
# 1875/1875 [==============================] - 17s 9ms/step - loss: 0.0624 - accuracy: 0.9869 - val_loss: 0.4306 - val_accuracy: 0.8948
# Epoch 56/90
# 1875/1875 [==============================] - 17s 9ms/step - loss: 0.0609 - accuracy: 0.9871 - val_loss: 0.4435 - val_accuracy: 0.8961
# Epoch 57/90
# 1875/1875 [==============================] - 17s 9ms/step - loss: 0.0589 - accuracy: 0.9871 - val_loss: 0.6585 - val_accuracy: 0.8579
# Epoch 58/90
# 1875/1875 [==============================] - 17s 9ms/step - loss: 0.0588 - accuracy: 0.9879 - val_loss: 0.4787 - val_accuracy: 0.8858
# Epoch 59/90
# 1875/1875 [==============================] - 17s 9ms/step - loss: 0.0554 - accuracy: 0.9889 - val_loss: 0.4573 - val_accuracy: 0.8935
# Epoch 60/90
# 1875/1875 [==============================] - 17s 9ms/step - loss: 0.0552 - accuracy: 0.9880 - val_loss: 0.4064 - val_accuracy: 0.9060
# Epoch 61/90
# 1875/1875 [==============================] - 17s 9ms/step - loss: 0.0505 - accuracy: 0.9902 - val_loss: 0.4743 - val_accuracy: 0.8952
# Epoch 62/90
# 1875/1875 [==============================] - 17s 9ms/step - loss: 0.0503 - accuracy: 0.9902 - val_loss: 0.4265 - val_accuracy: 0.9023
# Epoch 63/90
# 1875/1875 [==============================] - 17s 9ms/step - loss: 0.0537 - accuracy: 0.9883 - val_loss: 0.4355 - val_accuracy: 0.8999
# Epoch 64/90
# 1875/1875 [==============================] - 17s 9ms/step - loss: 0.0496 - accuracy: 0.9906 - val_loss: 0.6016 - val_accuracy: 0.8671
# Epoch 65/90
# 1875/1875 [==============================] - 17s 9ms/step - loss: 0.0460 - accuracy: 0.9911 - val_loss: 0.4867 - val_accuracy: 0.8918
# Epoch 66/90
# 1875/1875 [==============================] - 17s 9ms/step - loss: 0.0443 - accuracy: 0.9916 - val_loss: 0.4542 - val_accuracy: 0.8961
# Epoch 67/90
# 1875/1875 [==============================] - 17s 9ms/step - loss: 0.0443 - accuracy: 0.9915 - val_loss: 0.4783 - val_accuracy: 0.8922
# Epoch 68/90
# 1875/1875 [==============================] - 17s 9ms/step - loss: 0.0414 - accuracy: 0.9923 - val_loss: 0.4302 - val_accuracy: 0.9018
# Epoch 69/90
# 1875/1875 [==============================] - 17s 9ms/step - loss: 0.0437 - accuracy: 0.9915 - val_loss: 0.4839 - val_accuracy: 0.8899
# Epoch 70/90
# 1875/1875 [==============================] - 17s 9ms/step - loss: 0.0413 - accuracy: 0.9920 - val_loss: 0.4771 - val_accuracy: 0.8957
# Epoch 71/90
# 1875/1875 [==============================] - 17s 9ms/step - loss: 0.0391 - accuracy: 0.9931 - val_loss: 0.5827 - val_accuracy: 0.8733
# Epoch 72/90
# 1875/1875 [==============================] - 17s 9ms/step - loss: 0.0399 - accuracy: 0.9924 - val_loss: 0.4566 - val_accuracy: 0.8994
# Epoch 73/90
# 1875/1875 [==============================] - 17s 9ms/step - loss: 0.0370 - accuracy: 0.9938 - val_loss: 0.4636 - val_accuracy: 0.8982
# Epoch 74/90
# 1875/1875 [==============================] - 18s 10ms/step - loss: 0.0368 - accuracy: 0.9934 - val_loss: 0.4607 - val_accuracy: 0.9003
# Epoch 75/90
# 1875/1875 [==============================] - 18s 10ms/step - loss: 0.0358 - accuracy: 0.9937 - val_loss: 0.4787 - val_accuracy: 0.8958
# Epoch 76/90
# 1875/1875 [==============================] - 18s 9ms/step - loss: 0.0360 - accuracy: 0.9935 - val_loss: 0.4966 - val_accuracy: 0.8925
# Epoch 77/90
# 1875/1875 [==============================] - 18s 9ms/step - loss: 0.0357 - accuracy: 0.9930 - val_loss: 0.4896 - val_accuracy: 0.8942
# Epoch 78/90
# 1875/1875 [==============================] - 18s 10ms/step - loss: 0.0341 - accuracy: 0.9941 - val_loss: 0.4725 - val_accuracy: 0.8982
# Epoch 79/90
# 1875/1875 [==============================] - 19s 10ms/step - loss: 0.0313 - accuracy: 0.9952 - val_loss: 0.4854 - val_accuracy: 0.8969
# Epoch 80/90
# 1875/1875 [==============================] - 18s 10ms/step - loss: 0.0314 - accuracy: 0.9946 - val_loss: 0.4601 - val_accuracy: 0.9002
# Epoch 81/90
# 1875/1875 [==============================] - 19s 10ms/step - loss: 0.0298 - accuracy: 0.9952 - val_loss: 0.4680 - val_accuracy: 0.8988
# Epoch 82/90
# 1875/1875 [==============================] - 18s 10ms/step - loss: 0.0303 - accuracy: 0.9950 - val_loss: 0.4480 - val_accuracy: 0.9037
# Epoch 83/90
# 1875/1875 [==============================] - 18s 10ms/step - loss: 0.0311 - accuracy: 0.9945 - val_loss: 0.4521 - val_accuracy: 0.9037
# Epoch 84/90
# 1875/1875 [==============================] - 18s 10ms/step - loss: 0.0338 - accuracy: 0.9938 - val_loss: 0.4728 - val_accuracy: 0.9003
# Epoch 85/90
# 1875/1875 [==============================] - 18s 10ms/step - loss: 0.0319 - accuracy: 0.9941 - val_loss: 0.4810 - val_accuracy: 0.8989
# Epoch 86/90
# 1875/1875 [==============================] - 18s 10ms/step - loss: 0.0310 - accuracy: 0.9944 - val_loss: 0.4696 - val_accuracy: 0.9000
# Epoch 87/90
# 1875/1875 [==============================] - 18s 10ms/step - loss: 0.0313 - accuracy: 0.9944 - val_loss: 0.4775 - val_accuracy: 0.8975
# Epoch 88/90
# 1875/1875 [==============================] - 18s 10ms/step - loss: 0.0306 - accuracy: 0.9946 - val_loss: 0.4672 - val_accuracy: 0.8978
# Epoch 89/90
# 1875/1875 [==============================] - 18s 10ms/step - loss: 0.0248 - accuracy: 0.9966 - val_loss: 0.5022 - val_accuracy: 0.8957
# Epoch 90/90
# 1875/1875 [==============================] - 19s 10ms/step - loss: 0.0253 - accuracy: 0.9961 - val_loss: 0.5674 - val_accuracy: 0.8829

# %%
#fashion mnist, 레이어 2개 추가

accuracy = model.evaluate(test_images, test_labels, verbose=1)
print('Test loss:', accuracy[0])
print('Test accuracy:', accuracy[1])
# Out:
# 313/313 [==============================] - 1s 4ms/step - loss: 0.5674 - accuracy: 0.8829
# Test loss: 0.5673854351043701
# Test accuracy: 0.8828999996185303

# %%
import matplotlib.pyplot as plt

# Plot training & validation accuracy values
plt.figure(figsize=(12, 12))

plt.subplot(2, 1, 1)
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')

# Plot training & validation loss values
plt.subplot(2, 1, 2)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')

plt.subplots_adjust(hspace=0.3)
plt.show()
