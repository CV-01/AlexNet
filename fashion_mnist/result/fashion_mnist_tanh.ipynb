# %%
from tensorflow.python.client import device_lib 
print(device_lib.list_local_devices())
# Out:
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 13132549564482191234
# xla_global_id: -1
# , name: "/device:GPU:0"
# device_type: "GPU"
# memory_limit: 5748293632
# locality {
#   bus_id: 1
#   links {
#   }
# }
# incarnation: 321306490506694054
# physical_device_desc: "device: 0, name: NVIDIA GeForce RTX 3060 Ti, pci bus id: 0000:2b:00.0, compute capability: 8.6"
# xla_global_id: 416903419
# ]

# %%
import tensorflow as tf
from tensorflow import keras
from keras.models import Sequential
from keras.layers import Dense, Activation, Dropout, Flatten, Conv2D, MaxPooling2D, BatchNormalization
from keras.utils import to_categorical

# %%
# Fashion MNIST 데이터셋 로드
fashion_mnist = keras.datasets.fashion_mnist
(train_images, train_labels), (test_images, test_labels) = fashion_mnist.load_data()

# 데이터 전처리
train_images = train_images.reshape(-1, 28, 28, 1)
test_images = test_images.reshape(-1, 28, 28, 1)
train_images = train_images / 255.0
test_images = test_images / 255.0
train_labels = to_categorical(train_labels)
test_labels = to_categorical(test_labels)

print(train_labels.shape, test_labels.shape)

# 데이터 로더 생성
#batch_size = 64
#train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
#test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)
# Out:
# (60000, 10) (10000, 10)

# %%
# AlexNet model architecture
model = Sequential()

# 1st Convolutional Layer
model.add(Conv2D(filters=96, input_shape=(28,28,1), kernel_size=(11,11), strides=(4,4), padding='same')) 
model.add(BatchNormalization())
model.add(Activation('tanh'))
model.add(MaxPooling2D(pool_size=(2,2), strides=(2,2), padding='same'))

# 2nd Convolutional Layer
model.add(Conv2D(filters=256, kernel_size=(5,5), strides=(1,1), padding='same')) 
model.add(BatchNormalization())
model.add(Activation('tanh'))
model.add(MaxPooling2D(pool_size=(2,2), strides=(2,2), padding='same'))

# 3rd Convolutional Layer
model.add(Conv2D(filters=384, kernel_size=(3,3), strides=(1,1), padding='same')) 
model.add(BatchNormalization())
model.add(Activation('tanh'))

# 4th Convolutional Layer
model.add(Conv2D(filters=384, kernel_size=(3,3), strides=(1,1), padding='same')) 
model.add(BatchNormalization())
model.add(Activation('tanh'))

# 5th Convolutional Layer
model.add(Conv2D(filters=256, kernel_size=(3,3), strides=(1,1), padding='same')) 
model.add(BatchNormalization())
model.add(Activation('tanh'))
model.add(MaxPooling2D(pool_size=(2,2), strides=(2,2), padding='same'))

# Fully Connected layer
model.add(Flatten())
model.add(Dense(4096, input_shape=(32,32,3))) 
model.add(BatchNormalization()) 
model.add(Activation('tanh'))

# Add Dropout to prevent overfitting
model.add(Dropout(0.5))

# Fully Connected Layer
model.add(Dense(4096)) 
model.add(BatchNormalization()) 
model.add(Activation('tanh')) # Add Dropout 
model.add(Dropout(0.5))

# Output Layer
model.add(Dense(10)) 
model.add(BatchNormalization()) 
model.add(Activation('softmax'))

# Model Summary
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 7, 7, 96)          11712
#
#  batch_normalization (BatchN  (None, 7, 7, 96)         384
#  ormalization)
#
#  activation (Activation)     (None, 7, 7, 96)          0
#
#  max_pooling2d (MaxPooling2D  (None, 4, 4, 96)         0
#  )
#
#  conv2d_1 (Conv2D)           (None, 4, 4, 256)         614656
#
#  batch_normalization_1 (Batc  (None, 4, 4, 256)        1024
#  hNormalization)
#
#  activation_1 (Activation)   (None, 4, 4, 256)         0
#
#  max_pooling2d_1 (MaxPooling  (None, 2, 2, 256)        0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 2, 2, 384)         885120
#
#  batch_normalization_2 (Batc  (None, 2, 2, 384)        1536
#  hNormalization)
#
#  activation_2 (Activation)   (None, 2, 2, 384)         0
#
#  conv2d_3 (Conv2D)           (None, 2, 2, 384)         1327488
#
#  batch_normalization_3 (Batc  (None, 2, 2, 384)        1536
#  hNormalization)
#
#  activation_3 (Activation)   (None, 2, 2, 384)         0
#
#  conv2d_4 (Conv2D)           (None, 2, 2, 256)         884992
#
#  batch_normalization_4 (Batc  (None, 2, 2, 256)        1024
#  hNormalization)
#
#  activation_4 (Activation)   (None, 2, 2, 256)         0
#
#  max_pooling2d_2 (MaxPooling  (None, 1, 1, 256)        0
#  2D)
#
#  flatten (Flatten)           (None, 256)               0
#
#  dense (Dense)               (None, 4096)              1052672
#
#  batch_normalization_5 (Batc  (None, 4096)             16384
#  hNormalization)
#
#  activation_5 (Activation)   (None, 4096)              0
#
#  dropout (Dropout)           (None, 4096)              0
#
#  dense_1 (Dense)             (None, 4096)              16781312
#
#  batch_normalization_6 (Batc  (None, 4096)             16384
#  hNormalization)
#
#  activation_6 (Activation)   (None, 4096)              0
#
#  dropout_1 (Dropout)         (None, 4096)              0
#
#  dense_2 (Dense)             (None, 10)                40970
#
#  batch_normalization_7 (Batc  (None, 10)               40
#  hNormalization)
#
#  activation_7 (Activation)   (None, 10)                0
#
# =================================================================
# Total params: 21,637,234
# Trainable params: 21,618,078
# Non-trainable params: 19,156
# _________________________________________________________________

# %%
# Compile the model
model.compile(optimizer=tf.keras.optimizers.SGD(learning_rate=0.001), 
              loss='categorical_crossentropy',
              metrics=['accuracy'])
# Train the model
# model.fit(train_images, train_labels, epochs=90, validation_data=(test_images, test_labels))

history = model.fit(train_images, train_labels, epochs=90, 
                    validation_data=(test_images, test_labels))
# Out:
# Epoch 1/90
# 1875/1875 [==============================] - 21s 10ms/step - loss: 0.8895 - accuracy: 0.7710 - val_loss: 0.5326 - val_accuracy: 0.8403
# Epoch 2/90
# 1875/1875 [==============================] - 18s 9ms/step - loss: 0.6626 - accuracy: 0.8403 - val_loss: 0.4503 - val_accuracy: 0.8671
# Epoch 3/90
# 1875/1875 [==============================] - 17s 9ms/step - loss: 0.5768 - accuracy: 0.8588 - val_loss: 0.4138 - val_accuracy: 0.8740
# Epoch 4/90
# 1875/1875 [==============================] - 16s 9ms/step - loss: 0.5242 - accuracy: 0.8681 - val_loss: 0.3918 - val_accuracy: 0.8791
# Epoch 5/90
# 1875/1875 [==============================] - 17s 9ms/step - loss: 0.4834 - accuracy: 0.8764 - val_loss: 0.3976 - val_accuracy: 0.8722
# Epoch 6/90
# 1875/1875 [==============================] - 18s 10ms/step - loss: 0.4472 - accuracy: 0.8835 - val_loss: 0.3748 - val_accuracy: 0.8787
# Epoch 7/90
# 1875/1875 [==============================] - 18s 10ms/step - loss: 0.4283 - accuracy: 0.8866 - val_loss: 0.3494 - val_accuracy: 0.8890
# Epoch 8/90
# 1875/1875 [==============================] - 18s 10ms/step - loss: 0.4008 - accuracy: 0.8926 - val_loss: 0.3798 - val_accuracy: 0.8774
# Epoch 9/90
# 1875/1875 [==============================] - 18s 10ms/step - loss: 0.3835 - accuracy: 0.8976 - val_loss: 0.3444 - val_accuracy: 0.8892
# Epoch 10/90
# 1875/1875 [==============================] - 18s 10ms/step - loss: 0.3609 - accuracy: 0.9034 - val_loss: 0.3431 - val_accuracy: 0.8877
# Epoch 11/90
# 1875/1875 [==============================] - 18s 10ms/step - loss: 0.3478 - accuracy: 0.9059 - val_loss: 0.3321 - val_accuracy: 0.8916
# Epoch 12/90
# 1875/1875 [==============================] - 19s 10ms/step - loss: 0.3343 - accuracy: 0.9086 - val_loss: 0.3965 - val_accuracy: 0.8795
# Epoch 13/90
# 1875/1875 [==============================] - 18s 10ms/step - loss: 0.3154 - accuracy: 0.9152 - val_loss: 0.3392 - val_accuracy: 0.8931
# Epoch 14/90
# 1875/1875 [==============================] - 19s 10ms/step - loss: 0.3050 - accuracy: 0.9169 - val_loss: 0.4182 - val_accuracy: 0.8680
# Epoch 15/90
# 1875/1875 [==============================] - 18s 10ms/step - loss: 0.2927 - accuracy: 0.9200 - val_loss: 0.3368 - val_accuracy: 0.8925
# Epoch 16/90
# 1875/1875 [==============================] - 18s 10ms/step - loss: 0.2800 - accuracy: 0.9238 - val_loss: 0.3370 - val_accuracy: 0.8925
# Epoch 17/90
# 1875/1875 [==============================] - 18s 10ms/step - loss: 0.2731 - accuracy: 0.9255 - val_loss: 0.3776 - val_accuracy: 0.8860
# Epoch 18/90
# 1875/1875 [==============================] - 18s 10ms/step - loss: 0.2623 - accuracy: 0.9287 - val_loss: 0.3539 - val_accuracy: 0.8949
# Epoch 19/90
# 1875/1875 [==============================] - 18s 9ms/step - loss: 0.2523 - accuracy: 0.9319 - val_loss: 0.3999 - val_accuracy: 0.8890
# Epoch 20/90
# 1875/1875 [==============================] - 18s 10ms/step - loss: 0.2429 - accuracy: 0.9366 - val_loss: 0.3774 - val_accuracy: 0.8874
# Epoch 21/90
# 1875/1875 [==============================] - 18s 10ms/step - loss: 0.2337 - accuracy: 0.9370 - val_loss: 0.3820 - val_accuracy: 0.8935
# Epoch 22/90
# 1875/1875 [==============================] - 18s 10ms/step - loss: 0.2239 - accuracy: 0.9394 - val_loss: 0.3842 - val_accuracy: 0.8884
# Epoch 23/90
# 1875/1875 [==============================] - 18s 10ms/step - loss: 0.2121 - accuracy: 0.9434 - val_loss: 0.3874 - val_accuracy: 0.8911
# Epoch 24/90
# 1875/1875 [==============================] - 18s 10ms/step - loss: 0.2059 - accuracy: 0.9464 - val_loss: 0.3639 - val_accuracy: 0.8929
# Epoch 25/90
# 1875/1875 [==============================] - 17s 9ms/step - loss: 0.1987 - accuracy: 0.9483 - val_loss: 0.4105 - val_accuracy: 0.8859
# Epoch 26/90
# 1875/1875 [==============================] - 17s 9ms/step - loss: 0.1883 - accuracy: 0.9516 - val_loss: 0.4140 - val_accuracy: 0.8886
# Epoch 27/90
# 1875/1875 [==============================] - 18s 10ms/step - loss: 0.1808 - accuracy: 0.9541 - val_loss: 0.3572 - val_accuracy: 0.8967
# Epoch 28/90
# 1875/1875 [==============================] - 18s 10ms/step - loss: 0.1708 - accuracy: 0.9575 - val_loss: 0.3956 - val_accuracy: 0.8906
# Epoch 29/90
# 1875/1875 [==============================] - 18s 10ms/step - loss: 0.1663 - accuracy: 0.9578 - val_loss: 0.4044 - val_accuracy: 0.8926
# Epoch 30/90
# 1875/1875 [==============================] - 18s 9ms/step - loss: 0.1635 - accuracy: 0.9588 - val_loss: 0.3897 - val_accuracy: 0.8951
# Epoch 31/90
# 1875/1875 [==============================] - 18s 10ms/step - loss: 0.1551 - accuracy: 0.9614 - val_loss: 0.3951 - val_accuracy: 0.8953
# Epoch 32/90
# 1875/1875 [==============================] - 16s 9ms/step - loss: 0.1445 - accuracy: 0.9645 - val_loss: 0.4338 - val_accuracy: 0.8880
# Epoch 33/90
# 1875/1875 [==============================] - 18s 9ms/step - loss: 0.1427 - accuracy: 0.9654 - val_loss: 0.3756 - val_accuracy: 0.8979
# Epoch 34/90
# 1875/1875 [==============================] - 15s 8ms/step - loss: 0.1396 - accuracy: 0.9660 - val_loss: 0.4180 - val_accuracy: 0.8896
# Epoch 35/90
# 1875/1875 [==============================] - 16s 8ms/step - loss: 0.1329 - accuracy: 0.9680 - val_loss: 0.3987 - val_accuracy: 0.8944
# Epoch 36/90
# 1875/1875 [==============================] - 20s 10ms/step - loss: 0.1300 - accuracy: 0.9688 - val_loss: 0.4180 - val_accuracy: 0.8937
# Epoch 37/90
# 1875/1875 [==============================] - 20s 11ms/step - loss: 0.1243 - accuracy: 0.9701 - val_loss: 0.3795 - val_accuracy: 0.9008
# Epoch 38/90
# 1875/1875 [==============================] - 21s 11ms/step - loss: 0.1174 - accuracy: 0.9724 - val_loss: 0.4263 - val_accuracy: 0.8947
# Epoch 39/90
# 1875/1875 [==============================] - 19s 10ms/step - loss: 0.1151 - accuracy: 0.9724 - val_loss: 0.4128 - val_accuracy: 0.8979
# Epoch 40/90
# 1875/1875 [==============================] - 28s 15ms/step - loss: 0.1100 - accuracy: 0.9754 - val_loss: 0.3873 - val_accuracy: 0.9030
# Epoch 41/90
# 1875/1875 [==============================] - 19s 10ms/step - loss: 0.1070 - accuracy: 0.9757 - val_loss: 0.6051 - val_accuracy: 0.8598
# Epoch 42/90
# 1875/1875 [==============================] - 16s 9ms/step - loss: 0.1031 - accuracy: 0.9761 - val_loss: 0.5029 - val_accuracy: 0.8777
# Epoch 43/90
# 1875/1875 [==============================] - 18s 10ms/step - loss: 0.1009 - accuracy: 0.9768 - val_loss: 0.4284 - val_accuracy: 0.8923
# Epoch 44/90
# 1875/1875 [==============================] - 15s 8ms/step - loss: 0.0959 - accuracy: 0.9788 - val_loss: 0.4164 - val_accuracy: 0.8949
# Epoch 45/90
# 1875/1875 [==============================] - 15s 8ms/step - loss: 0.0928 - accuracy: 0.9795 - val_loss: 0.4291 - val_accuracy: 0.8986
# Epoch 46/90
# 1875/1875 [==============================] - 15s 8ms/step - loss: 0.0901 - accuracy: 0.9803 - val_loss: 0.4316 - val_accuracy: 0.8980
# Epoch 47/90
# 1875/1875 [==============================] - 15s 8ms/step - loss: 0.0860 - accuracy: 0.9823 - val_loss: 0.4069 - val_accuracy: 0.9040
# Epoch 48/90
# 1875/1875 [==============================] - 15s 8ms/step - loss: 0.0880 - accuracy: 0.9810 - val_loss: 0.4494 - val_accuracy: 0.8961
# Epoch 49/90
# 1875/1875 [==============================] - 15s 8ms/step - loss: 0.0808 - accuracy: 0.9829 - val_loss: 0.5480 - val_accuracy: 0.8752
# Epoch 50/90
# 1875/1875 [==============================] - 15s 8ms/step - loss: 0.0770 - accuracy: 0.9844 - val_loss: 0.4569 - val_accuracy: 0.8930
# Epoch 51/90
# 1875/1875 [==============================] - 15s 8ms/step - loss: 0.0762 - accuracy: 0.9844 - val_loss: 0.4574 - val_accuracy: 0.8972
# Epoch 52/90
# 1875/1875 [==============================] - 15s 8ms/step - loss: 0.0752 - accuracy: 0.9841 - val_loss: 0.4381 - val_accuracy: 0.9008
# Epoch 53/90
# 1875/1875 [==============================] - 15s 8ms/step - loss: 0.0687 - accuracy: 0.9865 - val_loss: 0.5133 - val_accuracy: 0.8877
# Epoch 54/90
# 1875/1875 [==============================] - 15s 8ms/step - loss: 0.0713 - accuracy: 0.9849 - val_loss: 0.4954 - val_accuracy: 0.8857
# Epoch 55/90
# 1875/1875 [==============================] - 15s 8ms/step - loss: 0.0664 - accuracy: 0.9868 - val_loss: 0.4994 - val_accuracy: 0.8886
# Epoch 56/90
# 1875/1875 [==============================] - 15s 8ms/step - loss: 0.0682 - accuracy: 0.9864 - val_loss: 0.5283 - val_accuracy: 0.8831
# Epoch 57/90
# 1875/1875 [==============================] - 15s 8ms/step - loss: 0.0607 - accuracy: 0.9883 - val_loss: 0.4512 - val_accuracy: 0.9005
# Epoch 58/90
# 1875/1875 [==============================] - 15s 8ms/step - loss: 0.0616 - accuracy: 0.9880 - val_loss: 0.4570 - val_accuracy: 0.9016
# Epoch 59/90
# 1875/1875 [==============================] - 15s 8ms/step - loss: 0.0622 - accuracy: 0.9877 - val_loss: 0.4821 - val_accuracy: 0.8969
# Epoch 60/90
# 1875/1875 [==============================] - 15s 8ms/step - loss: 0.0562 - accuracy: 0.9892 - val_loss: 0.5423 - val_accuracy: 0.8931
# Epoch 61/90
# 1875/1875 [==============================] - 15s 8ms/step - loss: 0.0541 - accuracy: 0.9898 - val_loss: 0.4750 - val_accuracy: 0.8971
# Epoch 62/90
# 1875/1875 [==============================] - 15s 8ms/step - loss: 0.0548 - accuracy: 0.9896 - val_loss: 0.4897 - val_accuracy: 0.8957
# Epoch 63/90
# 1875/1875 [==============================] - 15s 8ms/step - loss: 0.0531 - accuracy: 0.9897 - val_loss: 0.6405 - val_accuracy: 0.8750
# Epoch 64/90
# 1875/1875 [==============================] - 15s 8ms/step - loss: 0.0532 - accuracy: 0.9904 - val_loss: 0.4953 - val_accuracy: 0.8950
# Epoch 65/90
# 1875/1875 [==============================] - 15s 8ms/step - loss: 0.0487 - accuracy: 0.9909 - val_loss: 0.4951 - val_accuracy: 0.8979
# Epoch 66/90
# 1875/1875 [==============================] - 15s 8ms/step - loss: 0.0527 - accuracy: 0.9899 - val_loss: 0.4930 - val_accuracy: 0.8979
# Epoch 67/90
# 1875/1875 [==============================] - 15s 8ms/step - loss: 0.0495 - accuracy: 0.9913 - val_loss: 0.4587 - val_accuracy: 0.9030
# Epoch 68/90
# 1875/1875 [==============================] - 15s 8ms/step - loss: 0.0480 - accuracy: 0.9917 - val_loss: 0.4817 - val_accuracy: 0.9013
# Epoch 69/90
# 1875/1875 [==============================] - 15s 8ms/step - loss: 0.0477 - accuracy: 0.9914 - val_loss: 0.4741 - val_accuracy: 0.9042
# Epoch 70/90
# 1875/1875 [==============================] - 15s 8ms/step - loss: 0.0451 - accuracy: 0.9920 - val_loss: 0.5094 - val_accuracy: 0.8970
# Epoch 71/90
# 1875/1875 [==============================] - 15s 8ms/step - loss: 0.0432 - accuracy: 0.9926 - val_loss: 0.4836 - val_accuracy: 0.9007
# Epoch 72/90
# 1875/1875 [==============================] - 15s 8ms/step - loss: 0.0419 - accuracy: 0.9927 - val_loss: 0.4717 - val_accuracy: 0.9022
# Epoch 73/90
# 1875/1875 [==============================] - 15s 8ms/step - loss: 0.0421 - accuracy: 0.9933 - val_loss: 0.5311 - val_accuracy: 0.8984
# Epoch 74/90
# 1875/1875 [==============================] - 15s 8ms/step - loss: 0.0380 - accuracy: 0.9940 - val_loss: 0.5113 - val_accuracy: 0.8942
# Epoch 75/90
# 1875/1875 [==============================] - 15s 8ms/step - loss: 0.0410 - accuracy: 0.9929 - val_loss: 0.5543 - val_accuracy: 0.8936
# Epoch 76/90
# 1875/1875 [==============================] - 15s 8ms/step - loss: 0.0404 - accuracy: 0.9930 - val_loss: 0.5169 - val_accuracy: 0.8968
# Epoch 77/90
# 1875/1875 [==============================] - 15s 8ms/step - loss: 0.0380 - accuracy: 0.9940 - val_loss: 0.5072 - val_accuracy: 0.8985
# Epoch 78/90
# 1875/1875 [==============================] - 15s 8ms/step - loss: 0.0396 - accuracy: 0.9935 - val_loss: 0.5120 - val_accuracy: 0.8990
# Epoch 79/90
# 1875/1875 [==============================] - 15s 8ms/step - loss: 0.0404 - accuracy: 0.9927 - val_loss: 0.4880 - val_accuracy: 0.9010
# Epoch 80/90
# 1875/1875 [==============================] - 15s 8ms/step - loss: 0.0339 - accuracy: 0.9946 - val_loss: 0.4950 - val_accuracy: 0.9041
# Epoch 81/90
# 1875/1875 [==============================] - 15s 8ms/step - loss: 0.0342 - accuracy: 0.9948 - val_loss: 0.5202 - val_accuracy: 0.8954
# Epoch 82/90
# 1875/1875 [==============================] - 15s 8ms/step - loss: 0.0326 - accuracy: 0.9954 - val_loss: 0.4837 - val_accuracy: 0.9016
# Epoch 83/90
# 1875/1875 [==============================] - 15s 8ms/step - loss: 0.0301 - accuracy: 0.9962 - val_loss: 0.4900 - val_accuracy: 0.9032
# Epoch 84/90
# 1875/1875 [==============================] - 15s 8ms/step - loss: 0.0287 - accuracy: 0.9964 - val_loss: 0.4927 - val_accuracy: 0.9046
# Epoch 85/90
# 1875/1875 [==============================] - 15s 8ms/step - loss: 0.0337 - accuracy: 0.9945 - val_loss: 0.4874 - val_accuracy: 0.9008
# Epoch 86/90
# 1875/1875 [==============================] - 15s 8ms/step - loss: 0.0292 - accuracy: 0.9958 - val_loss: 0.5273 - val_accuracy: 0.8995
# Epoch 87/90
# 1875/1875 [==============================] - 15s 8ms/step - loss: 0.0264 - accuracy: 0.9966 - val_loss: 0.4871 - val_accuracy: 0.9057
# Epoch 88/90
# 1875/1875 [==============================] - 15s 8ms/step - loss: 0.0295 - accuracy: 0.9955 - val_loss: 0.4896 - val_accuracy: 0.9039
# Epoch 89/90
# 1875/1875 [==============================] - 15s 8ms/step - loss: 0.0301 - accuracy: 0.9954 - val_loss: 0.5390 - val_accuracy: 0.8998
# Epoch 90/90
# 1875/1875 [==============================] - 15s 8ms/step - loss: 0.0319 - accuracy: 0.9945 - val_loss: 0.5811 - val_accuracy: 0.8895

# %%
#fashion mnist, tanh

accuracy = model.evaluate(test_images, test_labels, verbose=1)
print('Test loss:', accuracy[0])
print('Test accuracy:', accuracy[1])
# Out:
# 313/313 [==============================] - 1s 3ms/step - loss: 0.5811 - accuracy: 0.8895
# Test loss: 0.5810701251029968
# Test accuracy: 0.8895000219345093

# %%
import matplotlib.pyplot as plt

# Plot training & validation accuracy values
plt.figure(figsize=(12, 12))

plt.subplot(2, 1, 1)
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')

# Plot training & validation loss values
plt.subplot(2, 1, 2)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')

plt.subplots_adjust(hspace=0.3)
plt.show()
