# %%
from tensorflow.python.client import device_lib 
print(device_lib.list_local_devices())
# Out:
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 4508222738330577721
# xla_global_id: -1
# , name: "/device:GPU:0"
# device_type: "GPU"
# memory_limit: 5748293632
# locality {
#   bus_id: 1
#   links {
#   }
# }
# incarnation: 11557487803907489807
# physical_device_desc: "device: 0, name: NVIDIA GeForce RTX 3060 Ti, pci bus id: 0000:2b:00.0, compute capability: 8.6"
# xla_global_id: 416903419
# ]

# %%
import tensorflow as tf
from tensorflow import keras
from keras.models import Sequential
from keras.layers import Dense, Activation, Dropout, Flatten, Conv2D, MaxPooling2D, BatchNormalization
from keras.utils import to_categorical

# %%
# Fashion MNIST 데이터셋 로드
fashion_mnist = keras.datasets.fashion_mnist
(train_images, train_labels), (test_images, test_labels) = fashion_mnist.load_data()

# 데이터 전처리
train_images = train_images.reshape(-1, 28, 28, 1)
test_images = test_images.reshape(-1, 28, 28, 1)
train_images = train_images / 255.0
test_images = test_images / 255.0
train_labels = to_categorical(train_labels)
test_labels = to_categorical(test_labels)

print(train_labels.shape, test_labels.shape)

# 데이터 로더 생성
#batch_size = 64
#train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
#test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)
# Out:
# (60000, 10) (10000, 10)

# %%
# AlexNet model architecture
model = Sequential()

# 1st Convolutional Layer
model.add(Conv2D(filters=96, input_shape=(28,28,1), kernel_size=(11,11), strides=(4,4), padding='same')) 
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2,2), strides=(2,2), padding='same'))

# 2nd Convolutional Layer
model.add(Conv2D(filters=256, kernel_size=(5,5), strides=(1,1), padding='same')) 
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2,2), strides=(2,2), padding='same'))

# 3rd Convolutional Layer
model.add(Conv2D(filters=384, kernel_size=(3,3), strides=(1,1), padding='same')) 
model.add(BatchNormalization())
model.add(Activation('relu'))

# 4th Convolutional Layer
model.add(Conv2D(filters=384, kernel_size=(3,3), strides=(1,1), padding='same')) 
model.add(BatchNormalization())
model.add(Activation('relu'))

# 5th Convolutional Layer
model.add(Conv2D(filters=256, kernel_size=(3,3), strides=(1,1), padding='same')) 
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2,2), strides=(2,2), padding='same'))

# Fully Connected layer
model.add(Flatten())
model.add(Dense(4096, input_shape=(32,32,3))) 
model.add(BatchNormalization()) 
model.add(Activation('relu'))

# Add Dropout to prevent overfitting
model.add(Dropout(0.1))

# Fully Connected Layer
model.add(Dense(4096)) 
model.add(BatchNormalization()) 
model.add(Activation('relu')) # Add Dropout 
model.add(Dropout(0.1))

# Output Layer
model.add(Dense(10)) 
model.add(BatchNormalization()) 
model.add(Activation('softmax'))

# Model Summary
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 7, 7, 96)          11712
#
#  batch_normalization (BatchN  (None, 7, 7, 96)         384
#  ormalization)
#
#  activation (Activation)     (None, 7, 7, 96)          0
#
#  max_pooling2d (MaxPooling2D  (None, 4, 4, 96)         0
#  )
#
#  conv2d_1 (Conv2D)           (None, 4, 4, 256)         614656
#
#  batch_normalization_1 (Batc  (None, 4, 4, 256)        1024
#  hNormalization)
#
#  activation_1 (Activation)   (None, 4, 4, 256)         0
#
#  max_pooling2d_1 (MaxPooling  (None, 2, 2, 256)        0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 2, 2, 384)         885120
#
#  batch_normalization_2 (Batc  (None, 2, 2, 384)        1536
#  hNormalization)
#
#  activation_2 (Activation)   (None, 2, 2, 384)         0
#
#  conv2d_3 (Conv2D)           (None, 2, 2, 384)         1327488
#
#  batch_normalization_3 (Batc  (None, 2, 2, 384)        1536
#  hNormalization)
#
#  activation_3 (Activation)   (None, 2, 2, 384)         0
#
#  conv2d_4 (Conv2D)           (None, 2, 2, 256)         884992
#
#  batch_normalization_4 (Batc  (None, 2, 2, 256)        1024
#  hNormalization)
#
#  activation_4 (Activation)   (None, 2, 2, 256)         0
#
#  max_pooling2d_2 (MaxPooling  (None, 1, 1, 256)        0
#  2D)
#
#  flatten (Flatten)           (None, 256)               0
#
#  dense (Dense)               (None, 4096)              1052672
#
#  batch_normalization_5 (Batc  (None, 4096)             16384
#  hNormalization)
#
#  activation_5 (Activation)   (None, 4096)              0
#
#  dropout (Dropout)           (None, 4096)              0
#
#  dense_1 (Dense)             (None, 4096)              16781312
#
#  batch_normalization_6 (Batc  (None, 4096)             16384
#  hNormalization)
#
#  activation_6 (Activation)   (None, 4096)              0
#
#  dropout_1 (Dropout)         (None, 4096)              0
#
#  dense_2 (Dense)             (None, 10)                40970
#
#  batch_normalization_7 (Batc  (None, 10)               40
#  hNormalization)
#
#  activation_7 (Activation)   (None, 10)                0
#
# =================================================================
# Total params: 21,637,234
# Trainable params: 21,618,078
# Non-trainable params: 19,156
# _________________________________________________________________

# %%
# Compile the model
model.compile(optimizer=tf.keras.optimizers.SGD(learning_rate=0.001), 
              loss='categorical_crossentropy',
              metrics=['accuracy'])
# Train the model
# model.fit(train_images, train_labels, epochs=90, validation_data=(test_images, test_labels))

history = model.fit(train_images, train_labels, epochs=90, 
                    validation_data=(test_images, test_labels))
# Out:
# Epoch 1/90
# 1875/1875 [==============================] - 25s 8ms/step - loss: 0.8136 - accuracy: 0.7988 - val_loss: 0.5834 - val_accuracy: 0.8535
# Epoch 2/90
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.6271 - accuracy: 0.8493 - val_loss: 0.5014 - val_accuracy: 0.8648
# Epoch 3/90
# 1875/1875 [==============================] - 14s 8ms/step - loss: 0.5493 - accuracy: 0.8668 - val_loss: 0.4500 - val_accuracy: 0.8775
# Epoch 4/90
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.4945 - accuracy: 0.8775 - val_loss: 0.4295 - val_accuracy: 0.8749
# Epoch 5/90
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.4560 - accuracy: 0.8855 - val_loss: 0.3942 - val_accuracy: 0.8873
# Epoch 6/90
# 1875/1875 [==============================] - 14s 8ms/step - loss: 0.4220 - accuracy: 0.8922 - val_loss: 0.3761 - val_accuracy: 0.8889
# Epoch 7/90
# 1875/1875 [==============================] - 14s 8ms/step - loss: 0.3966 - accuracy: 0.8966 - val_loss: 0.3754 - val_accuracy: 0.8894
# Epoch 8/90
# 1875/1875 [==============================] - 14s 8ms/step - loss: 0.3764 - accuracy: 0.9005 - val_loss: 0.3783 - val_accuracy: 0.8825
# Epoch 9/90
# 1875/1875 [==============================] - 14s 8ms/step - loss: 0.3464 - accuracy: 0.9097 - val_loss: 0.3917 - val_accuracy: 0.8779
# Epoch 10/90
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.3312 - accuracy: 0.9115 - val_loss: 0.3409 - val_accuracy: 0.8945
# Epoch 11/90
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.3178 - accuracy: 0.9150 - val_loss: 0.3281 - val_accuracy: 0.8973
# Epoch 12/90
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.2967 - accuracy: 0.9210 - val_loss: 0.3404 - val_accuracy: 0.8915
# Epoch 13/90
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.2855 - accuracy: 0.9237 - val_loss: 0.3312 - val_accuracy: 0.8963
# Epoch 14/90
# 1875/1875 [==============================] - 14s 8ms/step - loss: 0.2734 - accuracy: 0.9265 - val_loss: 0.3302 - val_accuracy: 0.8979
# Epoch 15/90
# 1875/1875 [==============================] - 14s 8ms/step - loss: 0.2582 - accuracy: 0.9313 - val_loss: 0.3373 - val_accuracy: 0.8948
# Epoch 16/90
# 1875/1875 [==============================] - 14s 8ms/step - loss: 0.2491 - accuracy: 0.9341 - val_loss: 0.3439 - val_accuracy: 0.8962
# Epoch 17/90
# 1875/1875 [==============================] - 14s 8ms/step - loss: 0.2328 - accuracy: 0.9387 - val_loss: 0.3546 - val_accuracy: 0.8920
# Epoch 18/90
# 1875/1875 [==============================] - 14s 8ms/step - loss: 0.2235 - accuracy: 0.9423 - val_loss: 0.3845 - val_accuracy: 0.8824
# Epoch 19/90
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.2159 - accuracy: 0.9430 - val_loss: 0.3504 - val_accuracy: 0.8935
# Epoch 20/90
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.2060 - accuracy: 0.9463 - val_loss: 0.3701 - val_accuracy: 0.8831
# Epoch 21/90
# 1875/1875 [==============================] - 14s 8ms/step - loss: 0.1961 - accuracy: 0.9495 - val_loss: 0.3549 - val_accuracy: 0.8925
# Epoch 22/90
# 1875/1875 [==============================] - 14s 8ms/step - loss: 0.1868 - accuracy: 0.9518 - val_loss: 0.3461 - val_accuracy: 0.8962
# Epoch 23/90
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.1794 - accuracy: 0.9550 - val_loss: 0.3231 - val_accuracy: 0.9034
# Epoch 24/90
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.1702 - accuracy: 0.9568 - val_loss: 0.3619 - val_accuracy: 0.8915
# Epoch 25/90
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.1616 - accuracy: 0.9591 - val_loss: 0.3665 - val_accuracy: 0.8925
# Epoch 26/90
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.1535 - accuracy: 0.9622 - val_loss: 0.3447 - val_accuracy: 0.9016
# Epoch 27/90
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.1468 - accuracy: 0.9641 - val_loss: 0.3391 - val_accuracy: 0.9012
# Epoch 28/90
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.1388 - accuracy: 0.9670 - val_loss: 0.3469 - val_accuracy: 0.9008
# Epoch 29/90
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.1359 - accuracy: 0.9668 - val_loss: 0.3541 - val_accuracy: 0.8966
# Epoch 30/90
# 1875/1875 [==============================] - 14s 8ms/step - loss: 0.1296 - accuracy: 0.9689 - val_loss: 0.3609 - val_accuracy: 0.8965
# Epoch 31/90
# 1875/1875 [==============================] - 14s 8ms/step - loss: 0.1248 - accuracy: 0.9697 - val_loss: 0.3455 - val_accuracy: 0.9019
# Epoch 32/90
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.1177 - accuracy: 0.9727 - val_loss: 0.3442 - val_accuracy: 0.8995
# Epoch 33/90
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.1171 - accuracy: 0.9725 - val_loss: 0.3441 - val_accuracy: 0.9038
# Epoch 34/90
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.1078 - accuracy: 0.9761 - val_loss: 0.3806 - val_accuracy: 0.8933
# Epoch 35/90
# 1875/1875 [==============================] - 14s 8ms/step - loss: 0.1048 - accuracy: 0.9763 - val_loss: 0.3945 - val_accuracy: 0.8945
# Epoch 36/90
# 1875/1875 [==============================] - 14s 8ms/step - loss: 0.0970 - accuracy: 0.9784 - val_loss: 0.4434 - val_accuracy: 0.8804
# Epoch 37/90
# 1875/1875 [==============================] - 14s 8ms/step - loss: 0.0967 - accuracy: 0.9786 - val_loss: 0.3643 - val_accuracy: 0.9022
# Epoch 38/90
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.0904 - accuracy: 0.9801 - val_loss: 0.3741 - val_accuracy: 0.8984
# Epoch 39/90
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.0871 - accuracy: 0.9813 - val_loss: 0.3479 - val_accuracy: 0.9037
# Epoch 40/90
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.0846 - accuracy: 0.9820 - val_loss: 0.4223 - val_accuracy: 0.8925
# Epoch 41/90
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.0817 - accuracy: 0.9826 - val_loss: 0.3783 - val_accuracy: 0.8986
# Epoch 42/90
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.0742 - accuracy: 0.9857 - val_loss: 0.3994 - val_accuracy: 0.8951
# Epoch 43/90
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.0728 - accuracy: 0.9855 - val_loss: 0.3676 - val_accuracy: 0.9047
# Epoch 44/90
# 1875/1875 [==============================] - 14s 8ms/step - loss: 0.0713 - accuracy: 0.9858 - val_loss: 0.3955 - val_accuracy: 0.8972
# Epoch 45/90
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.0688 - accuracy: 0.9859 - val_loss: 0.3716 - val_accuracy: 0.9017
# Epoch 46/90
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.0680 - accuracy: 0.9863 - val_loss: 0.4110 - val_accuracy: 0.8931
# Epoch 47/90
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.0647 - accuracy: 0.9872 - val_loss: 0.3958 - val_accuracy: 0.8981
# Epoch 48/90
# 1875/1875 [==============================] - 14s 8ms/step - loss: 0.0621 - accuracy: 0.9875 - val_loss: 0.4054 - val_accuracy: 0.8983
# Epoch 49/90
# 1875/1875 [==============================] - 14s 8ms/step - loss: 0.0601 - accuracy: 0.9884 - val_loss: 0.4038 - val_accuracy: 0.8965
# Epoch 50/90
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.0561 - accuracy: 0.9898 - val_loss: 0.4114 - val_accuracy: 0.8971
# Epoch 51/90
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.0524 - accuracy: 0.9914 - val_loss: 0.3913 - val_accuracy: 0.9022
# Epoch 52/90
# 1875/1875 [==============================] - 14s 8ms/step - loss: 0.0522 - accuracy: 0.9906 - val_loss: 0.4266 - val_accuracy: 0.8919
# Epoch 53/90
# 1875/1875 [==============================] - 14s 8ms/step - loss: 0.0501 - accuracy: 0.9912 - val_loss: 0.4126 - val_accuracy: 0.8950
# Epoch 54/90
# 1875/1875 [==============================] - 14s 8ms/step - loss: 0.0480 - accuracy: 0.9921 - val_loss: 0.3929 - val_accuracy: 0.8995
# Epoch 55/90
# 1875/1875 [==============================] - 14s 8ms/step - loss: 0.0491 - accuracy: 0.9914 - val_loss: 0.4021 - val_accuracy: 0.9005
# Epoch 56/90
# 1875/1875 [==============================] - 14s 8ms/step - loss: 0.0432 - accuracy: 0.9927 - val_loss: 0.3815 - val_accuracy: 0.9047
# Epoch 57/90
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.0420 - accuracy: 0.9935 - val_loss: 0.3895 - val_accuracy: 0.9029
# Epoch 58/90
# 1875/1875 [==============================] - 14s 8ms/step - loss: 0.0396 - accuracy: 0.9941 - val_loss: 0.4112 - val_accuracy: 0.8982
# Epoch 59/90
# 1875/1875 [==============================] - 15s 8ms/step - loss: 0.0411 - accuracy: 0.9938 - val_loss: 0.3999 - val_accuracy: 0.9025
# Epoch 60/90
# 1875/1875 [==============================] - 14s 8ms/step - loss: 0.0388 - accuracy: 0.9942 - val_loss: 0.4278 - val_accuracy: 0.8989
# Epoch 61/90
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.0404 - accuracy: 0.9936 - val_loss: 0.4183 - val_accuracy: 0.8973
# Epoch 62/90
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.0378 - accuracy: 0.9944 - val_loss: 0.4550 - val_accuracy: 0.8955
# Epoch 63/90
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.0372 - accuracy: 0.9941 - val_loss: 0.3920 - val_accuracy: 0.9047
# Epoch 64/90
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.0329 - accuracy: 0.9957 - val_loss: 0.4366 - val_accuracy: 0.8971
# Epoch 65/90
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.0321 - accuracy: 0.9958 - val_loss: 0.4765 - val_accuracy: 0.8887
# Epoch 66/90
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.0338 - accuracy: 0.9954 - val_loss: 0.4071 - val_accuracy: 0.9044
# Epoch 67/90
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.0295 - accuracy: 0.9965 - val_loss: 0.4041 - val_accuracy: 0.9021
# Epoch 68/90
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.0281 - accuracy: 0.9967 - val_loss: 0.3983 - val_accuracy: 0.9059
# Epoch 69/90
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.0280 - accuracy: 0.9966 - val_loss: 0.3934 - val_accuracy: 0.9078
# Epoch 70/90
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.0287 - accuracy: 0.9963 - val_loss: 0.4040 - val_accuracy: 0.9061
# Epoch 71/90
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.0271 - accuracy: 0.9967 - val_loss: 0.4048 - val_accuracy: 0.9034
# Epoch 72/90
# 1875/1875 [==============================] - 14s 8ms/step - loss: 0.0237 - accuracy: 0.9975 - val_loss: 0.4024 - val_accuracy: 0.9026
# Epoch 73/90
# 1875/1875 [==============================] - 14s 8ms/step - loss: 0.0297 - accuracy: 0.9959 - val_loss: 0.3896 - val_accuracy: 0.9086
# Epoch 74/90
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.0266 - accuracy: 0.9969 - val_loss: 0.3995 - val_accuracy: 0.9038
# Epoch 75/90
# 1875/1875 [==============================] - 14s 8ms/step - loss: 0.0235 - accuracy: 0.9974 - val_loss: 0.4367 - val_accuracy: 0.9009
# Epoch 76/90
# 1875/1875 [==============================] - 14s 8ms/step - loss: 0.0276 - accuracy: 0.9961 - val_loss: 0.4123 - val_accuracy: 0.9034
# Epoch 77/90
# 1875/1875 [==============================] - 14s 8ms/step - loss: 0.0266 - accuracy: 0.9965 - val_loss: 0.4072 - val_accuracy: 0.9063
# Epoch 78/90
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.0245 - accuracy: 0.9973 - val_loss: 0.4059 - val_accuracy: 0.9073
# Epoch 79/90
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.0234 - accuracy: 0.9975 - val_loss: 0.4063 - val_accuracy: 0.9060
# Epoch 80/90
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.0208 - accuracy: 0.9980 - val_loss: 0.5316 - val_accuracy: 0.8824
# Epoch 81/90
# 1875/1875 [==============================] - 13s 7ms/step - loss: 0.0207 - accuracy: 0.9981 - val_loss: 0.4029 - val_accuracy: 0.9089
# Epoch 82/90
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.0207 - accuracy: 0.9980 - val_loss: 0.4136 - val_accuracy: 0.9049
# Epoch 83/90
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.0246 - accuracy: 0.9968 - val_loss: 0.4187 - val_accuracy: 0.9029
# Epoch 84/90
# 1875/1875 [==============================] - 14s 8ms/step - loss: 0.0206 - accuracy: 0.9979 - val_loss: 0.4003 - val_accuracy: 0.9090
# Epoch 85/90
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.0219 - accuracy: 0.9973 - val_loss: 0.4073 - val_accuracy: 0.9035
# Epoch 86/90
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.0223 - accuracy: 0.9972 - val_loss: 0.4237 - val_accuracy: 0.9051
# Epoch 87/90
# 1875/1875 [==============================] - 14s 8ms/step - loss: 0.0207 - accuracy: 0.9977 - val_loss: 0.4231 - val_accuracy: 0.9048
# Epoch 88/90
# 1875/1875 [==============================] - 14s 8ms/step - loss: 0.0192 - accuracy: 0.9980 - val_loss: 0.4031 - val_accuracy: 0.9073
# Epoch 89/90
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.0206 - accuracy: 0.9975 - val_loss: 0.4088 - val_accuracy: 0.9047
# Epoch 90/90
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.0169 - accuracy: 0.9989 - val_loss: 0.4328 - val_accuracy: 0.9018

# %%
#fashion mnist, dropout 0.1

accuracy = model.evaluate(test_images, test_labels, verbose=1)
print('Test loss:', accuracy[0])
print('Test accuracy:', accuracy[1])
# Out:
# 313/313 [==============================] - 1s 3ms/step - loss: 0.4328 - accuracy: 0.9018
# Test loss: 0.432832807302475
# Test accuracy: 0.9017999768257141

# %%
import matplotlib.pyplot as plt

# Plot training & validation accuracy values
plt.figure(figsize=(12, 12))

plt.subplot(2, 1, 1)
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')

# Plot training & validation loss values
plt.subplot(2, 1, 2)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')

plt.subplots_adjust(hspace=0.3)
plt.show()
