# %%
from tensorflow.python.client import device_lib 
print(device_lib.list_local_devices())
# Out:
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 11455172380497646482
# xla_global_id: -1
# , name: "/device:GPU:0"
# device_type: "GPU"
# memory_limit: 5748293632
# locality {
#   bus_id: 1
#   links {
#   }
# }
# incarnation: 6241742774224530645
# physical_device_desc: "device: 0, name: NVIDIA GeForce RTX 3060 Ti, pci bus id: 0000:2b:00.0, compute capability: 8.6"
# xla_global_id: 416903419
# ]

# %%
import tensorflow as tf
from tensorflow import keras
from keras.models import Sequential
from keras.layers import Dense, Activation, Dropout, Flatten, Conv2D, MaxPooling2D, BatchNormalization
from keras.utils import to_categorical

# %%
# Fashion MNIST 데이터셋 로드
fashion_mnist = keras.datasets.fashion_mnist
(train_images, train_labels), (test_images, test_labels) = fashion_mnist.load_data()

# 데이터 전처리
train_images = train_images.reshape(-1, 28, 28, 1)
test_images = test_images.reshape(-1, 28, 28, 1)
train_images = train_images / 255.0
test_images = test_images / 255.0
train_labels = to_categorical(train_labels)
test_labels = to_categorical(test_labels)

print(train_labels.shape, test_labels.shape)

# 데이터 로더 생성
#batch_size = 64
#train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
#test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)
# Out:
# (60000, 10) (10000, 10)

# %%
# AlexNet model architecture
model = Sequential()

# 1st Convolutional Layer
model.add(Conv2D(filters=96, input_shape=(28,28,1), kernel_size=(11,11), strides=(4,4), padding='same')) 
model.add(BatchNormalization())
model.add(Activation('swish'))
model.add(MaxPooling2D(pool_size=(2,2), strides=(2,2), padding='same'))

# 2nd Convolutional Layer
model.add(Conv2D(filters=256, kernel_size=(5,5), strides=(1,1), padding='same')) 
model.add(BatchNormalization())
model.add(Activation('swish'))
model.add(MaxPooling2D(pool_size=(2,2), strides=(2,2), padding='same'))

# 3rd Convolutional Layer
model.add(Conv2D(filters=384, kernel_size=(3,3), strides=(1,1), padding='same')) 
model.add(BatchNormalization())
model.add(Activation('swish'))

# 4th Convolutional Layer
model.add(Conv2D(filters=384, kernel_size=(3,3), strides=(1,1), padding='same')) 
model.add(BatchNormalization())
model.add(Activation('swish'))

# 5th Convolutional Layer
model.add(Conv2D(filters=256, kernel_size=(3,3), strides=(1,1), padding='same')) 
model.add(BatchNormalization())
model.add(Activation('swish'))
model.add(MaxPooling2D(pool_size=(2,2), strides=(2,2), padding='same'))

# Fully Connected layer
model.add(Flatten())
model.add(Dense(4096, input_shape=(32,32,3))) 
model.add(BatchNormalization()) 
model.add(Activation('swish'))

# Add Dropout to prevent overfitting
model.add(Dropout(0.5))

# Fully Connected Layer
model.add(Dense(4096)) 
model.add(BatchNormalization()) 
model.add(Activation('swish')) # Add Dropout 
model.add(Dropout(0.5))

# Output Layer
model.add(Dense(10)) 
model.add(BatchNormalization()) 
model.add(Activation('softmax'))

# Model Summary
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 7, 7, 96)          11712
#
#  batch_normalization (BatchN  (None, 7, 7, 96)         384
#  ormalization)
#
#  activation (Activation)     (None, 7, 7, 96)          0
#
#  max_pooling2d (MaxPooling2D  (None, 4, 4, 96)         0
#  )
#
#  conv2d_1 (Conv2D)           (None, 4, 4, 256)         614656
#
#  batch_normalization_1 (Batc  (None, 4, 4, 256)        1024
#  hNormalization)
#
#  activation_1 (Activation)   (None, 4, 4, 256)         0
#
#  max_pooling2d_1 (MaxPooling  (None, 2, 2, 256)        0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 2, 2, 384)         885120
#
#  batch_normalization_2 (Batc  (None, 2, 2, 384)        1536
#  hNormalization)
#
#  activation_2 (Activation)   (None, 2, 2, 384)         0
#
#  conv2d_3 (Conv2D)           (None, 2, 2, 384)         1327488
#
#  batch_normalization_3 (Batc  (None, 2, 2, 384)        1536
#  hNormalization)
#
#  activation_3 (Activation)   (None, 2, 2, 384)         0
#
#  conv2d_4 (Conv2D)           (None, 2, 2, 256)         884992
#
#  batch_normalization_4 (Batc  (None, 2, 2, 256)        1024
#  hNormalization)
#
#  activation_4 (Activation)   (None, 2, 2, 256)         0
#
#  max_pooling2d_2 (MaxPooling  (None, 1, 1, 256)        0
#  2D)
#
#  flatten (Flatten)           (None, 256)               0
#
#  dense (Dense)               (None, 4096)              1052672
#
#  batch_normalization_5 (Batc  (None, 4096)             16384
#  hNormalization)
#
#  activation_5 (Activation)   (None, 4096)              0
#
#  dropout (Dropout)           (None, 4096)              0
#
#  dense_1 (Dense)             (None, 4096)              16781312
#
#  batch_normalization_6 (Batc  (None, 4096)             16384
#  hNormalization)
#
#  activation_6 (Activation)   (None, 4096)              0
#
#  dropout_1 (Dropout)         (None, 4096)              0
#
#  dense_2 (Dense)             (None, 10)                40970
#
#  batch_normalization_7 (Batc  (None, 10)               40
#  hNormalization)
#
#  activation_7 (Activation)   (None, 10)                0
#
# =================================================================
# Total params: 21,637,234
# Trainable params: 21,618,078
# Non-trainable params: 19,156
# _________________________________________________________________

# %%
# Compile the model
model.compile(optimizer=tf.keras.optimizers.SGD(learning_rate=0.001), 
              loss='categorical_crossentropy',
              metrics=['accuracy'])
# Train the model
# model.fit(train_images, train_labels, epochs=90, validation_data=(test_images, test_labels))

history = model.fit(train_images, train_labels, epochs=90, 
                    validation_data=(test_images, test_labels))
# Out:
# Epoch 1/90
# 1875/1875 [==============================] - 18s 8ms/step - loss: 0.9354 - accuracy: 0.7581 - val_loss: 0.6340 - val_accuracy: 0.8397
# Epoch 2/90
# 1875/1875 [==============================] - 15s 8ms/step - loss: 0.6852 - accuracy: 0.8371 - val_loss: 0.5341 - val_accuracy: 0.8608
# Epoch 3/90
# 1875/1875 [==============================] - 14s 8ms/step - loss: 0.5942 - accuracy: 0.8561 - val_loss: 0.4616 - val_accuracy: 0.8749
# Epoch 4/90
# 1875/1875 [==============================] - 15s 8ms/step - loss: 0.5327 - accuracy: 0.8680 - val_loss: 0.4295 - val_accuracy: 0.8814
# Epoch 5/90
# 1875/1875 [==============================] - 15s 8ms/step - loss: 0.4866 - accuracy: 0.8778 - val_loss: 0.4017 - val_accuracy: 0.8845
# Epoch 6/90
# 1875/1875 [==============================] - 14s 8ms/step - loss: 0.4543 - accuracy: 0.8839 - val_loss: 0.3812 - val_accuracy: 0.8893
# Epoch 7/90
# 1875/1875 [==============================] - 14s 8ms/step - loss: 0.4220 - accuracy: 0.8910 - val_loss: 0.3941 - val_accuracy: 0.8776
# Epoch 8/90
# 1875/1875 [==============================] - 15s 8ms/step - loss: 0.3998 - accuracy: 0.8954 - val_loss: 0.3855 - val_accuracy: 0.8816
# Epoch 9/90
# 1875/1875 [==============================] - 15s 8ms/step - loss: 0.3775 - accuracy: 0.9002 - val_loss: 0.3431 - val_accuracy: 0.8958
# Epoch 10/90
# 1875/1875 [==============================] - 15s 8ms/step - loss: 0.3534 - accuracy: 0.9060 - val_loss: 0.3398 - val_accuracy: 0.8959
# Epoch 11/90
# 1875/1875 [==============================] - 14s 8ms/step - loss: 0.3379 - accuracy: 0.9109 - val_loss: 0.3496 - val_accuracy: 0.8930
# Epoch 12/90
# 1875/1875 [==============================] - 15s 8ms/step - loss: 0.3246 - accuracy: 0.9132 - val_loss: 0.3275 - val_accuracy: 0.8985
# Epoch 13/90
# 1875/1875 [==============================] - 15s 8ms/step - loss: 0.3104 - accuracy: 0.9171 - val_loss: 0.3651 - val_accuracy: 0.8834
# Epoch 14/90
# 1875/1875 [==============================] - 14s 8ms/step - loss: 0.2939 - accuracy: 0.9212 - val_loss: 0.3195 - val_accuracy: 0.8982
# Epoch 15/90
# 1875/1875 [==============================] - 15s 8ms/step - loss: 0.2817 - accuracy: 0.9251 - val_loss: 0.3538 - val_accuracy: 0.8887
# Epoch 16/90
# 1875/1875 [==============================] - 15s 8ms/step - loss: 0.2663 - accuracy: 0.9303 - val_loss: 0.3261 - val_accuracy: 0.8977
# Epoch 17/90
# 1875/1875 [==============================] - 15s 8ms/step - loss: 0.2609 - accuracy: 0.9305 - val_loss: 0.3195 - val_accuracy: 0.9009
# Epoch 18/90
# 1875/1875 [==============================] - 15s 8ms/step - loss: 0.2433 - accuracy: 0.9369 - val_loss: 0.3194 - val_accuracy: 0.8994
# Epoch 19/90
# 1875/1875 [==============================] - 15s 8ms/step - loss: 0.2328 - accuracy: 0.9398 - val_loss: 0.3259 - val_accuracy: 0.8980
# Epoch 20/90
# 1875/1875 [==============================] - 15s 8ms/step - loss: 0.2239 - accuracy: 0.9418 - val_loss: 0.3212 - val_accuracy: 0.8993
# Epoch 21/90
# 1875/1875 [==============================] - 15s 8ms/step - loss: 0.2119 - accuracy: 0.9461 - val_loss: 0.3400 - val_accuracy: 0.8938
# Epoch 22/90
# 1875/1875 [==============================] - 15s 8ms/step - loss: 0.2038 - accuracy: 0.9479 - val_loss: 0.3606 - val_accuracy: 0.8913
# Epoch 23/90
# 1875/1875 [==============================] - 15s 8ms/step - loss: 0.1933 - accuracy: 0.9512 - val_loss: 0.3475 - val_accuracy: 0.8958
# Epoch 24/90
# 1875/1875 [==============================] - 15s 8ms/step - loss: 0.1833 - accuracy: 0.9535 - val_loss: 0.3542 - val_accuracy: 0.8965
# Epoch 25/90
# 1875/1875 [==============================] - 15s 8ms/step - loss: 0.1731 - accuracy: 0.9570 - val_loss: 0.3517 - val_accuracy: 0.8950
# Epoch 26/90
# 1875/1875 [==============================] - 15s 8ms/step - loss: 0.1683 - accuracy: 0.9581 - val_loss: 0.3583 - val_accuracy: 0.8948
# Epoch 27/90
# 1875/1875 [==============================] - 15s 8ms/step - loss: 0.1583 - accuracy: 0.9622 - val_loss: 0.3240 - val_accuracy: 0.9059
# Epoch 28/90
# 1875/1875 [==============================] - 15s 8ms/step - loss: 0.1538 - accuracy: 0.9630 - val_loss: 0.3602 - val_accuracy: 0.8972
# Epoch 29/90
# 1875/1875 [==============================] - 15s 8ms/step - loss: 0.1468 - accuracy: 0.9649 - val_loss: 0.3485 - val_accuracy: 0.8996
# Epoch 30/90
# 1875/1875 [==============================] - 15s 8ms/step - loss: 0.1392 - accuracy: 0.9678 - val_loss: 0.3475 - val_accuracy: 0.9036
# Epoch 31/90
# 1875/1875 [==============================] - 15s 8ms/step - loss: 0.1323 - accuracy: 0.9703 - val_loss: 0.3336 - val_accuracy: 0.9039
# Epoch 32/90
# 1875/1875 [==============================] - 15s 8ms/step - loss: 0.1292 - accuracy: 0.9704 - val_loss: 0.3551 - val_accuracy: 0.8987
# Epoch 33/90
# 1875/1875 [==============================] - 15s 8ms/step - loss: 0.1241 - accuracy: 0.9721 - val_loss: 0.4095 - val_accuracy: 0.8862
# Epoch 34/90
# 1875/1875 [==============================] - 15s 8ms/step - loss: 0.1172 - accuracy: 0.9734 - val_loss: 0.3369 - val_accuracy: 0.9046
# Epoch 35/90
# 1875/1875 [==============================] - 15s 8ms/step - loss: 0.1139 - accuracy: 0.9746 - val_loss: 0.3733 - val_accuracy: 0.8973
# Epoch 36/90
# 1875/1875 [==============================] - 15s 8ms/step - loss: 0.1080 - accuracy: 0.9763 - val_loss: 0.3700 - val_accuracy: 0.8971
# Epoch 37/90
# 1875/1875 [==============================] - 15s 8ms/step - loss: 0.1037 - accuracy: 0.9777 - val_loss: 0.3751 - val_accuracy: 0.8963
# Epoch 38/90
# 1875/1875 [==============================] - 15s 8ms/step - loss: 0.0997 - accuracy: 0.9792 - val_loss: 0.3745 - val_accuracy: 0.8970
# Epoch 39/90
# 1875/1875 [==============================] - 15s 8ms/step - loss: 0.0935 - accuracy: 0.9808 - val_loss: 0.3737 - val_accuracy: 0.9009
# Epoch 40/90
# 1875/1875 [==============================] - 15s 8ms/step - loss: 0.0940 - accuracy: 0.9805 - val_loss: 0.3755 - val_accuracy: 0.8992
# Epoch 41/90
# 1875/1875 [==============================] - 15s 8ms/step - loss: 0.0871 - accuracy: 0.9822 - val_loss: 0.3658 - val_accuracy: 0.9021
# Epoch 42/90
# 1875/1875 [==============================] - 15s 8ms/step - loss: 0.0814 - accuracy: 0.9843 - val_loss: 0.3864 - val_accuracy: 0.8957
# Epoch 43/90
# 1875/1875 [==============================] - 15s 8ms/step - loss: 0.0817 - accuracy: 0.9840 - val_loss: 0.4730 - val_accuracy: 0.8805
# Epoch 44/90
# 1875/1875 [==============================] - 15s 8ms/step - loss: 0.0751 - accuracy: 0.9858 - val_loss: 0.3655 - val_accuracy: 0.9033
# Epoch 45/90
# 1875/1875 [==============================] - 15s 8ms/step - loss: 0.0750 - accuracy: 0.9854 - val_loss: 0.4154 - val_accuracy: 0.8908
# Epoch 46/90
# 1875/1875 [==============================] - 15s 8ms/step - loss: 0.0706 - accuracy: 0.9864 - val_loss: 0.3594 - val_accuracy: 0.9038
# Epoch 47/90
# 1875/1875 [==============================] - 15s 8ms/step - loss: 0.0690 - accuracy: 0.9872 - val_loss: 0.4089 - val_accuracy: 0.8953
# Epoch 48/90
# 1875/1875 [==============================] - 15s 8ms/step - loss: 0.0676 - accuracy: 0.9875 - val_loss: 0.3966 - val_accuracy: 0.8992
# Epoch 49/90
# 1875/1875 [==============================] - 15s 8ms/step - loss: 0.0642 - accuracy: 0.9878 - val_loss: 0.4256 - val_accuracy: 0.8906
# Epoch 50/90
# 1875/1875 [==============================] - 15s 8ms/step - loss: 0.0620 - accuracy: 0.9895 - val_loss: 0.3862 - val_accuracy: 0.9011
# Epoch 51/90
# 1875/1875 [==============================] - 15s 8ms/step - loss: 0.0606 - accuracy: 0.9891 - val_loss: 0.4658 - val_accuracy: 0.8867
# Epoch 52/90
# 1875/1875 [==============================] - 15s 8ms/step - loss: 0.0575 - accuracy: 0.9902 - val_loss: 0.4261 - val_accuracy: 0.8977
# Epoch 53/90
# 1875/1875 [==============================] - 15s 8ms/step - loss: 0.0547 - accuracy: 0.9908 - val_loss: 0.3828 - val_accuracy: 0.9037
# Epoch 54/90
# 1875/1875 [==============================] - 15s 8ms/step - loss: 0.0544 - accuracy: 0.9911 - val_loss: 0.3833 - val_accuracy: 0.9078
# Epoch 55/90
# 1875/1875 [==============================] - 15s 8ms/step - loss: 0.0499 - accuracy: 0.9921 - val_loss: 0.4123 - val_accuracy: 0.8984
# Epoch 56/90
# 1875/1875 [==============================] - 15s 8ms/step - loss: 0.0507 - accuracy: 0.9917 - val_loss: 0.4398 - val_accuracy: 0.8947
# Epoch 57/90
# 1875/1875 [==============================] - 15s 8ms/step - loss: 0.0472 - accuracy: 0.9928 - val_loss: 0.3857 - val_accuracy: 0.9050
# Epoch 58/90
# 1875/1875 [==============================] - 15s 8ms/step - loss: 0.0451 - accuracy: 0.9933 - val_loss: 0.3760 - val_accuracy: 0.9054
# Epoch 59/90
# 1875/1875 [==============================] - 15s 8ms/step - loss: 0.0445 - accuracy: 0.9937 - val_loss: 0.4028 - val_accuracy: 0.9053
# Epoch 60/90
# 1875/1875 [==============================] - 14s 8ms/step - loss: 0.0425 - accuracy: 0.9940 - val_loss: 0.4691 - val_accuracy: 0.8874
# Epoch 61/90
# 1875/1875 [==============================] - 14s 8ms/step - loss: 0.0444 - accuracy: 0.9932 - val_loss: 0.4016 - val_accuracy: 0.9038
# Epoch 62/90
# 1875/1875 [==============================] - 15s 8ms/step - loss: 0.0416 - accuracy: 0.9935 - val_loss: 0.3892 - val_accuracy: 0.9043
# Epoch 63/90
# 1875/1875 [==============================] - 14s 8ms/step - loss: 0.0382 - accuracy: 0.9949 - val_loss: 0.4360 - val_accuracy: 0.8989
# Epoch 64/90
# 1875/1875 [==============================] - 14s 8ms/step - loss: 0.0360 - accuracy: 0.9954 - val_loss: 0.3981 - val_accuracy: 0.9046
# Epoch 65/90
# 1875/1875 [==============================] - 15s 8ms/step - loss: 0.0371 - accuracy: 0.9947 - val_loss: 0.3829 - val_accuracy: 0.9065
# Epoch 66/90
# 1875/1875 [==============================] - 15s 8ms/step - loss: 0.0366 - accuracy: 0.9950 - val_loss: 0.4077 - val_accuracy: 0.9028
# Epoch 67/90
# 1875/1875 [==============================] - 15s 8ms/step - loss: 0.0355 - accuracy: 0.9957 - val_loss: 0.4140 - val_accuracy: 0.9018
# Epoch 68/90
# 1875/1875 [==============================] - 15s 8ms/step - loss: 0.0345 - accuracy: 0.9951 - val_loss: 0.4162 - val_accuracy: 0.9033
# Epoch 69/90
# 1875/1875 [==============================] - 14s 8ms/step - loss: 0.0345 - accuracy: 0.9954 - val_loss: 0.3975 - val_accuracy: 0.9052
# Epoch 70/90
# 1875/1875 [==============================] - 14s 8ms/step - loss: 0.0303 - accuracy: 0.9966 - val_loss: 0.4032 - val_accuracy: 0.9027
# Epoch 71/90
# 1875/1875 [==============================] - 14s 8ms/step - loss: 0.0340 - accuracy: 0.9954 - val_loss: 0.4028 - val_accuracy: 0.9062
# Epoch 72/90
# 1875/1875 [==============================] - 14s 8ms/step - loss: 0.0312 - accuracy: 0.9960 - val_loss: 0.3931 - val_accuracy: 0.9072
# Epoch 73/90
# 1875/1875 [==============================] - 14s 8ms/step - loss: 0.0292 - accuracy: 0.9965 - val_loss: 0.4019 - val_accuracy: 0.9063
# Epoch 74/90
# 1875/1875 [==============================] - 14s 8ms/step - loss: 0.0323 - accuracy: 0.9957 - val_loss: 0.4108 - val_accuracy: 0.9060
# Epoch 75/90
# 1875/1875 [==============================] - 14s 8ms/step - loss: 0.0326 - accuracy: 0.9952 - val_loss: 0.4064 - val_accuracy: 0.9085
# Epoch 76/90
# 1875/1875 [==============================] - 14s 8ms/step - loss: 0.0286 - accuracy: 0.9965 - val_loss: 0.3930 - val_accuracy: 0.9096
# Epoch 77/90
# 1875/1875 [==============================] - 15s 8ms/step - loss: 0.0282 - accuracy: 0.9968 - val_loss: 0.4182 - val_accuracy: 0.9044
# Epoch 78/90
# 1875/1875 [==============================] - 15s 8ms/step - loss: 0.0264 - accuracy: 0.9969 - val_loss: 0.4345 - val_accuracy: 0.9001
# Epoch 79/90
# 1875/1875 [==============================] - 15s 8ms/step - loss: 0.0297 - accuracy: 0.9958 - val_loss: 0.4107 - val_accuracy: 0.9051
# Epoch 80/90
# 1875/1875 [==============================] - 14s 8ms/step - loss: 0.0273 - accuracy: 0.9965 - val_loss: 0.4336 - val_accuracy: 0.9009
# Epoch 81/90
# 1875/1875 [==============================] - 15s 8ms/step - loss: 0.0247 - accuracy: 0.9973 - val_loss: 0.4620 - val_accuracy: 0.8953
# Epoch 82/90
# 1875/1875 [==============================] - 14s 8ms/step - loss: 0.0268 - accuracy: 0.9966 - val_loss: 0.4020 - val_accuracy: 0.9063
# Epoch 83/90
# 1875/1875 [==============================] - 15s 8ms/step - loss: 0.0255 - accuracy: 0.9969 - val_loss: 0.4171 - val_accuracy: 0.9075
# Epoch 84/90
# 1875/1875 [==============================] - 15s 8ms/step - loss: 0.0262 - accuracy: 0.9967 - val_loss: 0.4039 - val_accuracy: 0.9070
# Epoch 85/90
# 1875/1875 [==============================] - 15s 8ms/step - loss: 0.0236 - accuracy: 0.9976 - val_loss: 0.4174 - val_accuracy: 0.9057
# Epoch 86/90
# 1875/1875 [==============================] - 15s 8ms/step - loss: 0.0258 - accuracy: 0.9965 - val_loss: 0.4148 - val_accuracy: 0.9071
# Epoch 87/90
# 1875/1875 [==============================] - 15s 8ms/step - loss: 0.0216 - accuracy: 0.9982 - val_loss: 0.4191 - val_accuracy: 0.9069
# Epoch 88/90
# 1875/1875 [==============================] - 15s 8ms/step - loss: 0.0216 - accuracy: 0.9978 - val_loss: 0.4636 - val_accuracy: 0.9025
# Epoch 89/90
# 1875/1875 [==============================] - 15s 8ms/step - loss: 0.0202 - accuracy: 0.9980 - val_loss: 0.4310 - val_accuracy: 0.9061
# Epoch 90/90
# 1875/1875 [==============================] - 15s 8ms/step - loss: 0.0233 - accuracy: 0.9975 - val_loss: 0.4350 - val_accuracy: 0.9028

# %%
#fashion mnist, swish

accuracy = model.evaluate(test_images, test_labels, verbose=1)
print('Test loss:', accuracy[0])
print('Test accuracy:', accuracy[1])
# Out:
# 313/313 [==============================] - 1s 3ms/step - loss: 0.4350 - accuracy: 0.9028
# Test loss: 0.43499547243118286
# Test accuracy: 0.9028000235557556

# %%
import matplotlib.pyplot as plt

# Plot training & validation accuracy values
plt.figure(figsize=(12, 12))

plt.subplot(2, 1, 1)
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')

# Plot training & validation loss values
plt.subplot(2, 1, 2)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')

plt.subplots_adjust(hspace=0.3)
plt.show()
