# %%
from tensorflow.python.client import device_lib 
print(device_lib.list_local_devices())
# Out:
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 186225118278820300
# xla_global_id: -1
# , name: "/device:GPU:0"
# device_type: "GPU"
# memory_limit: 5748293632
# locality {
#   bus_id: 1
#   links {
#   }
# }
# incarnation: 15853861789471423086
# physical_device_desc: "device: 0, name: NVIDIA GeForce RTX 3060 Ti, pci bus id: 0000:2b:00.0, compute capability: 8.6"
# xla_global_id: 416903419
# ]

# %%
import tensorflow as tf
from tensorflow import keras
from keras.models import Sequential
from keras.layers import Dense, Activation, Dropout, Flatten, Conv2D, MaxPooling2D, BatchNormalization
from keras.utils import to_categorical

# %%
# Fashion MNIST 데이터셋 로드
fashion_mnist = keras.datasets.fashion_mnist
(train_images, train_labels), (test_images, test_labels) = fashion_mnist.load_data()

# 데이터 전처리
train_images = train_images.reshape(-1, 28, 28, 1)
test_images = test_images.reshape(-1, 28, 28, 1)
train_images = train_images / 255.0
test_images = test_images / 255.0
train_labels = to_categorical(train_labels)
test_labels = to_categorical(test_labels)

print(train_labels.shape, test_labels.shape)

# 데이터 로더 생성
#batch_size = 64
#train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
#test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)
# Out:
# (60000, 10) (10000, 10)

# %%
# AlexNet model architecture
model = Sequential()

# 1st Convolutional Layer
model.add(Conv2D(filters=96, input_shape=(28,28,1), kernel_size=(11,11), strides=(4,4), padding='same')) 
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2,2), strides=(2,2), padding='same'))

# 2nd Convolutional Layer
model.add(Conv2D(filters=256, kernel_size=(5,5), strides=(1,1), padding='same')) 
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2,2), strides=(2,2), padding='same'))

# 3rd Convolutional Layer
model.add(Conv2D(filters=384, kernel_size=(3,3), strides=(1,1), padding='same')) 
model.add(BatchNormalization())
model.add(Activation('relu'))

# 4th Convolutional Layer
model.add(Conv2D(filters=384, kernel_size=(3,3), strides=(1,1), padding='same')) 
model.add(BatchNormalization())
model.add(Activation('relu'))

# 5th Convolutional Layer
model.add(Conv2D(filters=256, kernel_size=(3,3), strides=(1,1), padding='same')) 
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2,2), strides=(2,2), padding='same'))

# Fully Connected layer
model.add(Flatten())
model.add(Dense(4096, input_shape=(32,32,3))) 
model.add(BatchNormalization()) 
model.add(Activation('relu'))

# Add Dropout to prevent overfitting
model.add(Dropout(0.5))

# Fully Connected Layer
model.add(Dense(4096)) 
model.add(BatchNormalization()) 
model.add(Activation('relu')) # Add Dropout 
model.add(Dropout(0.5))

# Output Layer
model.add(Dense(10)) 
model.add(BatchNormalization()) 
model.add(Activation('softmax'))

# Model Summary
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 7, 7, 96)          11712
#
#  batch_normalization (BatchN  (None, 7, 7, 96)         384
#  ormalization)
#
#  activation (Activation)     (None, 7, 7, 96)          0
#
#  max_pooling2d (MaxPooling2D  (None, 4, 4, 96)         0
#  )
#
#  conv2d_1 (Conv2D)           (None, 4, 4, 256)         614656
#
#  batch_normalization_1 (Batc  (None, 4, 4, 256)        1024
#  hNormalization)
#
#  activation_1 (Activation)   (None, 4, 4, 256)         0
#
#  max_pooling2d_1 (MaxPooling  (None, 2, 2, 256)        0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 2, 2, 384)         885120
#
#  batch_normalization_2 (Batc  (None, 2, 2, 384)        1536
#  hNormalization)
#
#  activation_2 (Activation)   (None, 2, 2, 384)         0
#
#  conv2d_3 (Conv2D)           (None, 2, 2, 384)         1327488
#
#  batch_normalization_3 (Batc  (None, 2, 2, 384)        1536
#  hNormalization)
#
#  activation_3 (Activation)   (None, 2, 2, 384)         0
#
#  conv2d_4 (Conv2D)           (None, 2, 2, 256)         884992
#
#  batch_normalization_4 (Batc  (None, 2, 2, 256)        1024
#  hNormalization)
#
#  activation_4 (Activation)   (None, 2, 2, 256)         0
#
#  max_pooling2d_2 (MaxPooling  (None, 1, 1, 256)        0
#  2D)
#
#  flatten (Flatten)           (None, 256)               0
#
#  dense (Dense)               (None, 4096)              1052672
#
#  batch_normalization_5 (Batc  (None, 4096)             16384
#  hNormalization)
#
#  activation_5 (Activation)   (None, 4096)              0
#
#  dropout (Dropout)           (None, 4096)              0
#
#  dense_1 (Dense)             (None, 4096)              16781312
#
#  batch_normalization_6 (Batc  (None, 4096)             16384
#  hNormalization)
#
#  activation_6 (Activation)   (None, 4096)              0
#
#  dropout_1 (Dropout)         (None, 4096)              0
#
#  dense_2 (Dense)             (None, 10)                40970
#
#  batch_normalization_7 (Batc  (None, 10)               40
#  hNormalization)
#
#  activation_7 (Activation)   (None, 10)                0
#
# =================================================================
# Total params: 21,637,234
# Trainable params: 21,618,078
# Non-trainable params: 19,156
# _________________________________________________________________

# %%
# Compile the model
model.compile(optimizer=tf.keras.optimizers.SGD(learning_rate=0.001), 
              loss='categorical_crossentropy',
              metrics=['accuracy'])
# Train the model
# model.fit(train_images, train_labels, epochs=90, validation_data=(test_images, test_labels))

history = model.fit(train_images, train_labels, epochs=90, 
                    validation_data=(test_images, test_labels))
# Out:
# Epoch 1/90
# 1875/1875 [==============================] - 17s 8ms/step - loss: 0.9545 - accuracy: 0.7513 - val_loss: 0.6155 - val_accuracy: 0.8390
# Epoch 2/90
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.6992 - accuracy: 0.8309 - val_loss: 0.5402 - val_accuracy: 0.8511
# Epoch 3/90
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.6086 - accuracy: 0.8515 - val_loss: 0.4662 - val_accuracy: 0.8709
# Epoch 4/90
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.5460 - accuracy: 0.8641 - val_loss: 0.4334 - val_accuracy: 0.8750
# Epoch 5/90
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.5031 - accuracy: 0.8732 - val_loss: 0.4144 - val_accuracy: 0.8753
# Epoch 6/90
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.4650 - accuracy: 0.8806 - val_loss: 0.3744 - val_accuracy: 0.8858
# Epoch 7/90
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.4402 - accuracy: 0.8848 - val_loss: 0.4119 - val_accuracy: 0.8729
# Epoch 8/90
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.4149 - accuracy: 0.8900 - val_loss: 0.4084 - val_accuracy: 0.8676
# Epoch 9/90
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.3973 - accuracy: 0.8939 - val_loss: 0.4127 - val_accuracy: 0.8746
# Epoch 10/90
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.3789 - accuracy: 0.8981 - val_loss: 0.3426 - val_accuracy: 0.8891
# Epoch 11/90
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.3576 - accuracy: 0.9037 - val_loss: 0.3289 - val_accuracy: 0.8969
# Epoch 12/90
# 1875/1875 [==============================] - 14s 8ms/step - loss: 0.3437 - accuracy: 0.9061 - val_loss: 0.3935 - val_accuracy: 0.8755
# Epoch 13/90
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.3284 - accuracy: 0.9115 - val_loss: 0.3549 - val_accuracy: 0.8868
# Epoch 14/90
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.3138 - accuracy: 0.9132 - val_loss: 0.3280 - val_accuracy: 0.8931
# Epoch 15/90
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.2998 - accuracy: 0.9175 - val_loss: 0.3165 - val_accuracy: 0.8955
# Epoch 16/90
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.2916 - accuracy: 0.9205 - val_loss: 0.4442 - val_accuracy: 0.8645
# Epoch 17/90
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.2806 - accuracy: 0.9231 - val_loss: 0.3428 - val_accuracy: 0.8894
# Epoch 18/90
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.2701 - accuracy: 0.9257 - val_loss: 0.3200 - val_accuracy: 0.8977
# Epoch 19/90
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.2564 - accuracy: 0.9304 - val_loss: 0.3178 - val_accuracy: 0.8974
# Epoch 20/90
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.2478 - accuracy: 0.9326 - val_loss: 0.3544 - val_accuracy: 0.8885
# Epoch 21/90
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.2410 - accuracy: 0.9350 - val_loss: 0.3490 - val_accuracy: 0.8904
# Epoch 22/90
# 1875/1875 [==============================] - 14s 8ms/step - loss: 0.2292 - accuracy: 0.9384 - val_loss: 0.3422 - val_accuracy: 0.8945
# Epoch 23/90
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.2192 - accuracy: 0.9415 - val_loss: 0.3863 - val_accuracy: 0.8840
# Epoch 24/90
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.2108 - accuracy: 0.9444 - val_loss: 0.3416 - val_accuracy: 0.8962
# Epoch 25/90
# 1875/1875 [==============================] - 14s 8ms/step - loss: 0.2020 - accuracy: 0.9471 - val_loss: 0.3237 - val_accuracy: 0.8972
# Epoch 26/90
# 1875/1875 [==============================] - 14s 8ms/step - loss: 0.1977 - accuracy: 0.9482 - val_loss: 0.3171 - val_accuracy: 0.9016
# Epoch 27/90
# 1875/1875 [==============================] - 14s 8ms/step - loss: 0.1892 - accuracy: 0.9501 - val_loss: 0.3839 - val_accuracy: 0.8858
# Epoch 28/90
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.1831 - accuracy: 0.9524 - val_loss: 0.3256 - val_accuracy: 0.8999
# Epoch 29/90
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.1767 - accuracy: 0.9541 - val_loss: 0.3862 - val_accuracy: 0.8872
# Epoch 30/90
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.1695 - accuracy: 0.9569 - val_loss: 0.3341 - val_accuracy: 0.8997
# Epoch 31/90
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.1637 - accuracy: 0.9579 - val_loss: 0.3846 - val_accuracy: 0.8900
# Epoch 32/90
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.1545 - accuracy: 0.9618 - val_loss: 0.3682 - val_accuracy: 0.8954
# Epoch 33/90
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.1493 - accuracy: 0.9631 - val_loss: 0.3944 - val_accuracy: 0.8881
# Epoch 34/90
# 1875/1875 [==============================] - 14s 8ms/step - loss: 0.1431 - accuracy: 0.9656 - val_loss: 0.4007 - val_accuracy: 0.8898
# Epoch 35/90
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.1406 - accuracy: 0.9651 - val_loss: 0.3889 - val_accuracy: 0.8894
# Epoch 36/90
# 1875/1875 [==============================] - 14s 8ms/step - loss: 0.1339 - accuracy: 0.9673 - val_loss: 0.3513 - val_accuracy: 0.8987
# Epoch 37/90
# 1875/1875 [==============================] - 14s 8ms/step - loss: 0.1264 - accuracy: 0.9691 - val_loss: 0.3562 - val_accuracy: 0.8983
# Epoch 38/90
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.1277 - accuracy: 0.9683 - val_loss: 0.3730 - val_accuracy: 0.8944
# Epoch 39/90
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.1198 - accuracy: 0.9715 - val_loss: 0.3776 - val_accuracy: 0.8984
# Epoch 40/90
# 1875/1875 [==============================] - 14s 8ms/step - loss: 0.1125 - accuracy: 0.9740 - val_loss: 0.4161 - val_accuracy: 0.8830
# Epoch 41/90
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.1085 - accuracy: 0.9748 - val_loss: 0.3692 - val_accuracy: 0.8984
# Epoch 42/90
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.1071 - accuracy: 0.9746 - val_loss: 0.4076 - val_accuracy: 0.8889
# Epoch 43/90
# 1875/1875 [==============================] - 14s 8ms/step - loss: 0.1039 - accuracy: 0.9750 - val_loss: 0.3921 - val_accuracy: 0.8932
# Epoch 44/90
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.0989 - accuracy: 0.9772 - val_loss: 0.3659 - val_accuracy: 0.8985
# Epoch 45/90
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.0922 - accuracy: 0.9792 - val_loss: 0.3846 - val_accuracy: 0.8978
# Epoch 46/90
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.0937 - accuracy: 0.9791 - val_loss: 0.3527 - val_accuracy: 0.9023
# Epoch 47/90
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.0903 - accuracy: 0.9792 - val_loss: 0.3838 - val_accuracy: 0.8995
# Epoch 48/90
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.0861 - accuracy: 0.9815 - val_loss: 0.3648 - val_accuracy: 0.9069
# Epoch 49/90
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.0822 - accuracy: 0.9826 - val_loss: 0.3652 - val_accuracy: 0.9014
# Epoch 50/90
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.0829 - accuracy: 0.9821 - val_loss: 0.3761 - val_accuracy: 0.9024
# Epoch 51/90
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.0772 - accuracy: 0.9839 - val_loss: 0.3591 - val_accuracy: 0.9048
# Epoch 52/90
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.0754 - accuracy: 0.9840 - val_loss: 0.4157 - val_accuracy: 0.8934
# Epoch 53/90
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.0717 - accuracy: 0.9854 - val_loss: 0.4222 - val_accuracy: 0.8923
# Epoch 54/90
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.0729 - accuracy: 0.9841 - val_loss: 0.4097 - val_accuracy: 0.8976
# Epoch 55/90
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.0670 - accuracy: 0.9861 - val_loss: 0.4051 - val_accuracy: 0.8950
# Epoch 56/90
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.0639 - accuracy: 0.9870 - val_loss: 0.3712 - val_accuracy: 0.9047
# Epoch 57/90
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.0612 - accuracy: 0.9879 - val_loss: 0.3867 - val_accuracy: 0.8993
# Epoch 58/90
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.0586 - accuracy: 0.9884 - val_loss: 0.3970 - val_accuracy: 0.8979
# Epoch 59/90
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.0584 - accuracy: 0.9888 - val_loss: 0.3746 - val_accuracy: 0.9035
# Epoch 60/90
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.0550 - accuracy: 0.9894 - val_loss: 0.6938 - val_accuracy: 0.8480
# Epoch 61/90
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.0554 - accuracy: 0.9888 - val_loss: 0.4344 - val_accuracy: 0.8990
# Epoch 62/90
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.0579 - accuracy: 0.9877 - val_loss: 0.4234 - val_accuracy: 0.8989
# Epoch 63/90
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.0549 - accuracy: 0.9890 - val_loss: 0.3912 - val_accuracy: 0.9046
# Epoch 64/90
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.0545 - accuracy: 0.9889 - val_loss: 0.3847 - val_accuracy: 0.9066
# Epoch 65/90
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.0516 - accuracy: 0.9903 - val_loss: 0.4709 - val_accuracy: 0.8893
# Epoch 66/90
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.0480 - accuracy: 0.9914 - val_loss: 0.4673 - val_accuracy: 0.8860
# Epoch 67/90
# 1875/1875 [==============================] - 14s 8ms/step - loss: 0.0450 - accuracy: 0.9919 - val_loss: 0.4563 - val_accuracy: 0.8919
# Epoch 68/90
# 1875/1875 [==============================] - 15s 8ms/step - loss: 0.0457 - accuracy: 0.9912 - val_loss: 0.4768 - val_accuracy: 0.8932
# Epoch 69/90
# 1875/1875 [==============================] - 15s 8ms/step - loss: 0.0455 - accuracy: 0.9918 - val_loss: 0.4268 - val_accuracy: 0.9008
# Epoch 70/90
# 1875/1875 [==============================] - 15s 8ms/step - loss: 0.0433 - accuracy: 0.9921 - val_loss: 0.3919 - val_accuracy: 0.9073
# Epoch 71/90
# 1875/1875 [==============================] - 15s 8ms/step - loss: 0.0413 - accuracy: 0.9930 - val_loss: 0.3857 - val_accuracy: 0.9081
# Epoch 72/90
# 1875/1875 [==============================] - 15s 8ms/step - loss: 0.0417 - accuracy: 0.9925 - val_loss: 0.4658 - val_accuracy: 0.8975
# Epoch 73/90
# 1875/1875 [==============================] - 15s 8ms/step - loss: 0.0428 - accuracy: 0.9920 - val_loss: 0.4302 - val_accuracy: 0.9005
# Epoch 74/90
# 1875/1875 [==============================] - 15s 8ms/step - loss: 0.0391 - accuracy: 0.9936 - val_loss: 0.3971 - val_accuracy: 0.9067
# Epoch 75/90
# 1875/1875 [==============================] - 15s 8ms/step - loss: 0.0386 - accuracy: 0.9936 - val_loss: 0.5167 - val_accuracy: 0.8865
# Epoch 76/90
# 1875/1875 [==============================] - 15s 8ms/step - loss: 0.0369 - accuracy: 0.9939 - val_loss: 0.4140 - val_accuracy: 0.9044
# Epoch 77/90
# 1875/1875 [==============================] - 15s 8ms/step - loss: 0.0397 - accuracy: 0.9929 - val_loss: 0.3930 - val_accuracy: 0.9079
# Epoch 78/90
# 1875/1875 [==============================] - 14s 8ms/step - loss: 0.0355 - accuracy: 0.9941 - val_loss: 0.4318 - val_accuracy: 0.9025
# Epoch 79/90
# 1875/1875 [==============================] - 14s 8ms/step - loss: 0.0364 - accuracy: 0.9937 - val_loss: 0.5449 - val_accuracy: 0.8834
# Epoch 80/90
# 1875/1875 [==============================] - 16s 9ms/step - loss: 0.0326 - accuracy: 0.9950 - val_loss: 0.4740 - val_accuracy: 0.8947
# Epoch 81/90
# 1875/1875 [==============================] - 17s 9ms/step - loss: 0.0367 - accuracy: 0.9936 - val_loss: 0.4516 - val_accuracy: 0.8932
# Epoch 82/90
# 1875/1875 [==============================] - 18s 9ms/step - loss: 0.0347 - accuracy: 0.9944 - val_loss: 0.4080 - val_accuracy: 0.9071
# Epoch 83/90
# 1875/1875 [==============================] - 18s 9ms/step - loss: 0.0292 - accuracy: 0.9959 - val_loss: 0.4352 - val_accuracy: 0.9023
# Epoch 84/90
# 1875/1875 [==============================] - 18s 9ms/step - loss: 0.0310 - accuracy: 0.9949 - val_loss: 0.4458 - val_accuracy: 0.9013
# Epoch 85/90
# 1875/1875 [==============================] - 18s 9ms/step - loss: 0.0294 - accuracy: 0.9958 - val_loss: 0.4159 - val_accuracy: 0.9058
# Epoch 86/90
# 1875/1875 [==============================] - 18s 9ms/step - loss: 0.0303 - accuracy: 0.9955 - val_loss: 0.4168 - val_accuracy: 0.9085
# Epoch 87/90
# 1875/1875 [==============================] - 18s 10ms/step - loss: 0.0304 - accuracy: 0.9949 - val_loss: 0.4336 - val_accuracy: 0.9028
# Epoch 88/90
# 1875/1875 [==============================] - 17s 9ms/step - loss: 0.0284 - accuracy: 0.9960 - val_loss: 0.5186 - val_accuracy: 0.8835
# Epoch 89/90
# 1875/1875 [==============================] - 18s 9ms/step - loss: 0.0265 - accuracy: 0.9964 - val_loss: 0.4357 - val_accuracy: 0.9045
# Epoch 90/90
# 1875/1875 [==============================] - 17s 9ms/step - loss: 0.0277 - accuracy: 0.9956 - val_loss: 0.5428 - val_accuracy: 0.8823

# %%
#fashion mnist

accuracy = model.evaluate(test_images, test_labels, verbose=1)
print('Test loss:', accuracy[0])
print('Test accuracy:', accuracy[1])
# Out:
# 313/313 [==============================] - 1s 4ms/step - loss: 0.5428 - accuracy: 0.8823
# Test loss: 0.5427606701850891
# Test accuracy: 0.8823000192642212

# %%
import matplotlib.pyplot as plt

# Plot training & validation accuracy values
plt.figure(figsize=(12, 12))

plt.subplot(2, 1, 1)
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')

# Plot training & validation loss values
plt.subplot(2, 1, 2)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')

plt.subplots_adjust(hspace=0.3)
plt.show()
