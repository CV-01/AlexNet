# %%
from tensorflow.python.client import device_lib 
print(device_lib.list_local_devices())
# Out:
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 1265226140478796554
# xla_global_id: -1
# , name: "/device:GPU:0"
# device_type: "GPU"
# memory_limit: 5748293632
# locality {
#   bus_id: 1
#   links {
#   }
# }
# incarnation: 6993943785203934590
# physical_device_desc: "device: 0, name: NVIDIA GeForce RTX 3060 Ti, pci bus id: 0000:2b:00.0, compute capability: 8.6"
# xla_global_id: 416903419
# ]

# %%
import tensorflow as tf
from tensorflow import keras
from keras.models import Sequential
from keras.layers import Dense, Activation, Dropout, Flatten, Conv2D, MaxPooling2D, BatchNormalization
from keras.utils import to_categorical

# %%
# Fashion MNIST 데이터셋 로드
fashion_mnist = keras.datasets.fashion_mnist
(train_images, train_labels), (test_images, test_labels) = fashion_mnist.load_data()

# 데이터 전처리
train_images = train_images.reshape(-1, 28, 28, 1)
test_images = test_images.reshape(-1, 28, 28, 1)
train_images = train_images / 255.0
test_images = test_images / 255.0
train_labels = to_categorical(train_labels)
test_labels = to_categorical(test_labels)

print(train_labels.shape, test_labels.shape)

# 데이터 로더 생성
#batch_size = 64
#train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
#test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)
# Out:
# (60000, 10) (10000, 10)

# %%
# AlexNet model architecture
model = Sequential()

# 1st Convolutional Layer
model.add(Conv2D(filters=96, input_shape=(28,28,1), kernel_size=(11,11), strides=(4,4), padding='same')) 
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2,2), strides=(2,2), padding='same'))

# 2nd Convolutional Layer
model.add(Conv2D(filters=256, kernel_size=(5,5), strides=(1,1), padding='same')) 
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2,2), strides=(2,2), padding='same'))

# # 3rd Convolutional Layer
# model.add(Conv2D(filters=384, kernel_size=(3,3), strides=(1,1), padding='same')) 
# model.add(BatchNormalization())
# model.add(Activation('relu'))

# # 4th Convolutional Layer
# model.add(Conv2D(filters=384, kernel_size=(3,3), strides=(1,1), padding='same')) 
# model.add(BatchNormalization())
# model.add(Activation('relu'))

# 5th Convolutional Layer
model.add(Conv2D(filters=256, kernel_size=(3,3), strides=(1,1), padding='same')) 
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2,2), strides=(2,2), padding='same'))

# Fully Connected layer
model.add(Flatten())
model.add(Dense(4096, input_shape=(32,32,3))) 
model.add(BatchNormalization()) 
model.add(Activation('relu'))

# Add Dropout to prevent overfitting
model.add(Dropout(0.5))

# Fully Connected Layer
model.add(Dense(4096)) 
model.add(BatchNormalization()) 
model.add(Activation('relu')) # Add Dropout 
model.add(Dropout(0.5))

# Output Layer
model.add(Dense(10)) 
model.add(BatchNormalization()) 
model.add(Activation('softmax'))

# Model Summary
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 7, 7, 96)          11712
#
#  batch_normalization (BatchN  (None, 7, 7, 96)         384
#  ormalization)
#
#  activation (Activation)     (None, 7, 7, 96)          0
#
#  max_pooling2d (MaxPooling2D  (None, 4, 4, 96)         0
#  )
#
#  conv2d_1 (Conv2D)           (None, 4, 4, 256)         614656
#
#  batch_normalization_1 (Batc  (None, 4, 4, 256)        1024
#  hNormalization)
#
#  activation_1 (Activation)   (None, 4, 4, 256)         0
#
#  max_pooling2d_1 (MaxPooling  (None, 2, 2, 256)        0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 2, 2, 256)         590080
#
#  batch_normalization_2 (Batc  (None, 2, 2, 256)        1024
#  hNormalization)
#
#  activation_2 (Activation)   (None, 2, 2, 256)         0
#
#  max_pooling2d_2 (MaxPooling  (None, 1, 1, 256)        0
#  2D)
#
#  flatten (Flatten)           (None, 256)               0
#
#  dense (Dense)               (None, 4096)              1052672
#
#  batch_normalization_3 (Batc  (None, 4096)             16384
#  hNormalization)
#
#  activation_3 (Activation)   (None, 4096)              0
#
#  dropout (Dropout)           (None, 4096)              0
#
#  dense_1 (Dense)             (None, 4096)              16781312
#
#  batch_normalization_4 (Batc  (None, 4096)             16384
#  hNormalization)
#
#  activation_4 (Activation)   (None, 4096)              0
#
#  dropout_1 (Dropout)         (None, 4096)              0
#
#  dense_2 (Dense)             (None, 10)                40970
#
#  batch_normalization_5 (Batc  (None, 10)               40
#  hNormalization)
#
#  activation_5 (Activation)   (None, 10)                0
#
# =================================================================
# Total params: 19,126,642
# Trainable params: 19,109,022
# Non-trainable params: 17,620
# _________________________________________________________________

# %%
# Compile the model
model.compile(optimizer=tf.keras.optimizers.SGD(learning_rate=0.001), 
              loss='categorical_crossentropy',
              metrics=['accuracy'])
# Train the model
# model.fit(train_images, train_labels, epochs=90, validation_data=(test_images, test_labels))

history = model.fit(train_images, train_labels, epochs=90, 
                    validation_data=(test_images, test_labels))
# Out:
# Epoch 1/90
# 1875/1875 [==============================] - 13s 6ms/step - loss: 1.0024 - accuracy: 0.7301 - val_loss: 0.6490 - val_accuracy: 0.8293
# Epoch 2/90
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.7405 - accuracy: 0.8181 - val_loss: 0.5501 - val_accuracy: 0.8542
# Epoch 3/90
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.6419 - accuracy: 0.8399 - val_loss: 0.5028 - val_accuracy: 0.8640
# Epoch 4/90
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.5847 - accuracy: 0.8523 - val_loss: 0.4519 - val_accuracy: 0.8699
# Epoch 5/90
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.5341 - accuracy: 0.8604 - val_loss: 0.4294 - val_accuracy: 0.8701
# Epoch 6/90
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.5030 - accuracy: 0.8679 - val_loss: 0.4171 - val_accuracy: 0.8699
# Epoch 7/90
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.4735 - accuracy: 0.8710 - val_loss: 0.4137 - val_accuracy: 0.8657
# Epoch 8/90
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.4514 - accuracy: 0.8778 - val_loss: 0.3890 - val_accuracy: 0.8784
# Epoch 9/90
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.4272 - accuracy: 0.8841 - val_loss: 0.3835 - val_accuracy: 0.8788
# Epoch 10/90
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.4123 - accuracy: 0.8860 - val_loss: 0.3728 - val_accuracy: 0.8817
# Epoch 11/90
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.3956 - accuracy: 0.8890 - val_loss: 0.3753 - val_accuracy: 0.8803
# Epoch 12/90
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.3815 - accuracy: 0.8940 - val_loss: 0.3662 - val_accuracy: 0.8807
# Epoch 13/90
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.3667 - accuracy: 0.8970 - val_loss: 0.3549 - val_accuracy: 0.8868
# Epoch 14/90
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.3563 - accuracy: 0.8994 - val_loss: 0.3274 - val_accuracy: 0.8952
# Epoch 15/90
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.3443 - accuracy: 0.9023 - val_loss: 0.3307 - val_accuracy: 0.8927
# Epoch 16/90
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.3326 - accuracy: 0.9039 - val_loss: 0.3506 - val_accuracy: 0.8881
# Epoch 17/90
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.3226 - accuracy: 0.9074 - val_loss: 0.3731 - val_accuracy: 0.8811
# Epoch 18/90
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.3146 - accuracy: 0.9092 - val_loss: 0.3401 - val_accuracy: 0.8905
# Epoch 19/90
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.3021 - accuracy: 0.9127 - val_loss: 0.3127 - val_accuracy: 0.9005
# Epoch 20/90
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.2943 - accuracy: 0.9166 - val_loss: 0.3153 - val_accuracy: 0.8972
# Epoch 21/90
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.2893 - accuracy: 0.9180 - val_loss: 0.3209 - val_accuracy: 0.8978
# Epoch 22/90
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.2800 - accuracy: 0.9199 - val_loss: 0.3675 - val_accuracy: 0.8832
# Epoch 23/90
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.2684 - accuracy: 0.9230 - val_loss: 0.4438 - val_accuracy: 0.8596
# Epoch 24/90
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.2633 - accuracy: 0.9250 - val_loss: 0.3196 - val_accuracy: 0.8989
# Epoch 25/90
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.2560 - accuracy: 0.9275 - val_loss: 0.3348 - val_accuracy: 0.8906
# Epoch 26/90
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.2490 - accuracy: 0.9299 - val_loss: 0.3182 - val_accuracy: 0.8974
# Epoch 27/90
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.2404 - accuracy: 0.9323 - val_loss: 0.3557 - val_accuracy: 0.8888
# Epoch 28/90
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.2330 - accuracy: 0.9342 - val_loss: 0.3064 - val_accuracy: 0.9052
# Epoch 29/90
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.2248 - accuracy: 0.9362 - val_loss: 0.3202 - val_accuracy: 0.8972
# Epoch 30/90
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.2213 - accuracy: 0.9377 - val_loss: 0.3359 - val_accuracy: 0.8940
# Epoch 31/90
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.2116 - accuracy: 0.9410 - val_loss: 0.3410 - val_accuracy: 0.8939
# Epoch 32/90
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.2083 - accuracy: 0.9425 - val_loss: 0.3317 - val_accuracy: 0.8992
# Epoch 33/90
# 1875/1875 [==============================] - 10s 6ms/step - loss: 0.1986 - accuracy: 0.9455 - val_loss: 0.4279 - val_accuracy: 0.8694
# Epoch 34/90
# 1875/1875 [==============================] - 12s 6ms/step - loss: 0.1978 - accuracy: 0.9441 - val_loss: 0.3567 - val_accuracy: 0.8911
# Epoch 35/90
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.1912 - accuracy: 0.9477 - val_loss: 0.3212 - val_accuracy: 0.9000
# Epoch 36/90
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.1853 - accuracy: 0.9497 - val_loss: 0.3603 - val_accuracy: 0.8891
# Epoch 37/90
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.1781 - accuracy: 0.9523 - val_loss: 0.3398 - val_accuracy: 0.8948
# Epoch 38/90
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.1719 - accuracy: 0.9545 - val_loss: 0.3720 - val_accuracy: 0.8841
# Epoch 39/90
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.1690 - accuracy: 0.9550 - val_loss: 0.3501 - val_accuracy: 0.8917
# Epoch 40/90
# 1875/1875 [==============================] - 12s 7ms/step - loss: 0.1639 - accuracy: 0.9563 - val_loss: 0.3445 - val_accuracy: 0.8970
# Epoch 41/90
# 1875/1875 [==============================] - 13s 7ms/step - loss: 0.1599 - accuracy: 0.9571 - val_loss: 0.3914 - val_accuracy: 0.8824
# Epoch 42/90
# 1875/1875 [==============================] - 12s 7ms/step - loss: 0.1510 - accuracy: 0.9612 - val_loss: 0.3810 - val_accuracy: 0.8929
# Epoch 43/90
# 1875/1875 [==============================] - 12s 6ms/step - loss: 0.1500 - accuracy: 0.9605 - val_loss: 0.3916 - val_accuracy: 0.8877
# Epoch 44/90
# 1875/1875 [==============================] - 12s 7ms/step - loss: 0.1447 - accuracy: 0.9627 - val_loss: 0.3908 - val_accuracy: 0.8871
# Epoch 45/90
# 1875/1875 [==============================] - 12s 6ms/step - loss: 0.1403 - accuracy: 0.9638 - val_loss: 0.4237 - val_accuracy: 0.8786
# Epoch 46/90
# 1875/1875 [==============================] - 12s 7ms/step - loss: 0.1376 - accuracy: 0.9647 - val_loss: 0.3629 - val_accuracy: 0.8911
# Epoch 47/90
# 1875/1875 [==============================] - 12s 6ms/step - loss: 0.1292 - accuracy: 0.9680 - val_loss: 0.4251 - val_accuracy: 0.8847
# Epoch 48/90
# 1875/1875 [==============================] - 12s 7ms/step - loss: 0.1291 - accuracy: 0.9678 - val_loss: 0.3612 - val_accuracy: 0.8995
# Epoch 49/90
# 1875/1875 [==============================] - 12s 6ms/step - loss: 0.1261 - accuracy: 0.9690 - val_loss: 0.4050 - val_accuracy: 0.8837
# Epoch 50/90
# 1875/1875 [==============================] - 12s 7ms/step - loss: 0.1227 - accuracy: 0.9694 - val_loss: 0.3980 - val_accuracy: 0.8941
# Epoch 51/90
# 1875/1875 [==============================] - 12s 7ms/step - loss: 0.1156 - accuracy: 0.9716 - val_loss: 0.3462 - val_accuracy: 0.9011
# Epoch 52/90
# 1875/1875 [==============================] - 12s 7ms/step - loss: 0.1095 - accuracy: 0.9739 - val_loss: 0.3848 - val_accuracy: 0.8928
# Epoch 53/90
# 1875/1875 [==============================] - 12s 6ms/step - loss: 0.1084 - accuracy: 0.9742 - val_loss: 0.3564 - val_accuracy: 0.8996
# Epoch 54/90
# 1875/1875 [==============================] - 12s 6ms/step - loss: 0.1102 - accuracy: 0.9725 - val_loss: 0.3470 - val_accuracy: 0.9016
# Epoch 55/90
# 1875/1875 [==============================] - 12s 6ms/step - loss: 0.1047 - accuracy: 0.9751 - val_loss: 0.3753 - val_accuracy: 0.8961
# Epoch 56/90
# 1875/1875 [==============================] - 12s 6ms/step - loss: 0.1013 - accuracy: 0.9769 - val_loss: 0.3492 - val_accuracy: 0.9044
# Epoch 57/90
# 1875/1875 [==============================] - 12s 6ms/step - loss: 0.0995 - accuracy: 0.9764 - val_loss: 0.3795 - val_accuracy: 0.9002
# Epoch 58/90
# 1875/1875 [==============================] - 12s 6ms/step - loss: 0.0954 - accuracy: 0.9784 - val_loss: 0.4035 - val_accuracy: 0.8932
# Epoch 59/90
# 1875/1875 [==============================] - 12s 6ms/step - loss: 0.0914 - accuracy: 0.9792 - val_loss: 0.4298 - val_accuracy: 0.8901
# Epoch 60/90
# 1875/1875 [==============================] - 12s 6ms/step - loss: 0.0888 - accuracy: 0.9800 - val_loss: 0.3635 - val_accuracy: 0.8993
# Epoch 61/90
# 1875/1875 [==============================] - 12s 6ms/step - loss: 0.0859 - accuracy: 0.9813 - val_loss: 0.3516 - val_accuracy: 0.9029
# Epoch 62/90
# 1875/1875 [==============================] - 12s 6ms/step - loss: 0.0844 - accuracy: 0.9808 - val_loss: 0.3774 - val_accuracy: 0.8988
# Epoch 63/90
# 1875/1875 [==============================] - 12s 6ms/step - loss: 0.0823 - accuracy: 0.9815 - val_loss: 0.3705 - val_accuracy: 0.9029
# Epoch 64/90
# 1875/1875 [==============================] - 12s 6ms/step - loss: 0.0785 - accuracy: 0.9831 - val_loss: 0.3772 - val_accuracy: 0.9001
# Epoch 65/90
# 1875/1875 [==============================] - 12s 6ms/step - loss: 0.0750 - accuracy: 0.9835 - val_loss: 0.3826 - val_accuracy: 0.9024
# Epoch 66/90
# 1875/1875 [==============================] - 12s 6ms/step - loss: 0.0760 - accuracy: 0.9834 - val_loss: 0.3638 - val_accuracy: 0.9035
# Epoch 67/90
# 1875/1875 [==============================] - 12s 6ms/step - loss: 0.0735 - accuracy: 0.9845 - val_loss: 0.4920 - val_accuracy: 0.8812
# Epoch 68/90
# 1875/1875 [==============================] - 12s 7ms/step - loss: 0.0742 - accuracy: 0.9840 - val_loss: 0.3663 - val_accuracy: 0.9036
# Epoch 69/90
# 1875/1875 [==============================] - 12s 6ms/step - loss: 0.0694 - accuracy: 0.9854 - val_loss: 0.3768 - val_accuracy: 0.9015
# Epoch 70/90
# 1875/1875 [==============================] - 12s 6ms/step - loss: 0.0696 - accuracy: 0.9847 - val_loss: 0.4319 - val_accuracy: 0.8978
# Epoch 71/90
# 1875/1875 [==============================] - 12s 6ms/step - loss: 0.0678 - accuracy: 0.9854 - val_loss: 0.3784 - val_accuracy: 0.9000
# Epoch 72/90
# 1875/1875 [==============================] - 12s 6ms/step - loss: 0.0674 - accuracy: 0.9857 - val_loss: 0.3744 - val_accuracy: 0.9027
# Epoch 73/90
# 1875/1875 [==============================] - 12s 6ms/step - loss: 0.0613 - accuracy: 0.9880 - val_loss: 0.4084 - val_accuracy: 0.8988
# Epoch 74/90
# 1875/1875 [==============================] - 12s 6ms/step - loss: 0.0613 - accuracy: 0.9876 - val_loss: 0.3706 - val_accuracy: 0.9056
# Epoch 75/90
# 1875/1875 [==============================] - 12s 6ms/step - loss: 0.0599 - accuracy: 0.9876 - val_loss: 0.4771 - val_accuracy: 0.8865
# Epoch 76/90
# 1875/1875 [==============================] - 12s 6ms/step - loss: 0.0566 - accuracy: 0.9889 - val_loss: 0.4225 - val_accuracy: 0.8940
# Epoch 77/90
# 1875/1875 [==============================] - 12s 6ms/step - loss: 0.0566 - accuracy: 0.9886 - val_loss: 0.4244 - val_accuracy: 0.8904
# Epoch 78/90
# 1875/1875 [==============================] - 13s 7ms/step - loss: 0.0561 - accuracy: 0.9887 - val_loss: 0.3832 - val_accuracy: 0.9027
# Epoch 79/90
# 1875/1875 [==============================] - 12s 6ms/step - loss: 0.0494 - accuracy: 0.9916 - val_loss: 0.3884 - val_accuracy: 0.9043
# Epoch 80/90
# 1875/1875 [==============================] - 12s 6ms/step - loss: 0.0539 - accuracy: 0.9894 - val_loss: 0.6221 - val_accuracy: 0.8607
# Epoch 81/90
# 1875/1875 [==============================] - 12s 6ms/step - loss: 0.0514 - accuracy: 0.9906 - val_loss: 0.3879 - val_accuracy: 0.9004
# Epoch 82/90
# 1875/1875 [==============================] - 12s 7ms/step - loss: 0.0499 - accuracy: 0.9906 - val_loss: 0.4015 - val_accuracy: 0.9005
# Epoch 83/90
# 1875/1875 [==============================] - 12s 7ms/step - loss: 0.0474 - accuracy: 0.9913 - val_loss: 0.4004 - val_accuracy: 0.9015
# Epoch 84/90
# 1875/1875 [==============================] - 12s 6ms/step - loss: 0.0496 - accuracy: 0.9909 - val_loss: 0.3941 - val_accuracy: 0.8999
# Epoch 85/90
# 1875/1875 [==============================] - 12s 6ms/step - loss: 0.0502 - accuracy: 0.9910 - val_loss: 0.4027 - val_accuracy: 0.9016
# Epoch 86/90
# 1875/1875 [==============================] - 12s 6ms/step - loss: 0.0468 - accuracy: 0.9914 - val_loss: 0.4017 - val_accuracy: 0.9011
# Epoch 87/90
# 1875/1875 [==============================] - 12s 6ms/step - loss: 0.0475 - accuracy: 0.9913 - val_loss: 0.3866 - val_accuracy: 0.9050
# Epoch 88/90
# 1875/1875 [==============================] - 13s 7ms/step - loss: 0.0433 - accuracy: 0.9924 - val_loss: 0.3885 - val_accuracy: 0.9037
# Epoch 89/90
# 1875/1875 [==============================] - 12s 6ms/step - loss: 0.0419 - accuracy: 0.9932 - val_loss: 0.3878 - val_accuracy: 0.9038
# Epoch 90/90
# 1875/1875 [==============================] - 12s 6ms/step - loss: 0.0435 - accuracy: 0.9922 - val_loss: 0.4215 - val_accuracy: 0.8976

# %%
#fashion mnist, 3, 4번째 레이어 삭제

accuracy = model.evaluate(test_images, test_labels, verbose=1)
print('Test loss:', accuracy[0])
print('Test accuracy:', accuracy[1])
# Out:
# 313/313 [==============================] - 1s 3ms/step - loss: 0.4215 - accuracy: 0.8976
# Test loss: 0.4214654266834259
# Test accuracy: 0.897599995136261

# %%
import matplotlib.pyplot as plt

# Plot training & validation accuracy values
plt.figure(figsize=(12, 12))

plt.subplot(2, 1, 1)
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')

# Plot training & validation loss values
plt.subplot(2, 1, 2)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')

plt.subplots_adjust(hspace=0.3)
plt.show()
