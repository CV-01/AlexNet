# %%
from tensorflow.python.client import device_lib 
print(device_lib.list_local_devices())
# Out:
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 6688076730225422225
# xla_global_id: -1
# , name: "/device:GPU:0"
# device_type: "GPU"
# memory_limit: 5748293632
# locality {
#   bus_id: 1
#   links {
#   }
# }
# incarnation: 14802349135336390972
# physical_device_desc: "device: 0, name: NVIDIA GeForce RTX 3060 Ti, pci bus id: 0000:2b:00.0, compute capability: 8.6"
# xla_global_id: 416903419
# ]

# %%
import tensorflow as tf
from tensorflow import keras
from keras.models import Sequential
from keras.layers import Dense, Activation, Dropout, Flatten, Conv2D, MaxPooling2D, BatchNormalization
from keras.utils import to_categorical

# %%
# Fashion MNIST 데이터셋 로드
fashion_mnist = keras.datasets.fashion_mnist
(train_images, train_labels), (test_images, test_labels) = fashion_mnist.load_data()

# 데이터 전처리
train_images = train_images.reshape(-1, 28, 28, 1)
test_images = test_images.reshape(-1, 28, 28, 1)
train_images = train_images / 255.0
test_images = test_images / 255.0
train_labels = to_categorical(train_labels)
test_labels = to_categorical(test_labels)

print(train_labels.shape, test_labels.shape)

# 데이터 로더 생성
#batch_size = 64
#train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
#test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)
# Out:
# (60000, 10) (10000, 10)

# %%
# AlexNet model architecture
model = Sequential()

# 1st Convolutional Layer
model.add(Conv2D(filters=96, input_shape=(28,28,1), kernel_size=(11,11), strides=(4,4), padding='same')) 
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2,2), strides=(2,2), padding='same'))

# 2nd Convolutional Layer
model.add(Conv2D(filters=256, kernel_size=(5,5), strides=(1,1), padding='same')) 
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2,2), strides=(2,2), padding='same'))

# 3rd Convolutional Layer
model.add(Conv2D(filters=384, kernel_size=(3,3), strides=(1,1), padding='same')) 
model.add(BatchNormalization())
model.add(Activation('relu'))

# 4th Convolutional Layer
model.add(Conv2D(filters=384, kernel_size=(3,3), strides=(1,1), padding='same')) 
model.add(BatchNormalization())
model.add(Activation('relu'))

# 5th Convolutional Layer
model.add(Conv2D(filters=256, kernel_size=(3,3), strides=(1,1), padding='same')) 
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2,2), strides=(2,2), padding='same'))

# Fully Connected layer
model.add(Flatten())
model.add(Dense(4096, input_shape=(32,32,3))) 
model.add(BatchNormalization()) 
model.add(Activation('relu'))

# Add Dropout to prevent overfitting
model.add(Dropout(0.7))

# Fully Connected Layer
model.add(Dense(4096)) 
model.add(BatchNormalization()) 
model.add(Activation('relu')) # Add Dropout 
model.add(Dropout(0.7))

# Output Layer
model.add(Dense(10)) 
model.add(BatchNormalization()) 
model.add(Activation('softmax'))

# Model Summary
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 7, 7, 96)          11712
#
#  batch_normalization (BatchN  (None, 7, 7, 96)         384
#  ormalization)
#
#  activation (Activation)     (None, 7, 7, 96)          0
#
#  max_pooling2d (MaxPooling2D  (None, 4, 4, 96)         0
#  )
#
#  conv2d_1 (Conv2D)           (None, 4, 4, 256)         614656
#
#  batch_normalization_1 (Batc  (None, 4, 4, 256)        1024
#  hNormalization)
#
#  activation_1 (Activation)   (None, 4, 4, 256)         0
#
#  max_pooling2d_1 (MaxPooling  (None, 2, 2, 256)        0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 2, 2, 384)         885120
#
#  batch_normalization_2 (Batc  (None, 2, 2, 384)        1536
#  hNormalization)
#
#  activation_2 (Activation)   (None, 2, 2, 384)         0
#
#  conv2d_3 (Conv2D)           (None, 2, 2, 384)         1327488
#
#  batch_normalization_3 (Batc  (None, 2, 2, 384)        1536
#  hNormalization)
#
#  activation_3 (Activation)   (None, 2, 2, 384)         0
#
#  conv2d_4 (Conv2D)           (None, 2, 2, 256)         884992
#
#  batch_normalization_4 (Batc  (None, 2, 2, 256)        1024
#  hNormalization)
#
#  activation_4 (Activation)   (None, 2, 2, 256)         0
#
#  max_pooling2d_2 (MaxPooling  (None, 1, 1, 256)        0
#  2D)
#
#  flatten (Flatten)           (None, 256)               0
#
#  dense (Dense)               (None, 4096)              1052672
#
#  batch_normalization_5 (Batc  (None, 4096)             16384
#  hNormalization)
#
#  activation_5 (Activation)   (None, 4096)              0
#
#  dropout (Dropout)           (None, 4096)              0
#
#  dense_1 (Dense)             (None, 4096)              16781312
#
#  batch_normalization_6 (Batc  (None, 4096)             16384
#  hNormalization)
#
#  activation_6 (Activation)   (None, 4096)              0
#
#  dropout_1 (Dropout)         (None, 4096)              0
#
#  dense_2 (Dense)             (None, 10)                40970
#
#  batch_normalization_7 (Batc  (None, 10)               40
#  hNormalization)
#
#  activation_7 (Activation)   (None, 10)                0
#
# =================================================================
# Total params: 21,637,234
# Trainable params: 21,618,078
# Non-trainable params: 19,156
# _________________________________________________________________

# %%
# Compile the model
model.compile(optimizer=tf.keras.optimizers.SGD(learning_rate=0.001), 
              loss='categorical_crossentropy',
              metrics=['accuracy'])
# Train the model
# model.fit(train_images, train_labels, epochs=90, validation_data=(test_images, test_labels))

history = model.fit(train_images, train_labels, epochs=90, 
                    validation_data=(test_images, test_labels))
# Out:
# Epoch 1/90
# 1875/1875 [==============================] - 18s 8ms/step - loss: 1.1402 - accuracy: 0.6780 - val_loss: 0.7144 - val_accuracy: 0.8133
# Epoch 2/90
# 1875/1875 [==============================] - 14s 8ms/step - loss: 0.7914 - accuracy: 0.8080 - val_loss: 0.5760 - val_accuracy: 0.8380
# Epoch 3/90
# 1875/1875 [==============================] - 14s 8ms/step - loss: 0.6765 - accuracy: 0.8346 - val_loss: 0.5078 - val_accuracy: 0.8565
# Epoch 4/90
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.6006 - accuracy: 0.8517 - val_loss: 0.4696 - val_accuracy: 0.8656
# Epoch 5/90
# 1875/1875 [==============================] - 14s 8ms/step - loss: 0.5474 - accuracy: 0.8625 - val_loss: 0.4187 - val_accuracy: 0.8765
# Epoch 6/90
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.5068 - accuracy: 0.8704 - val_loss: 0.3961 - val_accuracy: 0.8802
# Epoch 7/90
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.4762 - accuracy: 0.8762 - val_loss: 0.3809 - val_accuracy: 0.8795
# Epoch 8/90
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.4510 - accuracy: 0.8809 - val_loss: 0.3723 - val_accuracy: 0.8841
# Epoch 9/90
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.4294 - accuracy: 0.8857 - val_loss: 0.3718 - val_accuracy: 0.8794
# Epoch 10/90
# 1875/1875 [==============================] - 14s 8ms/step - loss: 0.4084 - accuracy: 0.8898 - val_loss: 0.3523 - val_accuracy: 0.8899
# Epoch 11/90
# 1875/1875 [==============================] - 14s 8ms/step - loss: 0.3890 - accuracy: 0.8938 - val_loss: 0.3384 - val_accuracy: 0.8877
# Epoch 12/90
# 1875/1875 [==============================] - 14s 8ms/step - loss: 0.3744 - accuracy: 0.8978 - val_loss: 0.3295 - val_accuracy: 0.8931
# Epoch 13/90
# 1875/1875 [==============================] - 14s 8ms/step - loss: 0.3577 - accuracy: 0.9025 - val_loss: 0.3421 - val_accuracy: 0.8878
# Epoch 14/90
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.3496 - accuracy: 0.9041 - val_loss: 0.3778 - val_accuracy: 0.8787
# Epoch 15/90
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.3342 - accuracy: 0.9079 - val_loss: 0.3450 - val_accuracy: 0.8892
# Epoch 16/90
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.3234 - accuracy: 0.9114 - val_loss: 0.3391 - val_accuracy: 0.8858
# Epoch 17/90
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.3124 - accuracy: 0.9141 - val_loss: 0.3274 - val_accuracy: 0.8960
# Epoch 18/90
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.2976 - accuracy: 0.9183 - val_loss: 0.3282 - val_accuracy: 0.8920
# Epoch 19/90
# 1875/1875 [==============================] - 14s 8ms/step - loss: 0.2891 - accuracy: 0.9204 - val_loss: 0.3167 - val_accuracy: 0.8988
# Epoch 20/90
# 1875/1875 [==============================] - 14s 8ms/step - loss: 0.2807 - accuracy: 0.9221 - val_loss: 0.3584 - val_accuracy: 0.8901
# Epoch 21/90
# 1875/1875 [==============================] - 14s 8ms/step - loss: 0.2699 - accuracy: 0.9269 - val_loss: 0.3425 - val_accuracy: 0.8912
# Epoch 22/90
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.2638 - accuracy: 0.9273 - val_loss: 0.3239 - val_accuracy: 0.8954
# Epoch 23/90
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.2532 - accuracy: 0.9310 - val_loss: 0.3386 - val_accuracy: 0.8929
# Epoch 24/90
# 1875/1875 [==============================] - 14s 8ms/step - loss: 0.2466 - accuracy: 0.9334 - val_loss: 0.3189 - val_accuracy: 0.8982
# Epoch 25/90
# 1875/1875 [==============================] - 14s 8ms/step - loss: 0.2355 - accuracy: 0.9356 - val_loss: 0.3290 - val_accuracy: 0.8959
# Epoch 26/90
# 1875/1875 [==============================] - 14s 8ms/step - loss: 0.2305 - accuracy: 0.9379 - val_loss: 0.3372 - val_accuracy: 0.8945
# Epoch 27/90
# 1875/1875 [==============================] - 14s 8ms/step - loss: 0.2237 - accuracy: 0.9406 - val_loss: 0.3981 - val_accuracy: 0.8744
# Epoch 28/90
# 1875/1875 [==============================] - 14s 8ms/step - loss: 0.2179 - accuracy: 0.9414 - val_loss: 0.3225 - val_accuracy: 0.9006
# Epoch 29/90
# 1875/1875 [==============================] - 14s 8ms/step - loss: 0.2086 - accuracy: 0.9446 - val_loss: 0.3604 - val_accuracy: 0.8904
# Epoch 30/90
# 1875/1875 [==============================] - 14s 8ms/step - loss: 0.1992 - accuracy: 0.9467 - val_loss: 0.3506 - val_accuracy: 0.8937
# Epoch 31/90
# 1875/1875 [==============================] - 14s 8ms/step - loss: 0.1946 - accuracy: 0.9485 - val_loss: 0.3150 - val_accuracy: 0.8999
# Epoch 32/90
# 1875/1875 [==============================] - 14s 8ms/step - loss: 0.1875 - accuracy: 0.9503 - val_loss: 0.3511 - val_accuracy: 0.8962
# Epoch 33/90
# 1875/1875 [==============================] - 14s 8ms/step - loss: 0.1819 - accuracy: 0.9521 - val_loss: 0.3342 - val_accuracy: 0.8968
# Epoch 34/90
# 1875/1875 [==============================] - 14s 8ms/step - loss: 0.1743 - accuracy: 0.9542 - val_loss: 0.4183 - val_accuracy: 0.8800
# Epoch 35/90
# 1875/1875 [==============================] - 14s 8ms/step - loss: 0.1673 - accuracy: 0.9568 - val_loss: 0.3270 - val_accuracy: 0.9010
# Epoch 36/90
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.1622 - accuracy: 0.9589 - val_loss: 0.3215 - val_accuracy: 0.9058
# Epoch 37/90
# 1875/1875 [==============================] - 14s 8ms/step - loss: 0.1619 - accuracy: 0.9578 - val_loss: 0.3808 - val_accuracy: 0.8928
# Epoch 38/90
# 1875/1875 [==============================] - 14s 8ms/step - loss: 0.1526 - accuracy: 0.9623 - val_loss: 0.4010 - val_accuracy: 0.8838
# Epoch 39/90
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.1466 - accuracy: 0.9628 - val_loss: 0.3464 - val_accuracy: 0.8988
# Epoch 40/90
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.1430 - accuracy: 0.9643 - val_loss: 0.3681 - val_accuracy: 0.8952
# Epoch 41/90
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.1422 - accuracy: 0.9645 - val_loss: 0.3925 - val_accuracy: 0.8884
# Epoch 42/90
# 1875/1875 [==============================] - 15s 8ms/step - loss: 0.1318 - accuracy: 0.9674 - val_loss: 0.4123 - val_accuracy: 0.8866
# Epoch 43/90
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.1348 - accuracy: 0.9664 - val_loss: 0.3894 - val_accuracy: 0.8940
# Epoch 44/90
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.1281 - accuracy: 0.9685 - val_loss: 0.4254 - val_accuracy: 0.8834
# Epoch 45/90
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.1188 - accuracy: 0.9716 - val_loss: 0.4219 - val_accuracy: 0.8892
# Epoch 46/90
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.1175 - accuracy: 0.9718 - val_loss: 0.3667 - val_accuracy: 0.8994
# Epoch 47/90
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.1151 - accuracy: 0.9723 - val_loss: 0.4009 - val_accuracy: 0.8904
# Epoch 48/90
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.1085 - accuracy: 0.9747 - val_loss: 0.3499 - val_accuracy: 0.9061
# Epoch 49/90
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.1067 - accuracy: 0.9743 - val_loss: 0.4442 - val_accuracy: 0.8818
# Epoch 50/90
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.1030 - accuracy: 0.9761 - val_loss: 0.4797 - val_accuracy: 0.8787
# Epoch 51/90
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.0999 - accuracy: 0.9765 - val_loss: 0.3555 - val_accuracy: 0.9042
# Epoch 52/90
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.0952 - accuracy: 0.9787 - val_loss: 0.3995 - val_accuracy: 0.8963
# Epoch 53/90
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.0924 - accuracy: 0.9794 - val_loss: 0.3610 - val_accuracy: 0.9050
# Epoch 54/90
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.0909 - accuracy: 0.9800 - val_loss: 0.3697 - val_accuracy: 0.9047
# Epoch 55/90
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.0919 - accuracy: 0.9788 - val_loss: 0.4491 - val_accuracy: 0.8859
# Epoch 56/90
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.0860 - accuracy: 0.9803 - val_loss: 0.4353 - val_accuracy: 0.8852
# Epoch 57/90
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.0829 - accuracy: 0.9812 - val_loss: 0.3750 - val_accuracy: 0.8995
# Epoch 58/90
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.0821 - accuracy: 0.9817 - val_loss: 0.5054 - val_accuracy: 0.8797
# Epoch 59/90
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.0814 - accuracy: 0.9819 - val_loss: 0.3577 - val_accuracy: 0.9084
# Epoch 60/90
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.0724 - accuracy: 0.9845 - val_loss: 0.3700 - val_accuracy: 0.9020
# Epoch 61/90
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.0792 - accuracy: 0.9821 - val_loss: 0.5871 - val_accuracy: 0.8674
# Epoch 62/90
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.0730 - accuracy: 0.9845 - val_loss: 0.3747 - val_accuracy: 0.9068
# Epoch 63/90
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.0676 - accuracy: 0.9864 - val_loss: 0.4421 - val_accuracy: 0.8898
# Epoch 64/90
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.0652 - accuracy: 0.9869 - val_loss: 0.3823 - val_accuracy: 0.9064
# Epoch 65/90
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.0685 - accuracy: 0.9854 - val_loss: 0.3903 - val_accuracy: 0.9035
# Epoch 66/90
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.0657 - accuracy: 0.9859 - val_loss: 0.3995 - val_accuracy: 0.9013
# Epoch 67/90
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.0613 - accuracy: 0.9877 - val_loss: 0.4583 - val_accuracy: 0.8917
# Epoch 68/90
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.0588 - accuracy: 0.9882 - val_loss: 0.4188 - val_accuracy: 0.8981
# Epoch 69/90
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.0594 - accuracy: 0.9882 - val_loss: 0.3790 - val_accuracy: 0.9071
# Epoch 70/90
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.0583 - accuracy: 0.9879 - val_loss: 0.4051 - val_accuracy: 0.9030
# Epoch 71/90
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.0526 - accuracy: 0.9897 - val_loss: 0.4326 - val_accuracy: 0.8978
# Epoch 72/90
# 1875/1875 [==============================] - 14s 8ms/step - loss: 0.0523 - accuracy: 0.9899 - val_loss: 0.4268 - val_accuracy: 0.8974
# Epoch 73/90
# 1875/1875 [==============================] - 14s 8ms/step - loss: 0.0570 - accuracy: 0.9885 - val_loss: 0.3869 - val_accuracy: 0.9073
# Epoch 74/90
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.0509 - accuracy: 0.9894 - val_loss: 0.4090 - val_accuracy: 0.9050
# Epoch 75/90
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.0500 - accuracy: 0.9904 - val_loss: 0.3936 - val_accuracy: 0.9080
# Epoch 76/90
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.0516 - accuracy: 0.9892 - val_loss: 0.4461 - val_accuracy: 0.8951
# Epoch 77/90
# 1875/1875 [==============================] - 14s 8ms/step - loss: 0.0507 - accuracy: 0.9904 - val_loss: 0.4111 - val_accuracy: 0.9036
# Epoch 78/90
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.0515 - accuracy: 0.9898 - val_loss: 0.4183 - val_accuracy: 0.9010
# Epoch 79/90
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.0483 - accuracy: 0.9907 - val_loss: 0.4187 - val_accuracy: 0.9020
# Epoch 80/90
# 1875/1875 [==============================] - 14s 8ms/step - loss: 0.0454 - accuracy: 0.9915 - val_loss: 0.4163 - val_accuracy: 0.9035
# Epoch 81/90
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.0437 - accuracy: 0.9918 - val_loss: 0.4041 - val_accuracy: 0.9053
# Epoch 82/90
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.0435 - accuracy: 0.9920 - val_loss: 0.4238 - val_accuracy: 0.9036
# Epoch 83/90
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.0434 - accuracy: 0.9921 - val_loss: 0.4139 - val_accuracy: 0.9032
# Epoch 84/90
# 1875/1875 [==============================] - 15s 8ms/step - loss: 0.0401 - accuracy: 0.9926 - val_loss: 0.4225 - val_accuracy: 0.9042
# Epoch 85/90
# 1875/1875 [==============================] - 14s 8ms/step - loss: 0.0407 - accuracy: 0.9928 - val_loss: 0.4032 - val_accuracy: 0.9075
# Epoch 86/90
# 1875/1875 [==============================] - 14s 8ms/step - loss: 0.0385 - accuracy: 0.9934 - val_loss: 0.4182 - val_accuracy: 0.9060
# Epoch 87/90
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.0442 - accuracy: 0.9917 - val_loss: 0.3991 - val_accuracy: 0.9057
# Epoch 88/90
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.0393 - accuracy: 0.9925 - val_loss: 0.3946 - val_accuracy: 0.9087
# Epoch 89/90
# 1875/1875 [==============================] - 15s 8ms/step - loss: 0.0351 - accuracy: 0.9940 - val_loss: 0.6324 - val_accuracy: 0.8629
# Epoch 90/90
# 1875/1875 [==============================] - 14s 8ms/step - loss: 0.0338 - accuracy: 0.9944 - val_loss: 0.4022 - val_accuracy: 0.9092

# %%
#fashion mnist, dropout0.7

accuracy = model.evaluate(test_images, test_labels, verbose=1)
print('Test loss:', accuracy[0])
print('Test accuracy:', accuracy[1])
# Out:
# 313/313 [==============================] - 1s 3ms/step - loss: 0.4022 - accuracy: 0.9092
# Test loss: 0.40216436982154846
# Test accuracy: 0.9092000126838684

# %%
import matplotlib.pyplot as plt

# Plot training & validation accuracy values
plt.figure(figsize=(12, 12))

plt.subplot(2, 1, 1)
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')

# Plot training & validation loss values
plt.subplot(2, 1, 2)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')

plt.subplots_adjust(hspace=0.3)
plt.show()
