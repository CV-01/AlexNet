# %%
from tensorflow.python.client import device_lib 
print(device_lib.list_local_devices())
# Out:
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 1097485806935546910
# xla_global_id: -1
# , name: "/device:GPU:0"
# device_type: "GPU"
# memory_limit: 5748293632
# locality {
#   bus_id: 1
#   links {
#   }
# }
# incarnation: 13697803602167071876
# physical_device_desc: "device: 0, name: NVIDIA GeForce RTX 3060 Ti, pci bus id: 0000:2b:00.0, compute capability: 8.6"
# xla_global_id: 416903419
# ]

# %%
import tensorflow as tf
from tensorflow import keras
from keras.models import Sequential
from keras.layers import Dense, Activation, Dropout, Flatten, Conv2D, MaxPooling2D, BatchNormalization
from keras.utils import to_categorical

# %%
# Fashion MNIST 데이터셋 로드
fashion_mnist = keras.datasets.fashion_mnist
(train_images, train_labels), (test_images, test_labels) = fashion_mnist.load_data()

# 데이터 전처리
train_images = train_images.reshape(-1, 28, 28, 1)
test_images = test_images.reshape(-1, 28, 28, 1)
train_images = train_images / 255.0
test_images = test_images / 255.0
train_labels = to_categorical(train_labels)
test_labels = to_categorical(test_labels)

print(train_labels.shape, test_labels.shape)

# 데이터 로더 생성
#batch_size = 64
#train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
#test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)
# Out:
# (60000, 10) (10000, 10)

# %%
# AlexNet model architecture
model = Sequential()

# 1st Convolutional Layer
model.add(Conv2D(filters=96, input_shape=(28,28,1), kernel_size=(11,11), strides=(4,4), padding='same')) 
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2,2), strides=(2,2), padding='same'))

# 2nd Convolutional Layer
model.add(Conv2D(filters=256, kernel_size=(5,5), strides=(1,1), padding='same')) 
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2,2), strides=(2,2), padding='same'))

# 3rd Convolutional Layer
model.add(Conv2D(filters=384, kernel_size=(3,3), strides=(1,1), padding='same')) 
model.add(BatchNormalization())
model.add(Activation('relu'))

# 4th Convolutional Layer
model.add(Conv2D(filters=384, kernel_size=(3,3), strides=(1,1), padding='same')) 
model.add(BatchNormalization())
model.add(Activation('relu'))

# 5th Convolutional Layer
model.add(Conv2D(filters=256, kernel_size=(3,3), strides=(1,1), padding='same')) 
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2,2), strides=(2,2), padding='same'))

# Fully Connected layer
model.add(Flatten())
model.add(Dense(4096, input_shape=(32,32,3))) 
model.add(BatchNormalization()) 
model.add(Activation('relu'))

# Add Dropout to prevent overfitting
model.add(Dropout(0.9))

# Fully Connected Layer
model.add(Dense(4096)) 
model.add(BatchNormalization()) 
model.add(Activation('relu')) # Add Dropout 
model.add(Dropout(0.9))

# Output Layer
model.add(Dense(10)) 
model.add(BatchNormalization()) 
model.add(Activation('softmax'))

# Model Summary
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 7, 7, 96)          11712
#
#  batch_normalization (BatchN  (None, 7, 7, 96)         384
#  ormalization)
#
#  activation (Activation)     (None, 7, 7, 96)          0
#
#  max_pooling2d (MaxPooling2D  (None, 4, 4, 96)         0
#  )
#
#  conv2d_1 (Conv2D)           (None, 4, 4, 256)         614656
#
#  batch_normalization_1 (Batc  (None, 4, 4, 256)        1024
#  hNormalization)
#
#  activation_1 (Activation)   (None, 4, 4, 256)         0
#
#  max_pooling2d_1 (MaxPooling  (None, 2, 2, 256)        0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 2, 2, 384)         885120
#
#  batch_normalization_2 (Batc  (None, 2, 2, 384)        1536
#  hNormalization)
#
#  activation_2 (Activation)   (None, 2, 2, 384)         0
#
#  conv2d_3 (Conv2D)           (None, 2, 2, 384)         1327488
#
#  batch_normalization_3 (Batc  (None, 2, 2, 384)        1536
#  hNormalization)
#
#  activation_3 (Activation)   (None, 2, 2, 384)         0
#
#  conv2d_4 (Conv2D)           (None, 2, 2, 256)         884992
#
#  batch_normalization_4 (Batc  (None, 2, 2, 256)        1024
#  hNormalization)
#
#  activation_4 (Activation)   (None, 2, 2, 256)         0
#
#  max_pooling2d_2 (MaxPooling  (None, 1, 1, 256)        0
#  2D)
#
#  flatten (Flatten)           (None, 256)               0
#
#  dense (Dense)               (None, 4096)              1052672
#
#  batch_normalization_5 (Batc  (None, 4096)             16384
#  hNormalization)
#
#  activation_5 (Activation)   (None, 4096)              0
#
#  dropout (Dropout)           (None, 4096)              0
#
#  dense_1 (Dense)             (None, 4096)              16781312
#
#  batch_normalization_6 (Batc  (None, 4096)             16384
#  hNormalization)
#
#  activation_6 (Activation)   (None, 4096)              0
#
#  dropout_1 (Dropout)         (None, 4096)              0
#
#  dense_2 (Dense)             (None, 10)                40970
#
#  batch_normalization_7 (Batc  (None, 10)               40
#  hNormalization)
#
#  activation_7 (Activation)   (None, 10)                0
#
# =================================================================
# Total params: 21,637,234
# Trainable params: 21,618,078
# Non-trainable params: 19,156
# _________________________________________________________________

# %%
# Compile the model
model.compile(optimizer=tf.keras.optimizers.SGD(learning_rate=0.001), 
              loss='categorical_crossentropy',
              metrics=['accuracy'])
# Train the model
# model.fit(train_images, train_labels, epochs=90, validation_data=(test_images, test_labels))

history = model.fit(train_images, train_labels, epochs=90, 
                    validation_data=(test_images, test_labels))
# Out:
# Epoch 1/90
# 1875/1875 [==============================] - 16s 7ms/step - loss: 1.9192 - accuracy: 0.3322 - val_loss: 1.2372 - val_accuracy: 0.7040
# Epoch 2/90
# 1875/1875 [==============================] - 13s 7ms/step - loss: 1.3112 - accuracy: 0.5942 - val_loss: 0.9802 - val_accuracy: 0.7539
# Epoch 3/90
# 1875/1875 [==============================] - 14s 7ms/step - loss: 1.0953 - accuracy: 0.6907 - val_loss: 0.8078 - val_accuracy: 0.7982
# Epoch 4/90
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.9501 - accuracy: 0.7472 - val_loss: 0.7120 - val_accuracy: 0.8048
# Epoch 5/90
# 1875/1875 [==============================] - 14s 8ms/step - loss: 0.8426 - accuracy: 0.7840 - val_loss: 0.6257 - val_accuracy: 0.8264
# Epoch 6/90
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.7600 - accuracy: 0.8066 - val_loss: 0.5828 - val_accuracy: 0.8377
# Epoch 7/90
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.6989 - accuracy: 0.8236 - val_loss: 0.5673 - val_accuracy: 0.8290
# Epoch 8/90
# 1875/1875 [==============================] - 13s 7ms/step - loss: 0.6469 - accuracy: 0.8366 - val_loss: 0.5103 - val_accuracy: 0.8385
# Epoch 9/90
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.6071 - accuracy: 0.8443 - val_loss: 0.5008 - val_accuracy: 0.8376
# Epoch 10/90
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.5745 - accuracy: 0.8527 - val_loss: 0.4876 - val_accuracy: 0.8360
# Epoch 11/90
# 1875/1875 [==============================] - 13s 7ms/step - loss: 0.5423 - accuracy: 0.8596 - val_loss: 0.4590 - val_accuracy: 0.8453
# Epoch 12/90
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.5197 - accuracy: 0.8634 - val_loss: 0.4371 - val_accuracy: 0.8594
# Epoch 13/90
# 1875/1875 [==============================] - 13s 7ms/step - loss: 0.4973 - accuracy: 0.8699 - val_loss: 0.4749 - val_accuracy: 0.8371
# Epoch 14/90
# 1875/1875 [==============================] - 13s 7ms/step - loss: 0.4796 - accuracy: 0.8718 - val_loss: 0.4568 - val_accuracy: 0.8454
# Epoch 15/90
# 1875/1875 [==============================] - 13s 7ms/step - loss: 0.4595 - accuracy: 0.8769 - val_loss: 0.4065 - val_accuracy: 0.8586
# Epoch 16/90
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.4428 - accuracy: 0.8816 - val_loss: 0.4572 - val_accuracy: 0.8433
# Epoch 17/90
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.4313 - accuracy: 0.8831 - val_loss: 0.4221 - val_accuracy: 0.8593
# Epoch 18/90
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.4184 - accuracy: 0.8875 - val_loss: 0.4525 - val_accuracy: 0.8479
# Epoch 19/90
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.4064 - accuracy: 0.8895 - val_loss: 0.4483 - val_accuracy: 0.8493
# Epoch 20/90
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.3950 - accuracy: 0.8935 - val_loss: 0.4116 - val_accuracy: 0.8584
# Epoch 21/90
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.3781 - accuracy: 0.8977 - val_loss: 0.4230 - val_accuracy: 0.8560
# Epoch 22/90
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.3656 - accuracy: 0.9023 - val_loss: 0.3578 - val_accuracy: 0.8806
# Epoch 23/90
# 1875/1875 [==============================] - 15s 8ms/step - loss: 0.3592 - accuracy: 0.9029 - val_loss: 0.4677 - val_accuracy: 0.8386
# Epoch 24/90
# 1875/1875 [==============================] - 14s 8ms/step - loss: 0.3543 - accuracy: 0.9032 - val_loss: 0.4182 - val_accuracy: 0.8586
# Epoch 25/90
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.3413 - accuracy: 0.9079 - val_loss: 0.3849 - val_accuracy: 0.8740
# Epoch 26/90
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.3282 - accuracy: 0.9111 - val_loss: 0.4236 - val_accuracy: 0.8631
# Epoch 27/90
# 1875/1875 [==============================] - 13s 7ms/step - loss: 0.3187 - accuracy: 0.9140 - val_loss: 0.4690 - val_accuracy: 0.8441
# Epoch 28/90
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.3173 - accuracy: 0.9150 - val_loss: 0.4489 - val_accuracy: 0.8508
# Epoch 29/90
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.3050 - accuracy: 0.9184 - val_loss: 0.3897 - val_accuracy: 0.8713
# Epoch 30/90
# 1875/1875 [==============================] - 13s 7ms/step - loss: 0.2970 - accuracy: 0.9208 - val_loss: 0.4754 - val_accuracy: 0.8447
# Epoch 31/90
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.2868 - accuracy: 0.9238 - val_loss: 0.3977 - val_accuracy: 0.8707
# Epoch 32/90
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.2816 - accuracy: 0.9242 - val_loss: 0.3959 - val_accuracy: 0.8702
# Epoch 33/90
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.2718 - accuracy: 0.9271 - val_loss: 0.3921 - val_accuracy: 0.8713
# Epoch 34/90
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.2652 - accuracy: 0.9293 - val_loss: 0.4470 - val_accuracy: 0.8494
# Epoch 35/90
# 1875/1875 [==============================] - 14s 8ms/step - loss: 0.2571 - accuracy: 0.9320 - val_loss: 0.5660 - val_accuracy: 0.8128
# Epoch 36/90
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.2515 - accuracy: 0.9341 - val_loss: 0.4635 - val_accuracy: 0.8491
# Epoch 37/90
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.2426 - accuracy: 0.9376 - val_loss: 0.5400 - val_accuracy: 0.8314
# Epoch 38/90
# 1875/1875 [==============================] - 14s 8ms/step - loss: 0.2432 - accuracy: 0.9351 - val_loss: 0.3672 - val_accuracy: 0.8838
# Epoch 39/90
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.2304 - accuracy: 0.9398 - val_loss: 0.5220 - val_accuracy: 0.8360
# Epoch 40/90
# 1875/1875 [==============================] - 14s 8ms/step - loss: 0.2271 - accuracy: 0.9410 - val_loss: 0.4073 - val_accuracy: 0.8714
# Epoch 41/90
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.2156 - accuracy: 0.9447 - val_loss: 0.3809 - val_accuracy: 0.8805
# Epoch 42/90
# 1875/1875 [==============================] - 14s 8ms/step - loss: 0.2154 - accuracy: 0.9433 - val_loss: 0.4166 - val_accuracy: 0.8723
# Epoch 43/90
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.2061 - accuracy: 0.9468 - val_loss: 0.4056 - val_accuracy: 0.8737
# Epoch 44/90
# 1875/1875 [==============================] - 14s 8ms/step - loss: 0.2065 - accuracy: 0.9472 - val_loss: 0.4361 - val_accuracy: 0.8649
# Epoch 45/90
# 1875/1875 [==============================] - 14s 8ms/step - loss: 0.1990 - accuracy: 0.9494 - val_loss: 0.4195 - val_accuracy: 0.8729
# Epoch 46/90
# 1875/1875 [==============================] - 14s 8ms/step - loss: 0.1891 - accuracy: 0.9517 - val_loss: 0.4824 - val_accuracy: 0.8580
# Epoch 47/90
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.1884 - accuracy: 0.9506 - val_loss: 0.4733 - val_accuracy: 0.8529
# Epoch 48/90
# 1875/1875 [==============================] - 13s 7ms/step - loss: 0.1775 - accuracy: 0.9557 - val_loss: 0.3548 - val_accuracy: 0.8927
# Epoch 49/90
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.1743 - accuracy: 0.9568 - val_loss: 0.3789 - val_accuracy: 0.8850
# Epoch 50/90
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.1724 - accuracy: 0.9575 - val_loss: 0.4752 - val_accuracy: 0.8505
# Epoch 51/90
# 1875/1875 [==============================] - 14s 8ms/step - loss: 0.1686 - accuracy: 0.9581 - val_loss: 0.4500 - val_accuracy: 0.8654
# Epoch 52/90
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.1630 - accuracy: 0.9598 - val_loss: 0.3968 - val_accuracy: 0.8797
# Epoch 53/90
# 1875/1875 [==============================] - 14s 8ms/step - loss: 0.1585 - accuracy: 0.9614 - val_loss: 0.3821 - val_accuracy: 0.8904
# Epoch 54/90
# 1875/1875 [==============================] - 14s 8ms/step - loss: 0.1540 - accuracy: 0.9623 - val_loss: 0.4172 - val_accuracy: 0.8779
# Epoch 55/90
# 1875/1875 [==============================] - 14s 8ms/step - loss: 0.1516 - accuracy: 0.9638 - val_loss: 0.5470 - val_accuracy: 0.8474
# Epoch 56/90
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.1496 - accuracy: 0.9632 - val_loss: 0.6836 - val_accuracy: 0.8119
# Epoch 57/90
# 1875/1875 [==============================] - 15s 8ms/step - loss: 0.1463 - accuracy: 0.9639 - val_loss: 0.4306 - val_accuracy: 0.8758
# Epoch 58/90
# 1875/1875 [==============================] - 14s 8ms/step - loss: 0.1406 - accuracy: 0.9658 - val_loss: 0.5122 - val_accuracy: 0.8450
# Epoch 59/90
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.1383 - accuracy: 0.9665 - val_loss: 0.4270 - val_accuracy: 0.8750
# Epoch 60/90
# 1875/1875 [==============================] - 14s 8ms/step - loss: 0.1350 - accuracy: 0.9675 - val_loss: 0.4180 - val_accuracy: 0.8819
# Epoch 61/90
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.1339 - accuracy: 0.9682 - val_loss: 0.4088 - val_accuracy: 0.8823
# Epoch 62/90
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.1259 - accuracy: 0.9701 - val_loss: 0.4382 - val_accuracy: 0.8734
# Epoch 63/90
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.1284 - accuracy: 0.9701 - val_loss: 0.4705 - val_accuracy: 0.8667
# Epoch 64/90
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.1190 - accuracy: 0.9727 - val_loss: 0.4746 - val_accuracy: 0.8678
# Epoch 65/90
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.1164 - accuracy: 0.9742 - val_loss: 0.4212 - val_accuracy: 0.8857
# Epoch 66/90
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.1163 - accuracy: 0.9727 - val_loss: 0.4031 - val_accuracy: 0.8845
# Epoch 67/90
# 1875/1875 [==============================] - 15s 8ms/step - loss: 0.1124 - accuracy: 0.9740 - val_loss: 0.4911 - val_accuracy: 0.8670
# Epoch 68/90
# 1875/1875 [==============================] - 15s 8ms/step - loss: 0.1107 - accuracy: 0.9757 - val_loss: 0.4159 - val_accuracy: 0.8865
# Epoch 69/90
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.1058 - accuracy: 0.9756 - val_loss: 0.5039 - val_accuracy: 0.8606
# Epoch 70/90
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.1049 - accuracy: 0.9764 - val_loss: 0.6435 - val_accuracy: 0.8379
# Epoch 71/90
# 1875/1875 [==============================] - 13s 7ms/step - loss: 0.1043 - accuracy: 0.9771 - val_loss: 0.4158 - val_accuracy: 0.8860
# Epoch 72/90
# 1875/1875 [==============================] - 13s 7ms/step - loss: 0.1019 - accuracy: 0.9769 - val_loss: 0.4772 - val_accuracy: 0.8702
# Epoch 73/90
# 1875/1875 [==============================] - 13s 7ms/step - loss: 0.0994 - accuracy: 0.9781 - val_loss: 0.4454 - val_accuracy: 0.8748
# Epoch 74/90
# 1875/1875 [==============================] - 13s 7ms/step - loss: 0.0960 - accuracy: 0.9787 - val_loss: 0.4760 - val_accuracy: 0.8716
# Epoch 75/90
# 1875/1875 [==============================] - 13s 7ms/step - loss: 0.0910 - accuracy: 0.9802 - val_loss: 0.4480 - val_accuracy: 0.8791
# Epoch 76/90
# 1875/1875 [==============================] - 13s 7ms/step - loss: 0.0920 - accuracy: 0.9797 - val_loss: 0.5384 - val_accuracy: 0.8534
# Epoch 77/90
# 1875/1875 [==============================] - 13s 7ms/step - loss: 0.0875 - accuracy: 0.9815 - val_loss: 0.4639 - val_accuracy: 0.8768
# Epoch 78/90
# 1875/1875 [==============================] - 13s 7ms/step - loss: 0.0862 - accuracy: 0.9813 - val_loss: 0.4675 - val_accuracy: 0.8772
# Epoch 79/90
# 1875/1875 [==============================] - 13s 7ms/step - loss: 0.0840 - accuracy: 0.9821 - val_loss: 0.4329 - val_accuracy: 0.8884
# Epoch 80/90
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.0832 - accuracy: 0.9830 - val_loss: 0.4772 - val_accuracy: 0.8734
# Epoch 81/90
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.0803 - accuracy: 0.9833 - val_loss: 0.4597 - val_accuracy: 0.8822
# Epoch 82/90
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.0832 - accuracy: 0.9824 - val_loss: 0.4385 - val_accuracy: 0.8870
# Epoch 83/90
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.0775 - accuracy: 0.9836 - val_loss: 0.4308 - val_accuracy: 0.8873
# Epoch 84/90
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.0774 - accuracy: 0.9839 - val_loss: 0.4831 - val_accuracy: 0.8754
# Epoch 85/90
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.0765 - accuracy: 0.9844 - val_loss: 0.4875 - val_accuracy: 0.8726
# Epoch 86/90
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.0705 - accuracy: 0.9860 - val_loss: 0.5254 - val_accuracy: 0.8625
# Epoch 87/90
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.0721 - accuracy: 0.9854 - val_loss: 0.4163 - val_accuracy: 0.8950
# Epoch 88/90
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.0697 - accuracy: 0.9866 - val_loss: 0.5278 - val_accuracy: 0.8710
# Epoch 89/90
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.0703 - accuracy: 0.9865 - val_loss: 0.4754 - val_accuracy: 0.8793
# Epoch 90/90
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.0652 - accuracy: 0.9872 - val_loss: 0.5084 - val_accuracy: 0.8777

# %%
#fashion mnist, dropout0.9

accuracy = model.evaluate(test_images, test_labels, verbose=1)
print('Test loss:', accuracy[0])
print('Test accuracy:', accuracy[1])
# Out:
# 313/313 [==============================] - 1s 3ms/step - loss: 0.5084 - accuracy: 0.8777
# Test loss: 0.5084453821182251
# Test accuracy: 0.8776999711990356

# %%
import matplotlib.pyplot as plt

# Plot training & validation accuracy values
plt.figure(figsize=(12, 12))

plt.subplot(2, 1, 1)
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')

# Plot training & validation loss values
plt.subplot(2, 1, 2)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')

plt.subplots_adjust(hspace=0.3)
plt.show()
